# %% [markdown]
# # Table 3 code, to scrape data from Google

# %%
import requests
import pandas as pd
import threading
import re
from datetime import datetime
import os

# API key for SerpApi
serpapi_api_key = 'b5f1b87f8b27028ec463904255cd4c96250d67e4d7f51e602956b5725d857ef5'

# Shared list for Google Scholar articles
articles_google_scholar = []

# Define the output directory
output_dir = r"Your Directory"

os.makedirs(output_dir, exist_ok=True)  # Create the output directory if it doesn't exist

# Lock for thread-safe operations on shared variables
lock = threading.Lock()

# Function to fetch Google Scholar pages with a max limit of 100 results
def fetch_google_scholar_pages():
    global articles_google_scholar

    print("Fetching article data from Google Scholar...")

    base_url = "https://serpapi.com/search.json"

    query = '(("Large Language Models" OR "LLM" OR "Artificial Intelligence") AND ("Software Project Management" OR "Software Engineering Management" OR "Software Project Development" OR "IT Project Management" OR "Software Lifecycle Management" OR "Project Management Framework"))'

    start = 0
    page_size = 10  # Number of articles per page
    max_results = 1000  # Maximum number of articles to fetch
    total_fetched = 0  # Counter for articles fetched
    has_more_results = True  # Flag to control the loop

    while total_fetched < max_results and has_more_results:
        params = {
            "engine": "google_scholar",
            "q": query,
            "api_key": serpapi_api_key,
            "start": start,
            "as_vis": 1,  # Limit results to scholarly articles
        }

        response = requests.get(base_url, params=params)

        if response.status_code == 200:
            results = response.json()

            if 'organic_results' in results and results['organic_results']:
                fetched_any = False

                for article in results['organic_results']:
                    if total_fetched >= max_results:
                        break  # Stop fetching if we have reached the limit

                    title = article.get('title', 'No title available')
                    link = article.get('link', 'No link available')
                    snippet = article.get('snippet', 'No snippet available')  # Use snippet as a proxy for abstract
                    cited_by_count = article.get('inline_links', {}).get('cited_by', {}).get('total', 0)
                    authors_summary = article.get('publication_info', {}).get('summary', 'Not provided')
                    year_match = re.search(r'(\b(20|d{2})\|19|d{2})\b', authors_summary)
                    year = int(year_match.group(0)) if year_match else datetime.now().year

                    articles_google_scholar.append({
                        'title': title,
                        'authors': authors_summary,
                        'source': 'Google Scholar via SerpApi',
                        'year': year,
                        'doi': link,  # Google Scholar doesn't provide DOIs, using link instead
                        'abstract': snippet  # Ensure snippet is taken directly from Google Scholar result
                    })

                    total_fetched += 1
                    fetched_any = True

                if fetched_any:
                    start += page_size  # Move to the next page of results
                else:
                    print("No more new results available.")
                    has_more_results = False
            else:
                print("No more results available.")
                has_more_results = False
        else:
            print(f"Failed to fetch data for start={start} from Google Scholar: {response.status_code}, {response.text}")
            has_more_results = False

    with lock:
        df_google_scholar = pd.DataFrame(articles_google_scholar)
        df_google_scholar.to_csv(os.path.join(output_dir, "TIP_Google_Scholar_Results.csv"), index=False)

    print("Google Scholar data fetched and saved successfully.")

# Running the fetch using threading
thread = threading.Thread(target=fetch_google_scholar_pages)
thread.start()
thread.join()
# Out:
# Fetching article data from Google Scholar...
# No more results available.
# Google Scholar data fetched and saved successfully.

# %% [markdown]
# # Table 4 code to clean Table 3 data

# %%
import pandas as pd
import re
import os


def filter_dois(input_csv_path, output_dir):
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Define output file paths
    output_with_dois_csv_path = os.path.join(output_dir, "TIP_google_DOIs.csv")
    output_without_dois_csv_path = os.path.join(output_dir, "TIP_google_Without_DOIs.csv")
    output_removed_csv_path = os.path.join(output_dir, "TIP_google_Removed_articles.csv")
    output_filtered_csv_path = os.path.join(output_dir, "TIP_google_combined.csv")

    # Load the CSV file into a DataFrame
    df = pd.read_csv(input_csv_path)

    # Filter out entries containing 'book', 'report', 'chapter', 'thesis', or 'news' in the 'doi' column
    removal_pattern = r'book|report|chapter|thesis|news'
    removed_df = df[df['doi'].str.contains(removal_pattern, na=False, case=False)]
    remaining_df = df[~df['doi'].str.contains(removal_pattern, na=False, case=False)]

    # Filter based on the presence of DOIs in the remaining entries
    doi_pattern = r'10\.'  # DOIs typically start with "10."
    with_dois_df = remaining_df[remaining_df['doi'].str.contains(doi_pattern, na=False)]
    without_dois_df = remaining_df[~remaining_df['doi'].str.contains(doi_pattern, na=False)]

    # Save the filtered DataFrame with DOIs to a new CSV file
    with_dois_df.to_csv(output_with_dois_csv_path, index=False)

    # Further filter out entries with government URLs in the remaining entries without DOIs
    gov_pattern = r'\.gov|\.uk|\.au|\.ca'
    removed_gov_df = without_dois_df[without_dois_df['doi'].str.contains(gov_pattern, na=False, case=False)]
    cleaned_without_dois_df = without_dois_df[~without_dois_df['doi'].str.contains(gov_pattern, na=False, case=False)]

    # Combine all removed entries into a single DataFrame
    all_removed_df = pd.concat([removed_df, removed_gov_df])

    # Save the remaining entries without DOIs to a new CSV file
    cleaned_without_dois_df.to_csv(output_without_dois_csv_path, index=False)

    # Save all removed entries to a new CSV file
    all_removed_df.to_csv(output_removed_csv_path, index=False)

    # Combine entries with DOIs and cleaned entries without DOIs
    filtered_articles_df = pd.concat([with_dois_df, cleaned_without_dois_df])

    # Save the combined filtered articles to a new CSV file
    filtered_articles_df.to_csv(output_filtered_csv_path, index=False)

    print(f"Entries with DOIs saved to {output_with_dois_csv_path}")
    print(f"Entries without DOIs saved to {output_without_dois_csv_path}")
    print(f"Removed entries saved to {output_removed_csv_path}")
    print(f"Combined DOI/without DOI articles saved to {output_filtered_csv_path}")


# Define the input file path
input_csv_path = r"/content/Your_Directory/TIP_Google_Scholar_Results.csv"
output_dir = r"Cleaned"

# Call the function to filter entries with and without DOIs, and remove specific entries
filter_dois(input_csv_path, output_dir)
# Out:
# Entries with DOIs saved to Cleaned/TIP_google_DOIs.csv
# Entries without DOIs saved to Cleaned/TIP_google_Without_DOIs.csv
# Removed entries saved to Cleaned/TIP_google_Removed_articles.csv
# Combined DOI/without DOI articles saved to Cleaned/TIP_google_combined.csv

# %% [markdown]
# **Code to Scrape full abstracts for Google Scholar data.**

# %%
# !pip install openpyxl beautifulsoup4
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)

# %%
import pandas as pd
import requests
import re
import time
from bs4 import BeautifulSoup
from urllib.parse import quote
import os

# Configuration
input_file = r"Full_Abstract_scraping_for_google.xlsx"
output_file = r"Full_Abstracts.xlsx"

# Function to extract DOI from URL
def extract_doi(url):
    """Extract DOI from a URL if present"""
    if pd.isna(url) or url == 'No link available':
        return None
    doi_pattern = r'10\.\d{4,9}/[-._;()/:A-Z0-9]+'
    match = re.search(doi_pattern, str(url), re.IGNORECASE)
    return match.group(0) if match else None

# Function to get abstract from CrossRef using DOI
def get_abstract_from_crossref(doi):
    """Fetch abstract from CrossRef API using DOI"""
    try:
        url = f"https://api.crossref.org/works/{quote(doi, safe='')}"
        headers = {'User-Agent': 'Mozilla/5.0 (Educational Research; mailto:research@example.com)'}
        response = requests.get(url, headers=headers, timeout=10)

        if response.status_code == 200:
            data = response.json()
            abstract = data.get('message', {}).get('abstract', '')
            if abstract:
                # Remove XML tags if present
                abstract = re.sub(r'<[^>]+>', '', abstract)
                return abstract.strip()
    except Exception as e:
        print(f"  CrossRef error for DOI {doi}: {e}")
    return None

# Function to get abstract from Semantic Scholar
def get_abstract_from_semantic_scholar(title):
    """Fetch abstract from Semantic Scholar API using paper title"""
    try:
        url = "https://api.semanticscholar.org/graph/v1/paper/search"
        params = {
            'query': title,
            'limit': 1,
            'fields': 'abstract,title'
        }
        headers = {'User-Agent': 'Mozilla/5.0 (Educational Research)'}

        response = requests.get(url, params=params, headers=headers, timeout=10)

        if response.status_code == 200:
            data = response.json()
            if data.get('data') and len(data['data']) > 0:
                paper = data['data'][0]
                abstract = paper.get('abstract', '')
                if abstract and len(abstract) > 100:
                    return abstract.strip()
    except Exception as e:
        print(f"  Semantic Scholar error: {e}")
    return None

# Function to scrape abstract from paper URL
def scrape_abstract_from_url(url):
    """Attempt to scrape abstract directly from paper URL"""
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        response = requests.get(url, headers=headers, timeout=15)

        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')

            # Try common abstract selectors
            abstract_selectors = [
                {'name': 'meta', 'attrs': {'name': 'citation_abstract'}},
                {'name': 'meta', 'attrs': {'name': 'description'}},
                {'name': 'meta', 'attrs': {'property': 'og:description'}},
                {'name': 'meta', 'attrs': {'name': 'DC.Description'}},
                {'name': 'div', 'attrs': {'class': re.compile(r'abstract', re.I)}},
                {'name': 'section', 'attrs': {'class': re.compile(r'abstract', re.I)}},
                {'name': 'div', 'attrs': {'id': re.compile(r'abstract', re.I)}},
                {'name': 'section', 'attrs': {'id': re.compile(r'abstract', re.I)}},
            ]

            for selector in abstract_selectors:
                element = soup.find(**selector)
                if element:
                    if element.name == 'meta':
                        abstract = element.get('content', '')
                    else:
                        abstract = element.get_text(strip=True)
                        # Remove common abstract headers
                        abstract = re.sub(r'^abstract:?\s*', '', abstract, flags=re.IGNORECASE)

                    if abstract and len(abstract) > 100:
                        return abstract
    except Exception as e:
        print(f"  Scraping error: {e}")
    return None

# Function to get full abstract using multiple methods
def get_full_abstract(row):
    """Try multiple methods to get full abstract"""

    title = row['Title']
    url = row['DOI']
    current_abstract = row['Abstract']

    print(f"\nProcessing: {title[:60]}...")
    print(f"  Current abstract length: {len(str(current_abstract))} chars")

    # If current abstract is already long, keep it
    if len(str(current_abstract)) > 200:
        print(f"  ✓ Already has a good abstract, skipping")
        return current_abstract, "Original (sufficient)"

    # Method 1: Try DOI via CrossRef
    doi = extract_doi(url)
    if doi:
        print(f"  Trying CrossRef with DOI: {doi}")
        abstract = get_abstract_from_crossref(doi)
        if abstract and len(abstract) > len(str(current_abstract)):
            print(f"  ✓ Found via CrossRef ({len(abstract)} chars)")
            return abstract, "CrossRef"
        time.sleep(0.5)

    # Method 2: Try Semantic Scholar
    print(f"  Trying Semantic Scholar...")
    abstract = get_abstract_from_semantic_scholar(title)
    if abstract and len(abstract) > len(str(current_abstract)):
        print(f"  ✓ Found via Semantic Scholar ({len(abstract)} chars)")
        return abstract, "Semantic Scholar"
    time.sleep(0.5)

    # Method 3: Try scraping the URL
    if url and url != 'No link available':
        print(f"  Trying to scrape URL...")
        abstract = scrape_abstract_from_url(url)
        if abstract and len(abstract) > len(str(current_abstract)):
            print(f"  ✓ Found by scraping ({len(abstract)} chars)")
            return abstract, "Scraped from URL"
        time.sleep(1)

    # Fallback to original
    print(f"  ⚠ Keeping original abstract")
    return current_abstract, "Original (no better found)"

# Main processing function
def enrich_abstracts():
    print("="*70)
    print("ABSTRACT ENRICHMENT TOOL")
    print("="*70)

    # Read the Excel file
    print(f"\nReading Excel file: {input_file}")
    df = pd.read_excel(input_file)
    print(f"Found {len(df)} articles")

    # Check required columns
    required_columns = ['Title', 'Abstract', 'DOI']
    missing_columns = [col for col in required_columns if col not in df.columns]
    if missing_columns:
        print(f"Error: Missing columns: {missing_columns}")
        print(f"Available columns: {list(df.columns)}")
        return

    # Add new columns for enriched data
    df['Full_Abstract'] = ''
    df['Abstract_Source'] = ''

    # Process each row
    total = len(df)
    for idx, row in df.iterrows():
        print(f"\n[{idx+1}/{total}]", end=" ")
        try:
            full_abstract, source = get_full_abstract(row)
            df.at[idx, 'Full_Abstract'] = full_abstract
            df.at[idx, 'Abstract_Source'] = source
        except Exception as e:
            print(f"  ✗ Error: {e}")
            df.at[idx, 'Full_Abstract'] = row['Abstract']
            df.at[idx, 'Abstract_Source'] = "Error"

    # Save the enriched data to Excel
    df.to_excel(output_file, index=False)

    # Print statistics
    print("\n" + "="*70)
    print("ENRICHMENT STATISTICS")
    print("="*70)
    print("\nAbstract Sources:")
    print(df['Abstract_Source'].value_counts())

    print("\nAbstract Length Statistics:")
    print(f"Original average: {df['Abstract'].str.len().mean():.0f} characters")
    print(f"Enriched average: {df['Full_Abstract'].str.len().mean():.0f} characters")

    # Count improvements
    df['improved'] = df['Full_Abstract'].str.len() > df['Abstract'].str.len()
    improved_count = df['improved'].sum()
    print(f"\nImproved abstracts: {improved_count} out of {total} ({improved_count/total*100:.1f}%)")

    print(f"\n✓ Enriched data saved to: {output_file}")
    print("="*70)

# Run the enrichment
if __name__ == "__main__":
    try:
        enrich_abstracts()
    except FileNotFoundError:
        print(f"Error: Could not find input file: {input_file}")
        print("Please update the 'input_file' path in the script.")
    except Exception as e:
        print(f"Error: {e}")
        import traceback
        traceback.print_exc()
# Out:
# ======================================================================
# ABSTRACT ENRICHMENT TOOL
# ======================================================================
#
# Reading Excel file: Full_Abstract_scraping_for_google.xlsx
# Found 510 articles
#
# [1/510]
# Processing: Towards LLM-augmented multiagent systems for agile software ...
#   Current abstract length: 180 chars
#   Trying CrossRef with DOI: 10.1145/3691620.3695336
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [2/510]
# Processing: Keynote on Augmented Agile: Human-centred AI-assisted Softwa...
#   Current abstract length: 190 chars
#   Trying CrossRef with DOI: 10.1145/3643665.3648567
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1011 chars)
#
# [3/510]
# Processing: Future trends in IT project management–large organizations p...
#   Current abstract length: 180 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1370 chars)
#
# [4/510]
# Processing: Enhancing software effort estimation through reinforcement l...
#   Current abstract length: 177 chars
#   Trying CrossRef with DOI: 10.1108/ijmpb-03-2024-0065/full/html
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1068 chars)
#
# [5/510]
# Processing: Agents assisted software project management...
#   Current abstract length: 181 chars
#   Trying CrossRef with DOI: 10.1145/1341771.1341777
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [6/510]
# Processing: Software project management tools in global software develop...
#   Current abstract length: 179 chars
#   Trying CrossRef with DOI: 10.1186/s40064-016-3670-7
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1278 chars)
#
# [7/510]
# Processing: A software agent framework for the support of software proje...
#   Current abstract length: 183 chars
#   Trying CrossRef with DOI: 10.5555/954014.954017
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [8/510]
# Processing: Implementing microlearning and gamification techniques in te...
#   Current abstract length: 176 chars
#   Trying CrossRef with DOI: 10.1145/3548660.3561335
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [9/510]
# Processing: Nevena Rankovic Dragica Ranković Mirjana Ivanovic...
#   Current abstract length: 192 chars
#   Trying CrossRef with DOI: 10.1007/978-3-031-76572-8.pdf
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [10/510]
# Processing: A performance measurement view of IT project management...
#   Current abstract length: 183 chars
#   Trying CrossRef with DOI: 10.1108/17410401111101476/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [11/510]
# Processing: Microlearning strategy in the promotion of motivation and le...
#   Current abstract length: 184 chars
#   Trying CrossRef with DOI: 10.1002/cae.22717
#   ✓ Found via CrossRef (1534 chars)
#
# [12/510]
# Processing: Changes in IT Project Management Awareness According to Busi...
#   Current abstract length: 177 chars
#   Trying CrossRef with DOI: 10.2478/jec-2024-0018
#   ✓ Found via CrossRef (2749 chars)
#
# [13/510]
# Processing: IT project management resources and capabilities: a Delphi s...
#   Current abstract length: 188 chars
#   Trying CrossRef with DOI: 10.1108/17538371211214914/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [14/510]
# Processing: A 20‐year mapping of Bayesian belief networks in software pr...
#   Current abstract length: 180 chars
#   Trying CrossRef with DOI: 10.1049/sfw2.12043
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [15/510]
# Processing: Software Project Management for Distributed Computing...
#   Current abstract length: 178 chars
#   Trying CrossRef with DOI: 10.1007/978-3-319-54325-3.pdf
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (2066 chars)
#
# [16/510]
# Processing: Role of machine learning in software project management...
#   Current abstract length: 182 chars
#   Trying CrossRef with DOI: 10.1088/1742-6596/2040/1/012038/meta
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [17/510]
# Processing: IT Project Management 4.0: Trends and Future Directions...
#   Current abstract length: 183 chars
#   Trying CrossRef with DOI: 10.1142/9789811240584_0017
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [18/510]
# Processing: Dynamic staffing and rescheduling in software project manage...
#   Current abstract length: 183 chars
#   Trying CrossRef with DOI: 10.1371/journal.pone.0157104
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (985 chars)
#
# [19/510]
# Processing: Designing game scenarios for software project management edu...
#   Current abstract length: 180 chars
#   Trying CrossRef with DOI: 10.1049/iet-sen.2018.5081
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1277 chars)
#
# [20/510]
# Processing: Multiobjective simulation optimisation in software project m...
#   Current abstract length: 185 chars
#   Trying CrossRef with DOI: 10.1145/2001576.2001829
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [21/510]
# Processing: Software engineering: Management, personnel and methodology...
#   Current abstract length: 186 chars
#   Trying CrossRef with DOI: 10.5555/800091.802960
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [22/510]
# Processing: Moderating effect of Nigerian government policy support on t...
#   Current abstract length: 177 chars
#   Trying CrossRef with DOI: 10.1108/IJBPA-01-2023-0007/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [23/510]
# Processing: Development of a project management framework for the digita...
#   Current abstract length: 176 chars
#   Trying CrossRef with DOI: 10.4102/sajim.v26i1.1839
#   ✓ Found via CrossRef (1804 chars)
#
# [24/510]
# Processing: Using semantic documentation to support software project man...
#   Current abstract length: 182 chars
#   Trying CrossRef with DOI: 10.1007/s13740-018-0089-z
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [25/510]
# Processing: IT project management in the future...
#   Current abstract length: 184 chars
#   Trying CrossRef with DOI: 10.1142/9789811240584_0016
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1271 chars)
#
# [26/510]
# Processing: Object database support for a software project management en...
#   Current abstract length: 180 chars
#   Trying CrossRef with DOI: 10.1145/64135.64141
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [27/510]
# Processing: A data mining application: Analysis of problems occurring du...
#   Current abstract length: 181 chars
#   Trying CrossRef with DOI: 10.1142/S0218194005002476
#   ✓ Found via CrossRef (776 chars)
#
# [28/510]
# Processing: Knowledge management based on formal models of software proj...
#   Current abstract length: 165 chars
#   Trying CrossRef with DOI: 10.1080/01969720701346538
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [29/510]
# Processing: Key Artefacts in the Initial Phases of IT Project Management...
#   Current abstract length: 186 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [30/510]
# Processing: Quantitative software project management with mixed data: A ...
#   Current abstract length: 177 chars
#   Trying CrossRef with DOI: 10.1002/smr.2348
#   ✓ Found via CrossRef (1247 chars)
#
# [31/510]
# Processing: Proposition of the project management framework through inte...
#   Current abstract length: 184 chars
#   Trying CrossRef with DOI: 10.1504/IJPD.2009.024183
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [32/510]
# Processing: Innovative governance strategy to enhance the performance an...
#   Current abstract length: 191 chars
#   Trying CrossRef with DOI: 10.1504/IJPOM.2022.124128
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [33/510]
# Processing: Automation in Software Project Management...
#   Current abstract length: 175 chars
#   Trying CrossRef with DOI: 10.1108/978-1-80455-143-120231009/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [34/510]
# Processing: Leadership, sourcing modes and IT project management...
#   Current abstract length: 182 chars
#   Trying CrossRef with DOI: 10.1002/cjas.161
#   ✓ Found via CrossRef (914 chars)
#
# [35/510]
# Processing: Assessing SADC e-government maturity through the lens of its...
#   Current abstract length: 193 chars
#   Trying CrossRef with DOI: 10.1504/EG.2023.131726
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [36/510]
# Processing: Software Project Management Effectiveness Evaluation Tool...
#   Current abstract length: 187 chars
#   Trying CrossRef with DOI: 10.1145/3436829.3436844
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [37/510]
# Processing: Incorporating PMBOK2004 guidelines into the software project...
#   Current abstract length: 179 chars
#   Trying CrossRef with DOI: 10.1504/IJKL.2009.031508
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [38/510]
# Processing: Enabling open software project management data with antipatt...
#   Current abstract length: 182 chars
#   Trying CrossRef with DOI: 10.1145/2818187.2818286
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [39/510]
# Processing: A report on the second international workshop on software en...
#   Current abstract length: 187 chars
#   Trying CrossRef with DOI: 10.1145/3452383.3453718
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [40/510]
# Processing: IT project management capabilities enhancement impacts of co...
#   Current abstract length: 183 chars
#   Trying CrossRef with DOI: 10.1108/IJMPB-08-2013-0035/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [41/510]
# Processing: IT Project Management...
#   Current abstract length: 193 chars
#   Trying CrossRef with DOI: 10.1002/9781118785317.weom070032
#   ✓ Found via CrossRef (972 chars)
#
# [42/510]
# Processing: Applications of AI in classical software engineering...
#   Current abstract length: 179 chars
#   Trying CrossRef with DOI: 10.1186/s42467-020-00005-4
#   ✓ Found via CrossRef (1302 chars)
#
# [43/510]
# Processing: José Raúl Romero Inmaculada Medina-Bulo Francisco Chicano Ed...
#   Current abstract length: 186 chars
#   Trying CrossRef with DOI: 10.1007/978-981-19-9948-2.pdf
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [44/510]
# Processing: Leveraging ChatGPT for enhanced logical analysis in the theo...
#   Current abstract length: 187 chars
#   Trying CrossRef with DOI: 10.2478/orga-2024-0014
#   ✓ Found via CrossRef (1873 chars)
#
# [45/510]
# Processing: Mapping the Nursing Process to a Human Performance Technolog...
#   Current abstract length: 183 chars
#   Trying CrossRef with DOI: 10.1002/pfi.21783
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [46/510]
# Processing: Using GQIM Model and Gompertz Model to Measure, Analyze, and...
#   Current abstract length: 187 chars
#   Trying CrossRef with DOI: 10.1155/2023/2032876
#   ✓ Found via CrossRef (1257 chars)
#
# [47/510]
# Processing: Soft modeling support for managing knowledge-based informati...
#   Current abstract length: 193 chars
#   Trying CrossRef with DOI: 10.1080/01969720290040669
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [48/510]
# Processing: Project management for Modern Information systems...
#   Current abstract length: 185 chars
#   Trying CrossRef with DOI: 10.1108/02640470710754922/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [49/510]
# Processing: Artificial intelligence and project management: Empirical ov...
#   Current abstract length: 188 chars
#   Trying CrossRef with DOI: 10.1177/87569728231225198
#   ✓ Found via CrossRef (353 chars)
#
# [50/510]
# Processing: Green building project management: obstacles and solutions f...
#   Current abstract length: 186 chars
#   Trying CrossRef with DOI: 10.1002/sd.492
#   ✓ Found via CrossRef (1290 chars)
#
# [51/510]
# Processing: A model for estimating efforts required to make changes in a...
#   Current abstract length: 187 chars
#   Trying CrossRef with DOI: 10.1145/2007052.2007088
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [52/510]
# Processing: Evaluation of an artificial intelligence project in the soft...
#   Current abstract length: 186 chars
#   Trying CrossRef with DOI: 10.1108/JEIM-02-2022-0056
#   ✓ Found via CrossRef (1641 chars)
#
# [53/510]
# Processing: A Data‐Driven Artificial Neural Network Approach to Software...
#   Current abstract length: 191 chars
#   Trying CrossRef with DOI: 10.1049/2023/4324783
#   ✓ Found via CrossRef (1540 chars)
#
# [54/510]
# Processing: Project control and computational intelligence: trends and c...
#   Current abstract length: 192 chars
#   Trying CrossRef with DOI: 10.2991/ijcis.2017.10.1.22
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [55/510]
# Processing: Research on secure stereoscopic self-checking scheme for ope...
#   Current abstract length: 177 chars
#   Trying CrossRef with DOI: 10.1145/3349341.3349395
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [56/510]
# Processing: An architecture as a code framework to manage documentation ...
#   Current abstract length: 176 chars
#   Trying CrossRef with DOI: 10.1108/aci-12-2020-0159/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [57/510]
# Processing: Evolutionary neural network classifiers for software effort ...
#   Current abstract length: 184 chars
#   Trying CrossRef with DOI: 10.1504/IJCAET.2020.107445
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (943 chars)
#
# [58/510]
# Processing: Software for IT project quality management...
#   Current abstract length: 200 chars
#   Trying CrossRef with DOI: 10.1142/9789811240584_0015
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [59/510]
# Processing: RETRACTED ARTICLE: Project engineering management evaluation...
#   Current abstract length: 192 chars
#   Trying CrossRef with DOI: 10.1007/s00500-023-08133-9
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [60/510]
# Processing: When huskies bite back: A complex systems metaphor perspecti...
#   Current abstract length: 185 chars
#   Trying CrossRef with DOI: 10.1002/sres.2972
#   ✓ Found via CrossRef (938 chars)
#
# [61/510]
# Processing: A Study on the Effectiveness of Agile Methodology Using a Da...
#   Current abstract length: 174 chars
#   Trying CrossRef with DOI: 10.2478/aei-2023-0001.pdf
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [62/510]
# Processing: Research on blended learning mode based on network...
#   Current abstract length: 180 chars
#   Trying CrossRef with DOI: 10.1145/3447490.3447498
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [63/510]
# Processing: Requirement phase effort estimation using software metrics...
#   Current abstract length: 189 chars
#   Trying CrossRef with DOI: 10.1145/1741906.1742244
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [64/510]
# Processing: Beyond implementation: Driving CRM solution success in the e...
#   Current abstract length: 179 chars
#   Trying CrossRef with DOI: 10.1177/20438869251360807
#   ✓ Found via CrossRef (1094 chars)
#
# [65/510]
# Processing: Project scheduling conflict identification and resolution us...
#   Current abstract length: 188 chars
#   Trying CrossRef with DOI: 10.1007/s11235-011-9426-3
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [66/510]
# Processing: Evolutionary trends in decision sciences education research ...
#   Current abstract length: 183 chars
#   Trying CrossRef with DOI: 10.1089/big.2024.0128
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [67/510]
# Processing: SEffEst: Effort estimation in software projects using fuzzy ...
#   Current abstract length: 189 chars
#   Trying CrossRef with DOI: 10.1080/18756891.2012.718118
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [68/510]
# Processing: The importance of management practices in IS project perform...
#   Current abstract length: 191 chars
#   Trying CrossRef with DOI: 10.1108/17410390510579936/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [69/510]
# Processing: Mobile web accessibility readiness of government websites us...
#   Current abstract length: 187 chars
#   Trying CrossRef with DOI: 10.1504/EG.2017.083941
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [70/510]
# Processing: Comparison of regression model, feed-forward neural network ...
#   Current abstract length: 178 chars
#   Trying CrossRef with DOI: 10.1145/2020976.2020982
#   ✓ Found via CrossRef (980 chars)
#
# [71/510]
# Processing: Modernising pathology services: modelling effective IT proje...
#   Current abstract length: 184 chars
#   Trying CrossRef with DOI: 10.1108/IJPSM-11-2011-0129/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [72/510]
# Processing: Uncertainties evaluation and analysis using quantitative tec...
#   Current abstract length: 194 chars
#   Trying CrossRef with DOI: 10.1504/IJAHUC.2021.119088
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [73/510]
# Processing: Information technology project management within public sect...
#   Current abstract length: 188 chars
#   Trying CrossRef with DOI: 10.1108/17410391011083047/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [74/510]
# Processing: The evolution of military operations: artificial intelligenc...
#   Current abstract length: 193 chars
#   Trying CrossRef with DOI: 10.1504/IJCISTUDIES.2022.126906
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [75/510]
# Processing: Lessons learned from modeling the dynamics of software devel...
#   Current abstract length: 185 chars
#   Trying CrossRef with DOI: 10.1145/76380.76383
#   ✓ Found via CrossRef (274 chars)
#
# [76/510]
# Processing: Software cost estimation by fuzzy analogy for ISBSG reposito...
#   Current abstract length: 192 chars
#   Trying CrossRef with DOI: 10.1142/8564
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [77/510]
# Processing: Improving analogy software effort estimation using fuzzy fea...
#   Current abstract length: 196 chars
#   Trying CrossRef with DOI: 10.1145/1370788.1370805
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [78/510]
# Processing: The art of managing software development people...
#   Current abstract length: 166 chars
#   Trying CrossRef with DOI: 10.5555/3920
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [79/510]
# Processing: Success and failure retrospectives of FinTech projects: A ca...
#   Current abstract length: 178 chars
#   Trying CrossRef with DOI: 10.1007/s10796-020-10079-4
#   ✓ Found via CrossRef (992 chars)
#
# [80/510]
# Processing: … of internet finance industry with the core of e-commerce p...
#   Current abstract length: 192 chars
#   Trying CrossRef with DOI: 10.1504/IJAHUC.2022.121651
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [81/510]
# Processing: Understanding runaway information technology projects: Resul...
#   Current abstract length: 183 chars
#   Trying CrossRef with DOI: 10.1080/07421222.1994.11518050
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [82/510]
# Processing: Quality and reliability through common business environment...
#   Current abstract length: 169 chars
#   Trying CrossRef with DOI: 10.1108/09544789510098560/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [83/510]
# Processing: Public sector information system critical success factors...
#   Current abstract length: 181 chars
#   Trying CrossRef with DOI: 10.1108/17506160810862955/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [84/510]
# Processing: Adoption and implementation of BIM–case study of a Saudi Ara...
#   Current abstract length: 185 chars
#   Trying CrossRef with DOI: 10.1108/IJMPB-05-2017-0046/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [85/510]
# Processing: Asset life cycle management: towards improving physical asse...
#   Current abstract length: 185 chars
#   Trying CrossRef with DOI: 10.1108/01443570510599728/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [86/510]
# Processing: Global project management: communication, collaboration and ...
#   Current abstract length: 184 chars
#   Trying CrossRef with DOI: 10.1108/17538370910930590/full/html
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [87/510]
# Processing: Futuristic Dentistry: Intelligence Augmentation rather than ...
#   Current abstract length: 176 chars
#   Trying CrossRef with DOI: 10.5005/jp-journals-10063-0142
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [88/510]
# Processing: George Mason University...
#   Current abstract length: 171 chars
#   Trying CrossRef with DOI: 10.1007/978-3-642-77393-8_11.pdf
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [89/510]
# Processing: Introduction to the Methods Employed...
#   Current abstract length: 181 chars
#   Trying CrossRef with DOI: 10.1002/9781118574829.ch2
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [90/510]
# Processing: Scalability and ai: An insight on software project managemen...
#   Current abstract length: 186 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (927 chars)
#
# [91/510]
# Processing: Agile Project Management Using Large Language Models...
#   Current abstract length: 173 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1304 chars)
#
# [92/510]
# Processing: AI in software engineering: a survey on project management a...
#   Current abstract length: 185 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (844 chars)
#
# [93/510]
# Processing: The Role of Artificial Intelligence In Project Management Fo...
#   Current abstract length: 178 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [94/510]
# Processing: The future of IT Project Management & Delivery: NLP AI oppor...
#   Current abstract length: 184 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [95/510]
# Processing: DEVELOPMENT OF INFORMATION TECHNOLOGY FOR INTELLIGENT PLANNI...
#   Current abstract length: 198 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (2077 chars)
#
# [96/510]
# Processing: Agile software development project management and integratio...
#   Current abstract length: 192 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [97/510]
# Processing: LEVERAGING ARTIFICIAL INTELLIGENCE TO OPTIMIZE SOFTWARE PROJ...
#   Current abstract length: 193 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1108 chars)
#
# [98/510]
# Processing: The role of generative AI in IT project management...
#   Current abstract length: 187 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (4564 chars)
#
# [99/510]
# Processing: Business process reengineering: a scope of automation in sof...
#   Current abstract length: 185 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (245 chars)
#
# [100/510]
# Processing: Creative AI in software project management...
#   Current abstract length: 194 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1631 chars)
#
# [101/510]
# Processing: Leveraging large language models for predicting cost and dur...
#   Current abstract length: 194 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1289 chars)
#
# [102/510]
# Processing: Application of Artificial Intelligence in Project Management...
#   Current abstract length: 184 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [103/510]
# Processing: Revolutionizing Software Engineering with Generative AI and ...
#   Current abstract length: 177 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [104/510]
# Processing: The Impact of Artificial Intelligence on IT Project Manageme...
#   Current abstract length: 189 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [105/510]
# Processing: AI-driven Project Management in Software Engineering...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1769 chars)
#
# [106/510]
# Processing: AI Driven Strategies for Efficient Project Tracking and Deli...
#   Current abstract length: 195 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1498 chars)
#
# [107/510]
# Processing: A Framework for Leveraging Artificial Intelligence in Projec...
#   Current abstract length: 183 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [108/510]
# Processing: Optimised Intelligent Software Company Management System usi...
#   Current abstract length: 173 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [109/510]
# Processing: Present role of artificial intelligence in software project ...
#   Current abstract length: 184 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [110/510]
# Processing: Automated user story generation with test case specification...
#   Current abstract length: 186 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1206 chars)
#
# [111/510]
# Processing: The impact of artificial intelligence on project management ...
#   Current abstract length: 186 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [112/510]
# Processing: Artificial intelligence implementation in agile project mana...
#   Current abstract length: 187 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (824 chars)
#
# [113/510]
# Processing: Artificial intelligence and agile project management...
#   Current abstract length: 178 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [114/510]
# Processing: The use of AI in software engineering: A synthetic knowledge...
#   Current abstract length: 190 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1412 chars)
#
# [115/510]
# Processing: Addressing Agile Software Project Pain Points with Generativ...
#   Current abstract length: 177 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [116/510]
# Processing: Artificial Intelligence Project Management Methodologies: In...
#   Current abstract length: 3 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1818 chars)
#
# [117/510]
# Processing: The Transformative Role of Artificial Intelligence in Projec...
#   Current abstract length: 187 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [118/510]
# Processing: The nature and practices of the use of Machine Learning and ...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1325 chars)
#
# [119/510]
# Processing: Strategic project management development under influence of ...
#   Current abstract length: 192 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (2058 chars)
#
# [120/510]
# Processing: Applying Artificial Intelligence on Project Management Offic...
#   Current abstract length: 171 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [121/510]
# Processing: A novel framework for evaluating the software project manage...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [122/510]
# Processing: Putting intellectual robots to work: Implementing generative...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [123/510]
# Processing: Evaluating success factors of software project management in...
#   Current abstract length: 187 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1655 chars)
#
# [124/510]
# Processing: Artificial intelligence and its impacts on project managemen...
#   Current abstract length: 179 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1249 chars)
#
# [125/510]
# Processing: Impacto de la Inteligencia Artificial en la Gestión de Proye...
#   Current abstract length: 195 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [126/510]
# Processing: Organising Projects for Responsible Use of Generative Artifi...
#   Current abstract length: 194 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [127/510]
# Processing: AI-augmented agile project management in engineering: A fram...
#   Current abstract length: 196 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (950 chars)
#
# [128/510]
# Processing: Application of Natural Language Processing Techniques in Agi...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1446 chars)
#
# [129/510]
# Processing: CONSTRUCTION OF MODELS AND APPLICATION OF SYNCRETIC INNOVATI...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1974 chars)
#
# [130/510]
# Processing: Will Artificial Intelligence Replace Project Managers? A Cas...
#   Current abstract length: 194 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [131/510]
# Processing: Artificial Intelligence in Project Management: Project Manag...
#   Current abstract length: 189 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [132/510]
# Processing: Agile & AI in IT Project Management-How AI Can Drive IT Proj...
#   Current abstract length: 201 chars
#   ✓ Already has a good abstract, skipping
#
# [133/510]
# Processing: Using agents for distributed software project management...
#   Current abstract length: 185 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (693 chars)
#
# [134/510]
# Processing: Explainable artificial intelligence (XAI) in project managem...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (2064 chars)
#
# [135/510]
# Processing: … for Project Management of Developing a Safety-Oriented Log...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [136/510]
# Processing: AI-Driven Sustainable Project Management Framework...
#   Current abstract length: 183 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [137/510]
# Processing: A formal model for software project management...
#   Current abstract length: 183 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [138/510]
# Processing: Advancements in Artificial Intelligence for Automated Softwa...
#   Current abstract length: 186 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1062 chars)
#
# [139/510]
# Processing: Software Project Management vs INGO Project Management Tools...
#   Current abstract length: 175 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [140/510]
# Processing: Optimizing IT Governance and Project Management in Software ...
#   Current abstract length: 180 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1282 chars)
#
# [141/510]
# Processing: Examine the Potential of Artificial Intelligence in Enhancin...
#   Current abstract length: 183 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [142/510]
# Processing: Enhancing team diversity with generative ai: A novel project...
#   Current abstract length: 178 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1068 chars)
#
# [143/510]
# Processing: Using GenAI in IT project management: case studies, insights...
#   Current abstract length: 190 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [144/510]
# Processing: Towards a dynamic ontology based software project management...
#   Current abstract length: 179 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1052 chars)
#
# [145/510]
# Processing: Research on IT Engineering Project Resource Management Syste...
#   Current abstract length: 186 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1125 chars)
#
# [146/510]
# Processing: Project Management Revolution: How Startups Integrate Artifi...
#   Current abstract length: 184 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [147/510]
# Processing: A conceptual framework for applying artificial intelligence ...
#   Current abstract length: 192 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (975 chars)
#
# [148/510]
# Processing: AI driven strategic decision-making in IT project management...
#   Current abstract length: 187 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (2088 chars)
#
# [149/510]
# Processing: Importance of artificial intelligence in technology project ...
#   Current abstract length: 185 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1743 chars)
#
# [150/510]
# Processing: Learning Software Project Management From Analyzing Q&A's in...
#   Current abstract length: 175 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1324 chars)
#
# [151/510]
# Processing: Enhancing Risk Identification in Software Project Management...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [152/510]
# Processing: Artificial Intelligence in Cloud Security: Project Managemen...
#   Current abstract length: 198 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [153/510]
# Processing: ADAPTING SOFTWARE PROJECT MANAGEMENT FOR SUSTAINABILITY, ENV...
#   Current abstract length: 193 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [154/510]
# Processing: Ethical and Legal Considerations of AI in IT Project Managem...
#   Current abstract length: 190 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1234 chars)
#
# [155/510]
# Processing: OPTIMIZING RESOURCE ALLOCATION AND SCHEDULING STRATEGIES IN ...
#   Current abstract length: 183 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (2126 chars)
#
# [156/510]
# Processing: AI-Driven Project Management Systems: Enhancing IT Project E...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1274 chars)
#
# [157/510]
# Processing: Navigating the Future of IT Project Management: From Global ...
#   Current abstract length: 187 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1047 chars)
#
# [158/510]
# Processing: The impact of artificial intelligence on project management:...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [159/510]
# Processing: Market Trends in 2024 in the IT Project Management Industry...
#   Current abstract length: 193 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [160/510]
# Processing: An LLM-based multi-agent framework for agile effort estimati...
#   Current abstract length: 183 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1186 chars)
#
# [161/510]
# Processing: On Characteristics and Process Requirements of Artificial In...
#   Current abstract length: 184 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (908 chars)
#
# [162/510]
# Processing: GenAI-Enabled Backlog Grooming in Agile Software Projects: A...
#   Current abstract length: 178 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1009 chars)
#
# [163/510]
# Processing: Exploring the Landscape of Multicriteria Decision Making in ...
#   Current abstract length: 177 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [164/510]
# Processing: Symbio Coding: An Educational Testbed for AI Agent Simulatio...
#   Current abstract length: 180 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (861 chars)
#
# [165/510]
# Processing: Big Data Control and Optimization of Project Management...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (804 chars)
#
# [166/510]
# Processing: Effective Approaches and Challenges in Software Project Mana...
#   Current abstract length: 186 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (780 chars)
#
# [167/510]
# Processing: Get real get better: A framework for developing agile progra...
#   Current abstract length: 194 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (787 chars)
#
# [168/510]
# Processing: A proposal for research on the application of AI/ML in ITPM:...
#   Current abstract length: 189 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [169/510]
# Processing: AI-Driven Cybersecurity in IT Project Management: Enhancing ...
#   Current abstract length: 197 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1830 chars)
#
# [170/510]
# Processing: The Future of Project Management: Embracing artificial intel...
#   Current abstract length: 177 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [171/510]
# Processing: Revolutionizing Project Management with Artificial Intellige...
#   Current abstract length: 201 chars
#   ✓ Already has a good abstract, skipping
#
# [172/510]
# Processing: Fostering Agile IT Project Management and Interpersonal Skil...
#   Current abstract length: 183 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1245 chars)
#
# [173/510]
# Processing: An Empirical Study of Artificial Intelligence Support in Sof...
#   Current abstract length: 184 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [174/510]
# Processing: The influence of agile methodology (Scrum) on software proje...
#   Current abstract length: 183 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (754 chars)
#
# [175/510]
# Processing: Using AI to develop a framework to prevent employees from mi...
#   Current abstract length: 192 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [176/510]
# Processing: Augmented agile: Human-centered ai-assisted software managem...
#   Current abstract length: 190 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (624 chars)
#
# [177/510]
# Processing: Impact of artificial intelligence (AI) on information techno...
#   Current abstract length: 191 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [178/510]
# Processing: A Business Process Model for Augmented Artificial Intelligen...
#   Current abstract length: 166 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [179/510]
# Processing: Project Management Framework for Digitalization of Logistics...
#   Current abstract length: 195 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1243 chars)
#
# [180/510]
# Processing: Big data and cloud computing in IT project management: A fra...
#   Current abstract length: 184 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [181/510]
# Processing: Exploration of artificial intelligence utilization potential...
#   Current abstract length: 190 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (615 chars)
#
# [182/510]
# Processing: An experience-based approach to software project management...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1146 chars)
#
# [183/510]
# Processing: The last state of artificial intelligence in project managem...
#   Current abstract length: 194 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1146 chars)
#
# [184/510]
# Processing: Pulling the plug: Software project management and the proble...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [185/510]
# Processing: Trends in IT project management: Agile methodologies and the...
#   Current abstract length: 185 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [186/510]
# Processing: Predictive Analytics for Software Project Management...
#   Current abstract length: 178 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [187/510]
# Processing: Intelligent Resource Forecasting in Strategic IT Project Man...
#   Current abstract length: 184 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (679 chars)
#
# [188/510]
# Processing: Study of the principle of augmented competency in the audit ...
#   Current abstract length: 194 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (2113 chars)
#
# [189/510]
# Processing: AI-Integrated Cyber Security Risk Management Framework for I...
#   Current abstract length: 181 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (824 chars)
#
# [190/510]
# Processing: Optimizing IT Project Management in Ukraine's Aviation Secto...
#   Current abstract length: 191 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [191/510]
# Processing: Integrating Information Security Management System from ISO/...
#   Current abstract length: 175 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1254 chars)
#
# [192/510]
# Processing: Robotic process automation for software project management...
#   Current abstract length: 180 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1055 chars)
#
# [193/510]
# Processing: A knowledge based approach to assist in telecommunications s...
#   Current abstract length: 187 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (770 chars)
#
# [194/510]
# Processing: MODERN TECHNOLOGIES IN IT PROJECT MANAGEMENT...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (2052 chars)
#
# [195/510]
# Processing: Data-driven decision making for sustainable IT project manag...
#   Current abstract length: 181 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [196/510]
# Processing: Conceptual model-based reasoning for knowledge-based softwar...
#   Current abstract length: 179 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (709 chars)
#
# [197/510]
# Processing: A distributed software project management framework...
#   Current abstract length: 181 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [198/510]
# Processing: Problems and features of IT-project management in modern con...
#   Current abstract length: 186 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (441 chars)
#
# [199/510]
# Processing: Teaching Software Project Management: The collaborative vers...
#   Current abstract length: 184 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [200/510]
# Processing: Setting the Stage...
#   Current abstract length: 195 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [201/510]
# Processing: Agentic ai software engineer: Programming with trust...
#   Current abstract length: 184 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (748 chars)
#
# [202/510]
# Processing: AI-Driven Budget Estimation in End-User Software Engineering...
#   Current abstract length: 195 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [203/510]
# Processing: Perspectives on the adherance to scrum rules in software pro...
#   Current abstract length: 192 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (248 chars)
#
# [204/510]
# Processing: Modern convergent challenges in IT project management for CR...
#   Current abstract length: 181 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [205/510]
# Processing: Estimation issues in software project management...
# ...
#
# [447/510]
# Processing: Perspectives on a Cybersecurity Governance Framework Integra...
#   Current abstract length: 178 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1260 chars)
#
# [448/510]
# Processing: Predicting the Early Stage Software Development Effort using...
#   Current abstract length: 191 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [449/510]
# Processing: … of digitization of infrastructure projects and programs. P...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [450/510]
# Processing: Business viability of potential software projects using arti...
#   Current abstract length: 198 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (250 chars)
#
# [451/510]
# Processing: Development of Simple Effort Estimation Model based on Fuzzy...
#   Current abstract length: 185 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (247 chars)
#
# [452/510]
# Processing: Implementation Framework for a Maritime Transport Navigation...
#   Current abstract length: 177 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [453/510]
# Processing: LOCAL SENTIMENTS, GLOBAL IMPACT: THE CASE OF TIMISOARA AS TH...
#   Current abstract length: 180 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [454/510]
# Processing: A novel case base reasoning and frequent pattern based decis...
#   Current abstract length: 183 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   Scraping error: HTTPSConnectionPool(host='www.karlancer.com', port=443): Max retries exceeded with url: /api/file/1616065000.pdf (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7bc7f6ae7740>, 'Connection to www.karlancer.com timed out. (connect timeout=15)'))
#   ⚠ Keeping original abstract
#
# [455/510]
# Processing: A Preliminary Performance Eualuation Of Machinelearing Algor...
#   Current abstract length: 185 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (249 chars)
#
# [456/510]
# Processing: Improving the Accuracy of COCOMO II in Software Projects Usi...
#   Current abstract length: 191 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   Scraping error: HTTPSConnectionPool(host='e-jurnal.pnl.ac.id', port=443): Max retries exceeded with url: /JAISE/article/view/7603 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1010)')))
#   ⚠ Keeping original abstract
#
# [457/510]
# Processing: Communication and leadership skills in the Computer Science ...
#   Current abstract length: 180 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (911 chars)
#
# [458/510]
# Processing: An adaptive-network-based fuzzy inference system for project...
#   Current abstract length: 177 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   Scraping error: HTTPConnectionPool(host='www.scielo.org.co', port=80): Max retries exceeded with url: /scielo.php?pid=S0123-21262015000200004&script=sci_arttext (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7bc7f70cf170>: Failed to resolve 'www.scielo.org.co' ([Errno -3] Temporary failure in name resolution)"))
#   ⚠ Keeping original abstract
#
# [459/510]
# Processing: Evaluation of quantitative and mining techniques for reducin...
#   Current abstract length: 175 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [460/510]
# Processing: Quality of project management education and training program...
#   Current abstract length: 181 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [461/510]
# Processing: Innovation Practice and Ability Cultivation of Software Engi...
#   Current abstract length: 185 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (788 chars)
#
# [462/510]
# Processing: A novel game theoretic algorithm for project selection under...
#   Current abstract length: 191 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1122 chars)
#
# [463/510]
# Processing: Theorizing IT project success: Direct and indirect effects i...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1357 chars)
#
# [464/510]
# Processing: Artificial Intelligence: an astrodynamicits's perspective...
#   Current abstract length: 183 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [465/510]
# Processing: Conceptualising management of artificial intelligence in ter...
#   Current abstract length: 171 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (878 chars)
#
# [466/510]
# Processing: Mining software repositories to acquire software risk knowle...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (886 chars)
#
# [467/510]
# Processing: Differentiated Management of IT Service Workers: Applying Se...
#   Current abstract length: 181 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (774 chars)
#
# [468/510]
# Processing: Comparing different estimation methods for software effort...
#   Current abstract length: 191 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1489 chars)
#
# [469/510]
# Processing: Estimators characteristics and effort estimation of software...
#   Current abstract length: 183 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1347 chars)
#
# [470/510]
# Processing: Campus IoT collaboration and governance using the NIST cyber...
#   Current abstract length: 177 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1084 chars)
#
# [471/510]
# Processing: Software supply chain security of power industry based on BA...
#   Current abstract length: 175 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (990 chars)
#
# [472/510]
# Processing: Cyberbullying detection on social media...
#   Current abstract length: 186 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1531 chars)
#
# [473/510]
# Processing: Assessment of time reduction when using a modified task-trac...
#   Current abstract length: 176 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [474/510]
# Processing: Researching Etiquette Figures of Hercule Poirot's Character ...
#   Current abstract length: 196 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [475/510]
# Processing: New direction of nuclear code development: artificial intell...
#   Current abstract length: 186 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [476/510]
# Processing: Positive psychology in information technology project manage...
#   Current abstract length: 190 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [477/510]
# Processing: Rightsizing project management for libraries...
#   Current abstract length: 175 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (677 chars)
#
# [478/510]
# Processing: Application of Improved CNN Technology in Medical Imaging Co...
#   Current abstract length: 186 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1193 chars)
#
# [479/510]
# Processing: ARTIFICIAL INTELLIGENCE IN DERMATOLOGY: CURRENT APPLICATIONS...
#   Current abstract length: 194 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [480/510]
# Processing: Development of the Effort Estimation Model Using Fuzzy Decis...
#   Current abstract length: 189 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [481/510]
# Processing: Data Center and IT Equipment Installation in an Old Building...
#   Current abstract length: 195 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1147 chars)
#
# [482/510]
# Processing: O-plan: the open planning architecture...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [483/510]
# Processing: Business intelligence adoption for small and medium enterpri...
#   Current abstract length: 180 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [484/510]
# Processing: Steps in the Ontological Modelling of the Software Verificat...
#   Current abstract length: 190 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [485/510]
# Processing: An Iterative Pixel-Based Dimensional Voting Model for High S...
#   Current abstract length: 192 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1564 chars)
#
# [486/510]
# Processing: Integrating uncertainty in software effort estimation using ...
#   Current abstract length: 195 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [487/510]
# Processing: POSSIBILITIES OF APPLICATION OF ARTIFICIAL INTELLIGENCE IN B...
#   Current abstract length: 192 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [488/510]
# Processing: e-Waste Management Awareness Program in Solomon Island: A Pr...
#   Current abstract length: 179 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [489/510]
# Processing: Lean IT with value stream mapping analysis: A case study in ...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1084 chars)
#
# [490/510]
# Processing: Research on software quality assurance based on software qua...
#   Current abstract length: 189 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (482 chars)
#
# [491/510]
# Processing: Efficient software test management system based on microserv...
#   Current abstract length: 181 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (606 chars)
#
# [492/510]
# Processing: Replacing project managers in information technology project...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [493/510]
# Processing: Infrastructure elements for smart campuses: A bibliometric a...
#   Current abstract length: 194 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [494/510]
# Processing: The impact of group cohesiveness on decision-making outcomes...
#   Current abstract length: 184 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (1057 chars)
#
# [495/510]
# Processing: Ενίσχυση του ΙΤ Project management με την ενσωμάτωση λύσεων ...
#   Current abstract length: 178 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   Scraping error: HTTPSConnectionPool(host='hephaestus.nup.ac.cy', port=443): Read timed out. (read timeout=15)
#   ⚠ Keeping original abstract
#
# [496/510]
# Processing: BUSINESS PROCESS SYSTEM...
#   Current abstract length: 191 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1255 chars)
#
# [497/510]
# Processing: Using Intelligent Agents in Military Simulation or" Using Ag...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [498/510]
# Processing: Search UTHealth Houston...
#   Current abstract length: 185 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (632 chars)
#
# [499/510]
# Processing: Integrated clinician decision supporting system for pneumoni...
#   Current abstract length: 191 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1190 chars)
#
# [500/510]
# Processing: Privacy Concerns and Data Donations: Do Societal Benefits Ma...
#   Current abstract length: 175 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [501/510]
# Processing: THE SCOPE OPTIMIZATION OF SOFTWARE PROJECTS USING MODERN SOF...
#   Current abstract length: 174 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [502/510]
# Processing: Measuring the productivity of computer systems development a...
#   Current abstract length: 192 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (449 chars)
#
# [503/510]
# Processing: Large-Scale Agile Frameworks: Agile Frameworks, Agile Infras...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [504/510]
# Processing: Software risk management...
#   Current abstract length: 171 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [505/510]
# Processing: Risk Management Models of a Project for the Implementation o...
#   Current abstract length: 175 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [506/510]
# Processing: Beyond the Plan: The Psychology of Project Management...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   ✓ Found via Semantic Scholar (1538 chars)
#
# [507/510]
# Processing: PENINGKATAN KOMPETENSI TEKNIK JARINGAN KOMPUTER DAN TELEKOMU...
#   Current abstract length: 193 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [508/510]
# Processing: The Evolution of Project Management: Embracing AI, Sustainab...
#   Current abstract length: 189 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ⚠ Keeping original abstract
#
# [509/510]
# Processing: INFORMATION TECHNOLOGIES AND MANAGEMENT...
#   Current abstract length: 188 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#   ⚠ Keeping original abstract
#
# [510/510]
# Processing: Software Selection by Using the Takagi-Sugeno Algorithm on t...
#   Current abstract length: 182 chars
#   Trying Semantic Scholar...
#   Trying to scrape URL...
#   ✓ Found by scraping (763 chars)
#
# ======================================================================
# ENRICHMENT STATISTICS
# ======================================================================
#
# Abstract Sources:
# Abstract_Source
# Original (no better found)    268
# Scraped from URL              166
# Semantic Scholar               54
# CrossRef                       19
# Original (sufficient)           3
# Name: count, dtype: int64
#
# Abstract Length Statistics:
# Original average: 184 characters
# Enriched average: 636 characters
#
# Improved abstracts: 238 out of 510 (46.7%)
#
# ✓ Enriched data saved to: Full_Abstracts.xlsx
# ======================================================================

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# # **Data concatenation code from SPARK Table 5**

# %% [markdown]
# code to convert wos.xls to wos.csv

# %%
import pandas as pd

# Input XLS file path
xls_file = "wos.xls"

# Output CSV file path
csv_file = "wos.csv"

# Read the XLS file (first sheet by default)
df = pd.read_excel(xls_file)

# Save as CSV (without index column)
df.to_csv(csv_file, index=False, encoding='utf-8')

print(f"Converted {xls_file} to {csv_file}")
# Out:
# Converted wos.xls to wos.csv

# %% [markdown]
# code to count total meta-data values.

# %%
# !rm *.csv

# %%
import os
import pandas as pd

directory = r"/content"

def combine_csv_files(directory):
    all_dataframes = []
    total_expected = 0

    # Check each file individually with detailed info
    for filename in os.listdir(directory):
        if filename.endswith('.csv'):
            file_path = os.path.join(directory, filename)
            print(f"\n--- Processing {filename} ---")

            # Read and analyze each file
            df = pd.read_csv(file_path)
            print(f"Shape: {df.shape}")
            print(f"Columns: {list(df.columns)}")
            print(f"Non-null rows: {df.dropna(how='all').shape[0]}")
            print(f"Duplicates within file: {df.duplicated().sum()}")

            total_expected += len(df)
            all_dataframes.append(df)

    print(f"\n=== SUMMARY ===")
    print(f"Total expected: {total_expected}")
    print(f"Files processed: {len(all_dataframes)}")

    # Combine without any modifications
    combined_df = pd.concat(all_dataframes, ignore_index=True)
    print(f"Actual combined: {len(combined_df)}")
    print(f"Difference: {len(combined_df) - total_expected}")

combine_csv_files(directory)
# Out:
# --- Processing scopus_SPARK.csv ---
# Shape: (4083, 5)
# Columns: ['title', 'authors', 'doi', 'year', 'abstract']
# Non-null rows: 4083
# Duplicates within file: 0
#
# --- Processing ACM_SPARK.csv ---
# Shape: (7272, 5)
# Columns: ['title', 'authors', 'doi', 'year', 'abstract']
# Non-null rows: 7272
# Duplicates within file: 0
#
# --- Processing dblp-spark.csv ---
# Shape: (711, 5)
# Columns: ['title', 'authors', 'doi', 'year', 'abstract']
# Non-null rows: 711
# Duplicates within file: 0
#
# --- Processing google-spark.csv ---
# Shape: (789, 5)
# Columns: ['title', 'authors', 'doi', 'year', 'abstract']
# Non-null rows: 789
# Duplicates within file: 12
#
# --- Processing science_direct-spark.csv ---
# Shape: (50, 5)
# Columns: ['title', 'authors', 'doi', 'year', 'abstract']
# Non-null rows: 50
# Duplicates within file: 0
#
# --- Processing IEEE_SPARK.csv ---
# Shape: (4536, 5)
# Columns: ['title', 'authors', 'doi', 'year', 'abstract']
# Non-null rows: 4536
# Duplicates within file: 0
#
# --- Processing springer-spark.csv ---
# Shape: (546, 5)
# Columns: ['title', 'authors', 'doi', 'year', 'abstract']
# Non-null rows: 546
# Duplicates within file: 0
#
# --- Processing wos_SPARK.csv ---
# Shape: (2095, 5)
# Columns: ['title', 'authors', 'doi', 'year', 'abstract']
# Non-null rows: 2095
# Duplicates within file: 0
#
# === SUMMARY ===
# Total expected: 20082
# Files processed: 8
# Actual combined: 20082
# Difference: 0

# %% [markdown]
# run code below for table 5

# %%
import os
import pandas as pd

# Specify the directory where the CSV files are stored
directory = r"/content"

# Function to combine all CSV files in the specified directory
def combine_csv_files(directory):
    # Create a list to hold dataframes
    all_dataframes = []

    # Loop through all files in the directory
    for filename in os.listdir(directory):
        if filename.endswith('.csv'):  # Check if the file is a CSV
            file_path = os.path.join(directory, filename)  # Full path to the file
            df = pd.read_csv(file_path)  # Read the CSV file into a dataframe
            all_dataframes.append(df)  # Add the dataframe to the list

    # Concatenate all dataframes into one, assuming they all have the same columns
    combined_df = pd.concat(all_dataframes, ignore_index=True)
    # combined_df = pd.concat(all_dataframes, ignore_index=True, sort=False)

    # Save the combined dataframe to a new CSV file
    combined_df.to_csv(os.path.join(directory, 'Combined_Results.csv'), index=False)

    print(f"Combined results saved to {os.path.join(directory, 'Combined_Results.csv')}")

# Run the function to combine the CSV files
combine_csv_files(directory)
# Out:
# Combined results saved to /content/Combined_Results.csv

# %% [markdown]
# # **SPARK deduplication from Table 6**

# %% [markdown]
# Deduplication is based on:
# 1. DOI matching
# 2. Fuzzy Matching of Titles and Authors

# %%
# !pip install fuzzywuzzy
# !pip install python-Levenshtein
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Collecting python-Levenshtein
#   Downloading python_levenshtein-0.27.1-py3-none-any.whl.metadata (3.7 kB)
# Collecting Levenshtein==0.27.1 (from python-Levenshtein)
#   Downloading levenshtein-0.27.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.1->python-Levenshtein)
#   Downloading rapidfuzz-3.14.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading python_levenshtein-0.27.1-py3-none-any.whl (9.4 kB)
# Downloading levenshtein-0.27.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 4.0 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 45.4 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.27.1 python-Levenshtein-0.27.1 rapidfuzz-3.14.1

# %%
import pandas as pd
import os
import re
from fuzzywuzzy import fuzz

# Define paths
output_dir = r"/content"
screening_dir = os.path.join(output_dir, "Duplicates_Removed")
os.makedirs(screening_dir, exist_ok=True)
combined_path = os.path.join(output_dir, "Combined_Results.csv")
duplicates_removed_path = os.path.join(screening_dir, "Duplicates_Removed.csv")
no_duplicates_path = os.path.join(screening_dir, "No_Duplicates.csv")

# Load data
try:
    df_combined = pd.read_csv(combined_path)
    print(f"Loaded {len(df_combined)} articles.")
except FileNotFoundError as e:
    print(f"Error loading file: {e}")
    exit()

# Preprocess and normalize data
def preprocess_text(text):
    return re.sub(r'[^a-zA-Z0-9\s]', '', str(text)).lower().strip()

df_combined['Normalized Title'] = df_combined['title'].apply(preprocess_text)
df_combined['Normalized Authors'] = df_combined['authors'].apply(lambda x: ''.join(sorted(re.sub(r'[^A-Za-z\s]', '', str(x)).lower().split(' '))))

# Fuzzy matching and debugging
def is_duplicate(row, existing):
    for exist in existing:
        if row['doi'] == exist['doi']:
            return True, "DOI Match"

    for exist in existing:
        if fuzz.ratio(row['Normalized Title'], exist['Normalized Title']) > 90 and row['year'] == exist['year']:
            return True, "Fuzzy Title Match"

    return False, ""

unique_articles = []
duplicates = []
duplicates_info = []

for _, row in df_combined.iterrows():
    is_dup, method = is_duplicate(row, unique_articles)
    if not is_dup:
        unique_articles.append(row)
    else:
        duplicates.append(row)
        duplicates_info.append({"row": row.to_dict(), "Identification Method": method}) # Corrected syntax

        print(f"Duplicate found: {row['title']} with method: {method}")

# Save results and print counts
pd.DataFrame(unique_articles).to_csv(no_duplicates_path, index=False)
pd.DataFrame(duplicates_info).to_csv(duplicates_removed_path, index=False)

print("Files saved: No duplicates and duplicates files.")
print(f"{len(duplicates)} duplicates were identified and removed.")
# Out:
# Loaded 20082 articles.
# Duplicate found: Leveraging Machine Learning for Enhanced Bug Triaging in Open-Source Software Projects with method: Fuzzy Title Match
# Duplicate found: Bibliographic review of AI applied to project management and its analysis in the context of the metalworking industry with method: DOI Match
# Duplicate found: POLARIS: A framework to guide the development of Trustworthy AI systems with method: Fuzzy Title Match
# Duplicate found: CodeFuse-13B: A Pretrained Multi-Lingual Code Large Language Model with method: DOI Match
# Duplicate found: Lessons from Building StackSpot Al: A Contextualized AI Coding Assistant with method: DOI Match
# Duplicate found: Resolving Code Review Comments with Machine Learning with method: DOI Match
# Duplicate found: An Industry Case Study on Adoption of AI-based Programming Assistants with method: DOI Match
# Duplicate found: Application of machine learning on software quality assurance and testing: A chronological survey with method: Fuzzy Title Match
# Duplicate found: From user stories to models: A machine learning empowered automation with method: Fuzzy Title Match
# Duplicate found: Towards better technical debt detection with NLP and machine learning methods with method: DOI Match
# Duplicate found: Automatically predicting bug severity early in the development process with method: DOI Match
# Duplicate found: Specmate: Automated Creation of Test Cases from Acceptance Criteria with method: Fuzzy Title Match
# Duplicate found: Scenario-based generation of ontologies for domain-specific languages with method: Fuzzy Title Match
# Duplicate found: Discovering program Topoi through clustering with method: Fuzzy Title Match
# Duplicate found: Effort estimation in agile software development: An updated review with method: Fuzzy Title Match
# Duplicate found: Neural Network-based Detection of Self-Admitted Technical Debt: From Performance to Explainability with method: DOI Match
# Duplicate found: A Defect Estimator for Source Code: Linking Defect Reports with Programming Constructs Usage Metrics with method: DOI Match
# Duplicate found: In-IDE Code Generation from Natural Language: Promise and Challenges with method: DOI Match
# Duplicate found: Assessing the Fairness of AI Systems: AI Practitioners' Processes, Challenges, and Needs for Support with method: DOI Match
# Duplicate found: OnSRAM: Efficient Inter-Node On-Chip Scratchpad Management in Deep Learning Accelerators with method: DOI Match
# Duplicate found: GA-SCS: Graph-Augmented Source Code Summarization with method: DOI Match
# Duplicate found: Automated Identification of Toxic Code Reviews Using ToxiCR with method: DOI Match
# Duplicate found: Rise of Distributed Deep Learning Training in the Big Model Era: From a Software Engineering Perspective with method: DOI Match
# Duplicate found: CodeEditor: Learning to Edit Source Code with Pre-trained Models with method: DOI Match
# Duplicate found: Augmenting Human Teams with Robots in Knowledge Work Settings: Insights from the Literature with method: DOI Match
# Duplicate found: Automatically Inspecting Thousands of Static Bug Warnings with Large Language Model: How Far Are We? with method: DOI Match
# Duplicate found: Significant Productivity Gains through Programming with Large Language Models with method: DOI Match
# Duplicate found: Self-Collaboration Code Generation via ChatGPT with method: DOI Match
# Duplicate found: Automated Commit Intelligence by Pre-training with method: DOI Match
# Duplicate found: A Disruptive Research Playbook for Studying Disruptive Innovations with method: DOI Match
# Duplicate found: CARL: Unsupervised Code-Based Adversarial Attacks for Programming Language Models via Reinforcement Learning with method: DOI Match
# Duplicate found: Revisiting Sentiment Analysis for Software Engineering in the Era of Large Language Models with method: DOI Match
# Duplicate found: Exploring Automated Assertion Generation via Large Language Models with method: DOI Match
# Duplicate found: Trained without My Consent: Detecting Code Inclusion in Language Models Trained on Code with method: DOI Match
# Duplicate found: Empowering Agile-Based Generative Software Development through Human-AI Teamwork with method: DOI Match
# Duplicate found: A Catalog of Data Smells for Coding Tasks with method: DOI Match
# Duplicate found: The Impact of Generative AI on Creativity in Software Development: A Research Agenda with method: DOI Match
# Duplicate found: Requirements Are All You Need: The Final Frontier for End-User Software Engineering with method: DOI Match
# Duplicate found: Open Source AI-based SE Tools: Opportunities and Challenges of Collaborative Software Learning with method: DOI Match
# Duplicate found: From Today’s Code to Tomorrow’s Symphony: The AI Transformation of Developer’s Routine by 2030 with method: DOI Match
# Duplicate found: A Roadmap for Software Testing in Open-Collaborative and AI-Powered Era with method: DOI Match
# Duplicate found: Software Fairness Debt: Building a Research Agenda for Addressing Bias in AI Systems with method: DOI Match
# Duplicate found: 'Always Nice and Confident, Sometimes Wrong': Developer's Experiences Engaging Generative AI Chatbots Versus Human-Powered Q&amp;A Platforms with method: DOI Match
# Duplicate found: Characterising Open Source Co-opetition in Company-hosted Open Source Software Projects: The Cases of PyTorch, TensorFlow, and Transformers with method: DOI Match
# Duplicate found: Making Software Development More Diverse and Inclusive: Key Themes, Challenges, and Future Directions with method: DOI Match
# Duplicate found: LLM-Based Multi-Agent Systems for Software Engineering: Literature Review, Vision, and the Road Ahead with method: DOI Match
# Duplicate found: The Current Challenges of Software Engineering in the Era of Large Language Models with method: DOI Match
# Duplicate found: Innovating for Tomorrow: The Convergence of Software Engineering and Green AI with method: DOI Match
# Duplicate found: DDASR: Deep Diverse API Sequence Recommendation with method: DOI Match
# Duplicate found: The Future of AI-Driven Software Engineering with method: DOI Match
# Duplicate found: Software Engineering by and for Humans in an AI Era with method: DOI Match
# Duplicate found: Artificial Intelligence for Software Engineering: The Journey So Far and the Road Ahead with method: DOI Match
# Duplicate found: LEGO: Synthesizing IoT Device Components Based on Static Analysis and Large Language Models with method: DOI Match
# Duplicate found: Novice Perceptions on Effective Elements of PostgreSQL Error Messages with method: DOI Match
# Duplicate found: A Survey on Large Language Models for Code Generation with method: Fuzzy Title Match
# Duplicate found: MTP: A Meaning-Typed Language Abstraction for AI-Integrated Programming with method: DOI Match
# Duplicate found: Understanding and Improving Flaky Test Classification with method: DOI Match
# Duplicate found: Code-first model-driven engineering: on the agile adoption of MDE tooling with method: DOI Match
# Duplicate found: Retrieve and refine: exemplar-based neural comment generation with method: Fuzzy Title Match
# Duplicate found: A prediction model for software requirements change impact with method: DOI Match
# Duplicate found: Leveraging code clones and natural language processing for log statement prediction with method: DOI Match
# Duplicate found: Learning domain-specific edit operations from model repositories with frequent subgraph mining with method: DOI Match
# Duplicate found: EditSum: a retrieve-and-edit framework for source code summarization with method: DOI Match
# Duplicate found: PyExplainer: explaining the predictions of just-in-time defect models with method: DOI Match
# Duplicate found: ISPY: automatic issue-solution pair extraction from community live chats with method: DOI Match
# Duplicate found: On Automated Assistants for Software Development: The Role of LLMs with method: DOI Match
# Duplicate found: A Comprehensive Study on Code Clones in Automated Driving Software with method: DOI Match
# Duplicate found: EALink: An Efficient and Accurate Pre-trained Framework for Issue-Commit Link Recovery with method: DOI Match
# Duplicate found: Gamma: Revisiting Template-based Automated Program Repair via Mask Prediction with method: DOI Match
# Duplicate found: From Commit Message Generation to History-Aware Commit Message Completion with method: DOI Match
# Duplicate found: CodeGen4Libs: A Two-Stage Approach for Library-Oriented Code Generation with method: DOI Match
# Duplicate found: Identify and Update Test Cases when Production Code Changes: A Transformer-Based Approach with method: DOI Match
# Duplicate found: Software Engineering Using Autonomous Agents: Are We There Yet? with method: DOI Match
# Duplicate found: CAT-LM Training Language Models on Aligned Code and Tests with method: DOI Match
# Duplicate found: ZC3: Zero-Shot Cross-Language Code Clone Detection with method: DOI Match
# Duplicate found: A Comparative Study of Transformer-Based Neural Text Representation Techniques on Bug Triaging with method: DOI Match
# Duplicate found: Current and future bots in software development with method: DOI Match
# Duplicate found: An additional set of (automated) eyes: chatbots for agile retrospectives with method: DOI Match
# Duplicate found: Building sankie: an AI platform for DevOps with method: DOI Match
# Duplicate found: Toward imitating visual attention of experts in software development tasks with method: DOI Match
# Duplicate found: SReYantra: automated software requirement inter-dependencies elicitation, analysis and learning with method: DOI Match
# Duplicate found: Distribution awareness for AI system testing with method: DOI Match
# Duplicate found: Designing Adaptive Developer-Chatbot Interactions: Context Integration, Experimental Studies, and Levels of Automation with method: DOI Match
# Duplicate found: Can We Knapsack Software Defect Prediction? Nokia 5G Case with method: DOI Match
# Duplicate found: GUIDE: LLM-Driven GUI Generation Decomposition for Automated Prototyping with method: DOI Match
# Duplicate found: The Software Librarian: Python Package Insights for Copilot with method: DOI Match
# Duplicate found: Advancing Secure and Standard Source Code Generation Techniques with method: DOI Match
# Duplicate found: Foundation Models for Automatic Issue Labeling with method: DOI Match
# Duplicate found: Rethinking Software Development Considering Collaboration with AI Assistants with method: DOI Match
# Duplicate found: Towards Quality Assurance of Natural Language in Code with method: DOI Match
# Duplicate found: Intelligent Automation for Accelerating the Repair of Software Build Failures with method: DOI Match
# Duplicate found: Trustworthiness of Large Language Models for Code with method: DOI Match
# Duplicate found: ClauseBench: Enhancing Software License Analysis with Clause-Level Benchmarking with method: DOI Match
# Duplicate found: Exploring Large Language Models for Analyzing Open Source License Conflicts: How Far Are We? with method: DOI Match
# Duplicate found: Towards effective AI-powered agile project management with method: DOI Match
# Duplicate found: Auto-Logging: Al-Centred Logging Instrumentation with method: DOI Match
# Duplicate found: Learning autocompletion from real-world datasets with method: DOI Match
# Duplicate found: Evolving software to be ML-driven utilizing real-world A/B testing: experiences, insights, challenges with method: DOI Match
# Duplicate found: Towards inclusive software engineering through A/B testing: a case-study at windows with method: DOI Match
# Duplicate found: Scaling Web API Integrations with method: DOI Match
# Duplicate found: Code Librarian: A Software Package Recommendation System with method: DOI Match
# Duplicate found: DocToModel: Automated Authoring of Models from Diverse Requirements Specification Documents with method: DOI Match
# Duplicate found: An Empirical Study of License Conflict in Free and Open Source Software with method: DOI Match
# Duplicate found: Along the Margins: Marginalized Communities' Ethical Concerns about Social Platforms with method: DOI Match
# Duplicate found: From Expectation to Habit: Why Do Software Practitioners Adopt Fairness Toolkits? with method: DOI Match
# Duplicate found: Curious, Critical Thinker, Empathetic, and Ethically Responsible: Essential Soft Skills for Data Scientists in Software Engineering with method: DOI Match
# Duplicate found: Supporting analysts by dynamic extraction and classification of requirements-related knowledge with method: DOI Match
# Duplicate found: CCTest: Testing and Repairing Code Completion Systems with method: DOI Match
# Duplicate found: DLInfer: Deep Learning with Static Slicing for Python Type Inference with method: DOI Match
# Duplicate found: LiCoEval: Evaluating LLMs on License Compliance in Code Generation with method: DOI Match
# Duplicate found: SpecRover: Code Intent Extraction via LLMs with method: DOI Match
# Duplicate found: Unseen Horizons: Unveiling the Real Capability of LLM Code Generation Beyond the Familiar with method: DOI Match
# Duplicate found: What Guides Our Choices? Modeling Developers' Trust and Behavioral Intentions Towards GenAI with method: DOI Match
# Duplicate found: Instruct or Interact? Exploring and Eliciting LLMs' Capability in Code Snippet Adaptation through Prompt Engineering with method: DOI Match
# Duplicate found: exLong: Generating Exceptional Behavior Tests with Large Language Models with method: Fuzzy Title Match
# Duplicate found: Intention is All You Need: Refining Your Code from Your Intention with method: DOI Match
# Duplicate found: Trust Dynamics in AI-Assisted Development: Definitions, Factors, and Implications with method: DOI Match
# Duplicate found: Are LLMs Correctly Integrated into Software Systems? with method: DOI Match
# Duplicate found: HumanEvo: An Evolution-Aware Benchmark for More Realistic Evaluation of Repository-Level Code Generation with method: DOI Match
# Duplicate found: How Scientists Use Jupyter Notebooks: Goals, Quality Attributes, and Opportunities with method: DOI Match
# Duplicate found: Towards a knowledge warehouse and expert system for the automation of SDLC tasks with method: DOI Match
# Duplicate found: REDUCT: keep it close, keep it cool! efficient scaling of DNN inference on multi-core CPUs with near-cache compute with method: DOI Match
# Duplicate found: TCP: A Tensor Contraction Processor for AI Workloads with method: DOI Match
# Duplicate found: Voice-driven modeling: software modeling using automated speech recognition with method: DOI Match
# Duplicate found: Teaching modelling literacy: an artificial intelligence approach with method: DOI Match
# Duplicate found: Semantic source code models using identifier embeddings with method: DOI Match
# Duplicate found: Can duplicate questions on stack overflow benefit the software development community? with method: DOI Match
# Duplicate found: What do developers know about machine learning: a study of ML discussions on StackOverflow with method: DOI Match
# Duplicate found: Predicting co-changes between functionality specifications and source code in behavior driven development with method: DOI Match
# Duplicate found: Automatic detection of latent software component relationships from online Q&amp;A sites with method: DOI Match
# Duplicate found: LLM4VV: Exploring LLM-as-a-Judge for Validation and Verification Testsuites with method: DOI Match
# Duplicate found: Empirically Analyzing and Evaluating Security Features in Software Requirements with method: DOI Match
# Duplicate found: Code review comments: language matters with method: DOI Match
# Duplicate found: Enabling real-time feedback in software engineering with method: DOI Match
# Duplicate found: Ambiguous software requirement specification detection: an automated approach with method: DOI Match
# Duplicate found: Deep code comment generation with method: DOI Match
# Duplicate found: Recognizing software bug-specific named entity in software bug repository with method: DOI Match
# Duplicate found: Toward refactoring evaluation with code naturalness with method: DOI Match
# Duplicate found: Translating code comments to procedure specifications with method: DOI Match
# Duplicate found: Characterizing the natural language descriptions in software logging statements with method: DOI Match
# Duplicate found: Detecting and summarizing GUI changes in evolving mobile apps with method: DOI Match
# Duplicate found: Tell them apart: distilling technology differences from crowd-scale comparison discussions with method: DOI Match
# Duplicate found: Searching StackOverflow Questions with Multi-Faceted Categorization with method: DOI Match
# Duplicate found: An Effective Approach for Routing the Bug Reports to the Right Fixers with method: DOI Match
# Duplicate found: Affective Dynamics and Control in Group Processes with method: DOI Match
# Duplicate found: A Method of Automatic Code Generation Based on AADL Model with method: DOI Match
# Duplicate found: Exploring Violations of Programming Styles: Insights from Open Source Projects with method: DOI Match
# Duplicate found: Natural Language Processing for Productivity Metrics for Software Development Profiling in Enterprise Applications with method: DOI Match
# Duplicate found: CoaCor: Code Annotation for Code Retrieval with Reinforcement Learning with method: DOI Match
# Duplicate found: Latent variable-based multiple instance learning towards label-free polarity detection with method: DOI Match
# Duplicate found: Retrieve and refine: exemplar-based neural comment generation with method: DOI Match
# Duplicate found: Patching as translation: the data and the metaphor with method: DOI Match
# Duplicate found: Multi-task learning based pre-trained language model for code completion with method: DOI Match
# Duplicate found: Deciphering and Analyzing Software Requirements employing the techniques of Natural Language Processing with method: DOI Match
# Duplicate found: A learning-based approach for automatic construction of domain glossary from source code and documentation with method: DOI Match
# Duplicate found: Advances in designing a student-centered learning process using cutting-edge methods, tools, and artificial intelligence: an e-learning platform with method: DOI Match
# Duplicate found: Classifying non-functional requirements using RNN variants for quality software development with method: DOI Match
# Duplicate found: Automatic detection of architectural bad smells through semantic representation of code with method: DOI Match
# Duplicate found: Research on Geometric Modeling Virtual Assembly Technology Based on Component-level Assembly Feature with method: DOI Match
# Duplicate found: Research on Secure Stereoscopic Self-Checking Scheme for Open Source Software with method: DOI Match
# Duplicate found: EmbSE: A Word Embeddings Model Oriented Towards Software Engineering Domain with method: DOI Match
# Duplicate found: Fairway: a way to build fair ML software with method: DOI Match
# Duplicate found: DENAS: automated rule generation by knowledge extraction from neural networks with method: DOI Match
# Duplicate found: IntelliCode compose: code generation using transformer with method: DOI Match
# Duplicate found: DiffTech: a tool for differencing similar technologies from question-and-answer discussions with method: DOI Match
# Duplicate found: Bug Report Summarization: A systematic Literature Review with method: DOI Match
# Duplicate found: Developing QR Payment to Enhance the Technological Service in Sederhana Restaurant Network with method: DOI Match
# Duplicate found: A Design and Implementation of Chinese University Virtual Entrepreneurship Education Platform System Based on B / S Structure with method: DOI Match
# Duplicate found: Big code != big vocabulary: open-vocabulary models for source code with method: DOI Match
# Duplicate found: Understanding the automated parameter optimization on transfer learning for cross-project defect prediction: an empirical study with method: DOI Match
# Duplicate found: An investigation of cross-project learning in online just-in-time software defect prediction with method: DOI Match
# Duplicate found: Towards better technical debt detection with NLP and machine learning methods with method: DOI Match
# Duplicate found: Generating Use Case Scenarios from User Stories with method: DOI Match
# Duplicate found: PUMiner: Mining Security Posts from Developer Question and Answer Websites with PU Learning with method: DOI Match
# Duplicate found: The State of the ML-universe: 10 Years of Artificial Intelligence &amp; Machine Learning Software Development on GitHub with method: DOI Match
# Duplicate found: A Multiple Case Study of Artificial Intelligent System Development in Industry with method: DOI Match
# Duplicate found: Automatic Identification of Decisions from the Hibernate Developer Mailing List with method: DOI Match
# Duplicate found: Mining Decision-Making Processes in Open Source Software Development: A Study of Python Enhancement Proposals (PEPs) using Email Repositories with method: DOI Match
# Duplicate found: Cross-Project Software Fault Prediction Using Data Leveraging Technique to Improve Software Quality with method: DOI Match
# Duplicate found: A Literature Review of Automatic Traceability Links Recovery for Software Change Impact Analysis with method: DOI Match
# Duplicate found: A Self-Attentional Neural Architecture for Code Completion with Multi-Task Learning with method: DOI Match
# Duplicate found: Automated Software Quality Monitoring in Research Collaboration Projects with method: DOI Match
# Duplicate found: Mining Hypernyms Semantic Relations from Stack Overflow with method: DOI Match
# Duplicate found: Achiever or explorer? gamifying the creation process of training data for machine learning with method: DOI Match
# Duplicate found: DoMoBOT: a bot for automated and interactive domain modelling with method: DOI Match
# Duplicate found: Business Process Modelling Augmented: Model Driven transformation of User Stories to Processes with method: DOI Match
# Duplicate found: Application in Computer Software Testing Based on Artificial Intelligence Technology with method: DOI Match
# Duplicate found: Research on Software Development Automation Based on Microservice Architecture with method: DOI Match
# Duplicate found: Towards Accountability for Machine Learning Datasets: Practices from Software Engineering and Infrastructure with method: DOI Match
# Duplicate found: Research on Software Resource Management Model Based on Cloud Service with method: DOI Match
# Duplicate found: Generating bug-fixes using pretrained transformers with method: DOI Match
# Duplicate found: Discovering the rationale of decisions: towards a method for aligning learning and reasoning with method: DOI Match
# Duplicate found: Automating the removal of obsolete TODO comments with method: DOI Match
# Duplicate found: The Mozart reuse exposed dataflow processor for AI and beyond: industrial product with method: DOI Match
# Duplicate found: A Mining Software Repository Extended Cookbook: Lessons learned from a literature review with method: DOI Match
# Duplicate found: Multi-stream online transfer learning for software effort estimation: is it necessary? with method: DOI Match
# Duplicate found: Career Counseling Chatbot on Facebook Messenger using AI with method: DOI Match
# Duplicate found: Combining object-oriented paradigm and controlled natural language for requirements specification with method: DOI Match
# Duplicate found: Is neural machine translation approach accurate enough for coding assistance? with method: DOI Match
# Duplicate found: HINT: Integration Testing for AI-based features with Humans in the Loop with method: DOI Match
# Duplicate found: Solving Separation-of-Concerns Problems in Collaborative Design of Human-AI Systems through Leaky Abstractions with method: DOI Match
# Duplicate found: Using NLP to Quantify Program Decomposition in CS1 with method: DOI Match
# Duplicate found: On the relation of variability modeling languages and non-functional properties with method: DOI Match
# Duplicate found: Retrieval and Evaluation of Target Component Based on Ontology Knowledge with method: DOI Match
# Duplicate found: BugListener: identifying and synthesizing bug reports from collaborative live chats with method: DOI Match
# Duplicate found: Diversity-driven automated formal verification with method: DOI Match
# Duplicate found: TOGA: a neural method for test oracle generation with method: DOI Match
# Duplicate found: Using deep learning to generate complete log statements with method: DOI Match
# Duplicate found: More effective test case generation with multiple tribes of AI with method: Fuzzy Title Match
# Duplicate found: An Automated Approach to Domain-specific Term Extraction for Programming Language with method: DOI Match
# Duplicate found: Design of Garbage Classification System Based on Artificial Intelligence Technology with method: DOI Match
# Duplicate found: Choose your programming copilot: a comparison of the program synthesis performance of github copilot and genetic programming with method: DOI Match
# Duplicate found: What is an AI engineer? an empirical analysis of job ads in The Netherlands with method: DOI Match
# Duplicate found: AI governance in the system development life cycle: insights on responsible machine learning engineering with method: DOI Match
# Duplicate found: LineVD: statement-level vulnerability detection using graph neural networks with method: DOI Match
# Duplicate found: MLOps: a guide to its adoption in the context of responsible AI with method: DOI Match
# Duplicate found: So who is impacted anyway: a preliminary study of indirect stakeholder identification in practice with method: DOI Match
# Duplicate found: How Do Software Companies Deal with Artificial Intelligence Ethics? A Gap Analysis with method: DOI Match
# Duplicate found: RGVisNet: A Hybrid Retrieval-Generation Neural Framework Towards Automatic Data Visualization Generation with method: DOI Match
# Duplicate found: Automating code review activities by large-scale pre-training with method: DOI Match
# Duplicate found: DeepDev-PERF: a deep learning-based approach for improving software performance with method: DOI Match
# Duplicate found: NeuDep: neural binary memory dependence analysis with method: DOI Match
# Duplicate found: Program merge conflict resolution via neural transformers with method: DOI Match
# Duplicate found: Exploring and evaluating personalized models for code generation with method: DOI Match
# Duplicate found: An empirical study of deep transfer learning-based program repair for Kotlin projects with method: DOI Match
# Duplicate found: Tracing and Visualizing Human-ML/AI Collaborative Processes through Artifacts of Data Work with method: DOI Match
# Duplicate found: Software Artifact Mining in Software Engineering Conferences: A Meta-Analysis with method: DOI Match
# Duplicate found: Heterogeneous Graph Neural Networks for Software Effort Estimation with method: DOI Match
# Duplicate found: Example Driven Code Review Explanation with method: DOI Match
# Duplicate found: Incorporating Pre-trained Transformer Models into TextCNN for Sentiment Analysis on Software Engineering Texts with method: DOI Match
# Duplicate found: Different Approaches of Evolutionary Algorithms to Multiple Objective RCPSP with method: DOI Match
# Duplicate found: Experiences from Using Code Explanations Generated by Large Language Models in a Web Software Development E-Book with method: DOI Match
# Duplicate found: Automatic Code Documentation Generation Using GPT-3 with method: DOI Match
# Duplicate found: Identification and Mitigation of Toxic Communications Among Open Source Software Developers with method: DOI Match
# Duplicate found: TransRepair: Context-aware Program Repair for Compilation Errors with method: DOI Match
# Duplicate found: Dancing, not Wrestling: Moving from Compliance to Concordance for Secure Software Development with method: DOI Match
# Duplicate found: Software Introspection for Signaling Social-Cyber Operations with method: DOI Match
# Duplicate found: Do Users Write More Insecure Code with AI Assistants? with method: DOI Match
# Duplicate found: Pin or Fuse? Exploiting Scratchpad Memory to Reduce Off-Chip Data Transfer in DNN Accelerators with method: DOI Match
# Duplicate found: The Programmer’s Assistant: Conversational Interaction with a Large Language Model for Software Development with method: DOI Match
# Duplicate found: Activation During Upper Limb Movements Measured with Functional Near-Infrared Spectroscopy in Healthy Elderly Subjects with method: DOI Match
# Duplicate found: SPM: Structured Pretraining and Matching Architectures for Relevance Modeling in Meituan Search with method: DOI Match
# Duplicate found: Teaching IT Software Fundamentals: Strategies and Techniques for Inclusion of Large Language Models: Strategies and Techniques for Inclusion of Large Language Models with method: DOI Match
# Duplicate found: Automatic Recognition System of Landscape Portrait Photography on Account of AI with method: DOI Match
# Duplicate found: Intelligent Agents for Crowdsourced Software Engineering : A Survey with method: DOI Match
# Duplicate found: A Rapid Review of Responsible AI frameworks: How to guide the development of ethical AI with method: DOI Match
# Duplicate found: A Mixed Reality Approach for Innovative Pair Programming Education with a Conversational AI Virtual Avatar with method: DOI Match
# Duplicate found: Five Futures with AI Coding Agents with method: DOI Match
# Duplicate found: Exploring the Potential of ChatGPT in Automated Code Refinement: An Empirical Study with method: DOI Match
# Duplicate found: UniLog: Automatic Logging via LLM and In-Context Learning with method: DOI Match
# Duplicate found: Toward Automatically Completing GitHub Workflows with method: DOI Match
# Duplicate found: Unveiling Memorization in Code Models with method: DOI Match
# Duplicate found: Breaking the Flow: A Study of Interruptions During Software Engineering Activities with method: DOI Match
# Duplicate found: BinaryAI: Binary Software Composition Analysis via Intelligent Binary Source Code Matching with method: DOI Match
# Duplicate found: Rust-lancet: Automated Ownership-Rule-Violation Fixing with Behavior Preservation with method: DOI Match
# Duplicate found: Fuzz4All: Universal Fuzzing with Large Language Models with method: DOI Match
# Duplicate found: Streamlining Java Programming: Uncovering Well-Formed Idioms with IdioMine with method: DOI Match
# Duplicate found: LLMParser: An Exploratory Study on Using Large Language Models for Log Parsing with method: DOI Match
# Duplicate found: Are Prompt Engineering and TODO Comments Friends or Foes? An Evaluation on GitHub Copilot with method: DOI Match
# Duplicate found: Demystifying and Detecting Misuses of Deep Learning APIs with method: DOI Match
# Duplicate found: Evaluating Large Language Models in Class-Level Code Generation with method: DOI Match
# Duplicate found: Uncovering the Causes of Emotions in Software Developer Communication Using Zero-shot LLMs with method: DOI Match
# Duplicate found: Broken Promises: Measuring Confounding Effects in Learning-based Vulnerability Discovery with method: DOI Match
# Duplicate found: PyBartRec: Python API Recommendation with Semantic Information with method: DOI Match
# Duplicate found: Seq2Seq or Seq2Tree: Generating Code Using Both Paradigms via Mutual Learning with method: DOI Match
# Duplicate found: InferFix: End-to-End Program Repair with LLMs with method: DOI Match
# Duplicate found: AdaptivePaste: Intelligent Copy-Paste in IDE with method: DOI Match
# Duplicate found: Towards Greener Yet Powerful Code Generation via Quantization: An Empirical Study with method: DOI Match
# Duplicate found: Self-Supervised Query Reformulation for Code Search with method: DOI Match
# Duplicate found: H3S: A Hospital Staff Sign-in System Based on Face Recognition with method: DOI Match
# Duplicate found: Recommendation of UML Model Conflicts: Unveiling the Biometric Lens for Conflict Resolution with method: DOI Match
# Duplicate found: Similar Bug Reports Recommendation System using BERT with method: DOI Match
# Duplicate found: Software Technology Project Defect Prediction Based on AI with method: DOI Match
# Duplicate found: Is ChatGPT Capable of Crafting Gamification Strategies for Software Engineering Tasks? with method: DOI Match
# Duplicate found: Toward Programming Languages for Reasoning: Humans, Symbolic Systems, and AI Agents with method: DOI Match
# Duplicate found: An initial investigation of ChatGPT unit test generation capability with method: DOI Match
# Duplicate found: Can Large Language Models Write Parallel Code? with method: DOI Match
# Duplicate found: CS1 with a Side of AI: Teaching Software Verification for Secure Code in the Era of Generative AI with method: DOI Match
# Duplicate found: Diverging assessments: What, Why, and Experiences with method: DOI Match
# Duplicate found: Exploring the Impact of Generative AI for StandUp Report Recommendations in Software Capstone Project Development with method: DOI Match
# Duplicate found: Unveiling Quality in Chatbot Conversations: Quantitative Analysis of Chatbot Requirements with method: DOI Match
# Duplicate found: A Case Study on Data Science Processes in an Academia-Industry Collaboration with method: DOI Match
# Duplicate found: Incorporating Generative AI into Software Development Education with method: DOI Match
# Duplicate found: An Investigation into Misuse of Java Security APIs by Large Language Models with method: DOI Match
# Duplicate found: Effectiveness of the Improvement Recommendations Model for Addressing the Syntactic Ambiguity in Malay Requirements Specifications with method: DOI Match
# Duplicate found: Bridging the Theory-Practice Gap in a Maintenance Programming Course: An Experience Report with method: DOI Match
# Duplicate found: Beyond Functional Correctness: An Exploratory Study on the Time Efficiency of Programming Assignments with method: DOI Match
# Duplicate found: Towards Trustworthy AI Software Development Assistance with method: DOI Match
# Duplicate found: CodeFuse-13B: A Pretrained Multi-lingual Code Large Language Model with method: DOI Match
# Duplicate found: Resolving Code Review Comments with Machine Learning with method: DOI Match
# Duplicate found: Lessons from Building StackSpot AI: A Contextualized AI Coding Assistant with method: DOI Match
# Duplicate found: An Industry Case Study on Adoption of AI-based Programming Assistants with method: DOI Match
# Duplicate found: MissConf: LLM-Enhanced Reproduction of Configuration-Triggered Bugs with method: DOI Match
# Duplicate found: Accelerating Software Development Using Generative AI: ChatGPT Case Study with method: DOI Match
# Duplicate found: Workshop Report on Emerging Software Engineering Education with method: DOI Match
# Duplicate found: Iterative Design of a Teaching Assistant Training Program in Computer Science Using the Agile Method with method: DOI Match
# Duplicate found: Unlocking Potential with Generative AI Instruction: Investigating Mid-level Software Development Student Perceptions, Behavior, and Adoption with method: DOI Match
# Duplicate found: Exploring potential implications of intelligent tools for human aspects of software engineering with method: DOI Match
# Duplicate found: The Environmental Cost of Engineering Machine Learning-Enabled Systems: A Mapping Study with method: DOI Match
# Duplicate found: Supermind Ideator: How Scaffolding Human-AI Collaboration Can Increase Creativity with method: Fuzzy Title Match
# Duplicate found: From Requirements to Architecture: An AI-Based Journey to Semi-Automatically Generate Software Architectures with method: DOI Match
# Duplicate found: Trust in Software Supply Chains: Blockchain-Enabled SBOM and the AIBOM Future with method: DOI Match
# Duplicate found: Researchers’ Concerns on Artificial Intelligence Ethics: Results from a Scenario-Based Survey with method: DOI Match
# Duplicate found: Code Ownership in Open-Source AI Software Security with method: DOI Match
# Duplicate found: Industrial Experience Report on AI-Assisted Coding in Professional Software Development with method: DOI Match
# Duplicate found: An Empirical Study on Usage and Perceptions of LLMs in a Software Engineering Project with method: DOI Match
# Duplicate found: Gauging Tech Community Acceptance of Rapid Prototyping in Unfamiliar Programming Languages using LLM Chatbots with method: DOI Match
# Duplicate found: Learn to Code Sustainably: An Empirical Study on Green Code Generation with method: DOI Match
# Duplicate found: Unit Test Generation using Generative AI : A Comparative Performance Analysis of Autogeneration Tools with method: DOI Match
# Duplicate found: A New Generation of Intelligent Development Environments with method: DOI Match
# Duplicate found: In-IDE Human-AI Experience in the Era of Large Language Models; A Literature Review with method: DOI Match
# Duplicate found: Compositional API Recommendation for Library-Oriented Code Generation with method: DOI Match
# Duplicate found: Understanding Regular Expression Denial of Service (ReDoS): Insights from LLM-Generated Regexes and Developer Forums with method: DOI Match
# Duplicate found: AthenaLLM: Supporting Experiments with Large Language Models in Software Development with method: DOI Match
# Duplicate found: MalwareBench: Malware samples are not enough with method: DOI Match
# Duplicate found: Leveraging GPT-like LLMs to Automate Issue Labeling with method: DOI Match
# Duplicate found: MicroRec: Leveraging Large Language Models for Microservice Recommendation with method: DOI Match
# Duplicate found: Unveiling ChatGPT's Usage in Open Source Projects: A Mining-based Study with method: DOI Match
# Duplicate found: ChatGPT Chats Decoded: Uncovering Prompt Patterns for Superior Solutions in Software Development Lifecycle with method: DOI Match
# Duplicate found: Write me this Code: An Analysis of ChatGPT Quality for Producing Source Code with method: DOI Match
# Duplicate found: Quality Assessment of ChatGPT Generated Code and their Use by Developers with method: DOI Match
# Duplicate found: How I Learned to Stop Worrying and Love ChatGPT with method: DOI Match
# Duplicate found: Can ChatGPT Support Developers? An Empirical Evaluation of Large Language Models for Code Generation with method: DOI Match
# Duplicate found: The role of library versions in Developer-ChatGPT conversations with method: DOI Match
# Duplicate found: ChatGPT in Action: Analyzing Its Use in Software Development with method: DOI Match
# Duplicate found: Chatting with AI: Deciphering Developer Conversations with ChatGPT with method: DOI Match
# Duplicate found: Analyzing Developer-ChatGPT Conversations for Software Refactoring: An Exploratory Study with method: DOI Match
# Duplicate found: Investigating the Utility of ChatGPT in the Issue Tracking System: An Exploratory Study with method: DOI Match
# Duplicate found: How Do Software Developers Use ChatGPT? An Exploratory Study on GitHub Pull Requests with method: DOI Match
# Duplicate found: Using GitHub Copilot for Test Generation in Python: An Empirical Study with method: DOI Match
# Duplicate found: Exploring the Role of Automation in Duplicate Bug Report Detection: An Industrial Case Study with method: DOI Match
# Duplicate found: POLARIS: A Framework to Guide the Development of Trustworthy AI Systems with method: DOI Match
# Duplicate found: Developer Experiences with a Contextualized AI Coding Assistant: Usability, Expectations, and Outcomes with method: DOI Match
# Duplicate found: Using SVM Classification and Reverse Engineering to Generate Trustworthy Code in Software Development with method: DOI Match
# Duplicate found: Designing a CURE for CS1 with method: DOI Match
# Duplicate found: Deep Multiple Assertions Generation with method: DOI Match
# Duplicate found: LCM: LLM-focused Hybrid SPM-cache Architecture with Cache Management for Multi-Core AI Accelerators with method: DOI Match
# Duplicate found: FastLog: An End-to-End Method to Efficiently Generate and Insert Logging Statements with method: DOI Match
# Duplicate found: CoderUJB: An Executable and Unified Java Benchmark for Practical Programming Scenarios with method: DOI Match
# Duplicate found: CoEdPilot: Recommending Code Edits with Learned Prior Edit Relevance, Project-wise Awareness, and Interactive Nature with method: DOI Match
# Duplicate found: Feedback-Driven Automated Whole Bug Report Reproduction for Android Apps with method: DOI Match
# Duplicate found: When to Stop? Towards Efficient Code Generation in LLMs with Excess Token Prevention with method: DOI Match
# Duplicate found: SelfPiCo: Self-Guided Partial Code Execution with LLMs with method: DOI Match
# Duplicate found: One Size Does Not Fit All: Multi-granularity Patch Generation for Better Automated Program Repair with method: DOI Match
# Duplicate found: AutoCodeRover: Autonomous Program Improvement with method: DOI Match
# Duplicate found: A Practical Failure Prediction Model based on Code Smells and Software Development Metrics with method: DOI Match
# Duplicate found: Exploring ChatGPT for identifying sexism in the communication of software developers with method: DOI Match
# Duplicate found: A Comparative Study of Large Language Models for Goal Model Extraction with method: DOI Match
# Duplicate found: Using LLMs for Use Case Modelling of IoT Systems: An Experience Report with method: DOI Match
# Duplicate found: Turning Low-Code Development Platforms into True No-Code with LLMs with method: DOI Match
# Duplicate found: Evaluating the Impact of Conventional Code Analysis Against Large Language Models in API Vulnerability Detection with method: DOI Match
# Duplicate found: Using AI Assistants in Software Development: A Qualitative Study on Security Practices and Concerns with method: DOI Match
# Duplicate found: PromSec: Prompt Optimization for Secure Generation of Functional Source Code with Large Language Models (LLMs) with method: DOI Match
# Duplicate found: Demystifying RCE Vulnerabilities in LLM-Integrated Apps with method: DOI Match
# Duplicate found: Making Federated Learning Accessible to Scientists: The AI4EOSC Approach with method: DOI Match
# Duplicate found: LLMs for Intelligent Software Testing: A Comparative Study with method: DOI Match
# Duplicate found: Target sequences model based on the results of the corelation of demographic variables with other variables: application of the sequential patternmining algorithm with method: DOI Match
# Duplicate found: Developers' Perspective on Today's and Tomorrow's Programming Tool Assistance: A Survey with method: DOI Match
# Duplicate found: LEGION: Harnessing Pre-trained Language Models for GitHub Topic Recommendations with Distribution-Balance Loss with method: DOI Match
# Duplicate found: LLM-Based Chatbots for Mining Software Repositories: Challenges and Opportunities with method: DOI Match
# Duplicate found: A Catalog of Transformations to Remove Smells From Natural Language Tests with method: DOI Match
# Duplicate found: An LLM-based Approach to Recover Traceability Links between Security Requirements and Goal Models with method: DOI Match
# Duplicate found: Research on Computer Intelligent ChatGPT Natural Language Processing System Based on Scientific Knowledge Graph with method: DOI Match
# Duplicate found: Testing Learning-Enabled Cyber-Physical Systems with Large-Language Models: A Formal Approach with method: DOI Match
# Duplicate found: Software Engineering and Gender: A Tutorial with method: DOI Match
# Duplicate found: Rethinking Software Engineering in the Era of Foundation Models: A Curated Catalogue of Challenges in the Development of Trustworthy FMware with method: DOI Match
# Duplicate found: X-Lifecycle Learning for Cloud Incident Management using LLMs with method: DOI Match
# Duplicate found: On the Effectiveness of Large Language Models for GitHub Workflows with method: DOI Match
# Duplicate found: Identifying the Factors That Influence Trust in AI Code Completion with method: DOI Match
# Duplicate found: Unveiling the Potential of a Conversational Agent in Developer Support: Insights from Mozilla’s PDF.js Project with method: DOI Match
# Duplicate found: From Human-to-Human to Human-to-Bot Conversations in Software Engineering with method: DOI Match
# Duplicate found: Measuring Impacts of Poisoning on Model Parameters and Embeddings for Large Language Models of Code with method: DOI Match
# Duplicate found: Chain of Targeted Verification Questions to Improve the Reliability of Code Generated by LLMs with method: DOI Match
# Duplicate found: The Role of Generative AI in Software Development Productivity: A Pilot Case Study with method: DOI Match
# Duplicate found: The Impact of AI-Pair Programmers on Code Quality and Developer Satisfaction: Evidence from TiMi studio with method: DOI Match
# Duplicate found: MatsVD: Boosting Statement-Level Vulnerability Detection via Dependency-Based Attention with method: DOI Match
# Duplicate found: My Code Is Less Secure with Gen AI: Surveying Developers' Perceptions of the Impact of Code Generation Tools on Security with method: DOI Match
# Duplicate found: A Transformer-based Approach for Augmenting Software Engineering Chatbots Datasets with method: DOI Match
# Duplicate found: Multi-language Software Development in the LLM Era: Insights from Practitioners’ Conversations with ChatGPT with method: DOI Match
# Duplicate found: Debugging with Open-Source Large Language Models: An Evaluation with method: DOI Match
# Duplicate found: From Literature to Practice: Exploring Fairness Testing Tools for the Software Industry Adoption with method: DOI Match
# Duplicate found: Customer Opinion Analysis and Topic Extraction Using Machine Learning with method: DOI Match
# Duplicate found: Research on the Application of Clustering Algorithm for Online Education Students Based on Artificial Intelligence with method: DOI Match
# Duplicate found: Use of ChatGPT as an Assistant in the End-to-End Test Script Generation for Android Apps with method: DOI Match
# Duplicate found: A Framework for Clone Detection in UML Models (UMCD) with method: DOI Match
# Duplicate found: Evaluation of Code LLMs on Geospatial Code Generation with method: DOI Match
# Duplicate found: Bridging Incremental Programming and Complex Software Development Environments with method: DOI Match
# Duplicate found: Advancing Software Security and Reliability in Cloud Platforms through AI-based Anomaly Detection with method: DOI Match
# Duplicate found: Revisiting the Conflict-Resolving Problem from a Semantic Perspective with method: DOI Match
# Duplicate found: Effective Vulnerable Function Identification based on CVE Description Empowered by Large Language Models with method: DOI Match
# Duplicate found: Semantic-Enhanced Indirect Call Analysis with Large Language Models with method: DOI Match
# Duplicate found: Towards Leveraging LLMs for Reducing Open Source Onboarding Information Overload with method: DOI Match
# Duplicate found: Translation Titans, Reasoning Challenges: Satisfiability-Aided Language Models for Detecting Conflicting Requirements with method: DOI Match
# Duplicate found: The Software Genome Project: Unraveling Software Through Genetic Principles with method: DOI Match
# Duplicate found: AgoneTest: Automated creation and assessment of Unit tests leveraging Large Language Models with method: DOI Match
# Duplicate found: Cross-lingual Code Clone Detection: When LLMs Fail Short Against Embedding-based Classifier with method: DOI Match
# Duplicate found: Towards LLM-augmented multiagent systems for agile software engineering with method: DOI Match
# Duplicate found: PatchTrack: Analyzing ChatGPT's Impact on Software Patch Decision-Making in Pull Requests with method: DOI Match
# Duplicate found: PACGBI: A Pipeline for Automated Code Generation from Backlog Items with method: DOI Match
# Duplicate found: Self-Elicitation of Requirements with Automated GUI Prototyping with method: DOI Match
# Duplicate found: An Empirical Study to Evaluate AIGC Detectors on Code Content with method: DOI Match
# Duplicate found: RMCBench: Benchmarking Large Language Models' Resistance to Malicious Code with method: DOI Match
# ...
# Duplicate found: Exploiting Vision-Language Models in GUI Reuse with method: DOI Match
# Duplicate found: Novice Perceptions on Effective Elements of PostgreSQL Error Messages with method: DOI Match
# Duplicate found: Responsible AI in Agile Software Engineering - An Industry Perspective with method: DOI Match
# Duplicate found: Learning Global Context and Fine Structures for Enhanced Hyperspectral Subpixel Mapping with method: DOI Match
# Duplicate found: Rethinking Software Development Considering Collaboration with AI Assistants with method: DOI Match
# Duplicate found: Structural Semantic Enhancement: Better integrating code semantics for vulnerability detection with method: DOI Match
# Duplicate found: Co-Pilot for Project Managers: Developing a PDF-Driven AI Chatbot for Facilitating Project Management with method: DOI Match
# Duplicate found: Striking a balance between diversity and regularity: a preference-guided transformer for individual mobility prediction with method: DOI Match
# Duplicate found: Software in Metrology for the Digital Age: Addressing Compliance Challenges with MID, NAWID, and MDR with method: DOI Match
# Duplicate found: Unveiling code clone patterns in open source VR software: an empirical study with method: DOI Match
# Duplicate found: Not My First Choice: Why Software Testing Struggles to Attract Early-Career Professionals with method: DOI Match
# Duplicate found: A credibility and consistency-oriented stochastic aggregation framework for heterogeneous multi-attribute large-scale group decision making with several attribute sets with method: DOI Match
# Duplicate found: Measuring how computer science research translates into innovation and development with method: DOI Match
# Duplicate found: Automated categorization of software security requirements: an NLP and ML based approach with method: DOI Match
# Duplicate found: PassionNet: An innovative framework for duplicate and conflicting requirements identification with method: DOI Match
# Duplicate found: Intelligent Semantic Matching (ISM) for Video Tutorial Search using Transformer Models with method: DOI Match
# Duplicate found: CodeDoctor: multi-category code review comment generation with method: DOI Match
# Duplicate found: Autonomous AI-Driven Measurement and Characterization of 2D Materials Using Scanning Probe Microscopy with method: DOI Match
# Duplicate found: Binary and multi-class classification of Self-Admitted Technical Debt: How far can we go? with method: DOI Match
# Duplicate found: Foundation Models for Automatic Issue Labeling with method: DOI Match
# Duplicate found: Innovating for Tomorrow: The Convergence of Software Engineering and Green AI with method: DOI Match
# Duplicate found: Intelligent Root Cause Localization in MicroService Systems: A Survey and New Perspectives with method: DOI Match
# Duplicate found: Leveraging Machine Learning for Enhanced Bug Triaging in Open-Source Software Projects with method: Fuzzy Title Match
# Duplicate found: A First Look at Conventional Commits Classification with method: DOI Match
# Duplicate found: The Role of Ethics in Requirements Engineering for Developing Information Systems with method: DOI Match
# Duplicate found: Key Factors Affecting the Cost of Medical Software Development: Cost and Modeling with method: DOI Match
# Duplicate found: Advanced code slicing with pre-trained model fine-tuned for open-source component malware detection with method: DOI Match
# Duplicate found: Geographic Prior Guided Subpixel Mapping for Fine-Grained Urban Tree Cover Reconstruction with method: DOI Match
# Duplicate found: Leveraging RAG and LLMs for Access Control Policy Extraction From User Stories in Agile Software Development with method: DOI Match
# Duplicate found: Copilot's Island of Joy Balancing Individual Satisfaction with Team Interaction in Agile Development with method: DOI Match
# Duplicate found: Stage-Gate Is Not Waterfall ... Find Out Why and How with method: DOI Match
# Duplicate found: Responsible AI in the Software Industry: A Practitioner-Centered Perspective with method: DOI Match
# Duplicate found: Knowledge Management in Financial Software Support Team: A Prototype Based on Ontology with method: DOI Match
# Duplicate found: Interacting with vector databases by means of domain-specific language with method: DOI Match
# Duplicate found: Trustworthiness of Large Language Models for Code with method: DOI Match
# Duplicate found: FocalTransNet: A Hybrid Focal-Enhanced Transformer Network for Medical Image Segmentation with method: DOI Match
# Duplicate found: Intelligent cache prefetchers in HPC architecture with method: DOI Match
# Duplicate found: Can Artificial Intelligence Identify the Ideal Ablation Area for the Patients With Atypical Atrial Flutter? A Proof of Concept Study Using Developed Software with method: DOI Match
# Duplicate found: Towards Universal Modeling Language for Neural Networks with method: DOI Match
# Duplicate found: Cloud software code generation via knowledge graphs and multi-modal learning with method: DOI Match
# Duplicate found: Participatory AI: A Method for Integrating Inclusive and Ethical Design Considerations into Autonomous System Development with method: DOI Match
# Duplicate found: Gen AI in Computing Education: A Gap Analysis of Pedagogical Practices and Industry Expectations with method: DOI Match
# Duplicate found: Enhancing Software Sustainability: Leveraging Large Language Models to Evaluate Security Requirements Fulfillment in Requirements Engineering with method: DOI Match
# Duplicate found: Empowering Agile-Based Generative Software Development through Human-AI Teamwork with method: DOI Match
# Duplicate found: LOMOS: An AI-Based Runtime Security Monitoring System Fit for the Cloud Continuum with method: DOI Match
# Duplicate found: Cross-Language Code Smell Detection via Transfer Learning with method: DOI Match
# Duplicate found: Evaluating Software Development Agents: Patch Patterns, Code Quality, and Issue Complexity in Real-World GitHub Scenarios with method: DOI Match
# Duplicate found: Agile and Lean: Organization, Products and Development with method: Fuzzy Title Match
# Duplicate found: Tracking menopause: An SDK Data Audit for intimate infrastructures of datafication with ChatGPT4o with method: DOI Match
# Duplicate found: An Effective And Efficient Renewable Energy Generation Forecasting Via Meteorological Assistance with method: DOI Match
# Duplicate found: EmotiCloud: Cloud System to Monitor Patients Using AI Facial Emotion Recognition with method: DOI Match
# Duplicate found: Automated requirements engineering framework for agile model-driven development with method: DOI Match
# Duplicate found: Optimising Construction Site Auditing: A Novel Methodology Integrating Ground Drones and Building Information Modelling (BIM) Analysis with method: DOI Match
# Duplicate found: Learning Natural Consistency Representation for Face Forgery Video Detection with method: DOI Match
# Duplicate found: Virtual reality force feedback spine surgery simulator training for pedicle screw placement: assessing the impact of seniority and spinal region with method: DOI Match
# Duplicate found: Development and Evaluation of Viajefy: A Tourism Information System using TF-IDF Algorithm with method: Fuzzy Title Match
# Duplicate found: Named entity recognition for function point descriptions in software cost estimation processes with method: DOI Match
# Duplicate found: Trust Dynamics in AI-Assisted Development: Definitions, Factors, and Implications with method: DOI Match
# Duplicate found: Improving Co-Decoding Based Security Hardening of Code LLMs Leveraging Knowledge Distillation with method: DOI Match
# Duplicate found: Artificial intelligence for context-aware visual change detection in software test automation with method: DOI Match
# Duplicate found: BR-Hunter: Detect Information Types of Bug Reports From Online Community Discussions with method: DOI Match
# Duplicate found: Overcoming Multi-Legacy Application Challenges through Building Dynamic Capabilities for Low-Code Adoption with method: Fuzzy Title Match
# Duplicate found: Structural Relation Multi-Class Token Transformer for Weakly Supervised Semantic Segmentation with method: DOI Match
# Duplicate found: Research on Hybrid Collaborative Development Model Based on Multi-Dimensional Behavioral Information with method: DOI Match
# Duplicate found: Real-time optical imaging acquisition and processing in Python: a practical guide using CAS with method: DOI Match
# Duplicate found: Software vulnerability detection under poisoning attacks using CNN-based image processing with method: DOI Match
# Duplicate found: Proinflammatory Cytokines, Type I Interferons, and Specialized Proresolving Mediators Hallmark the Influence of Vaccination and Marketing on Backgrounded Beef Cattle with method: DOI Match
# Duplicate found: Examining the Air Quality Index and its adverse effects: an analytical study for smart cities development with method: DOI Match
# Duplicate found: MATLAB Application for User-Friendly Design of Fully Convolutional Data Description Models for Defect Detection of Industrial Products and Its Concurrent Visualization with method: DOI Match
# Duplicate found: GOAT: a novel global-local optimized graph transformer framework for predicting student performance in collaborative learning with method: DOI Match
# Duplicate found: Establishing Traceability Between Natural Language Requirements and Software Artifacts by Combining RAG and LLMs with method: DOI Match
# Duplicate found: Revitalizing STEM Education: integrating STEM into National curricula with active learning with method: DOI Match
# Duplicate found: EmoReflex: an AI-powered emotion-centric developer insights platform with method: DOI Match
# Duplicate found: Feature Learning via Correlation Analysis for Effective Duplicate Detection with method: DOI Match
# Duplicate found: PROSE-TO-P4: LEVERAGING HIGH LEVEL LANGUAGES with method: Fuzzy Title Match
# Duplicate found: A Comparison of Large Language Models and Genetic Programming for Program Synthesis with method: DOI Match
# Duplicate found: Teaching Machine Learning as Part of Agile Software Engineering with method: DOI Match
# Duplicate found: Cloud-Based Certification Review Web Application with Fingerprint Authentication for Computer Engineering Students with method: DOI Match
# Duplicate found: Exploring Code Language Models for Automated HLS-based Hardware Generation: Benchmark, Infrastructure and Analysis with method: DOI Match
# Duplicate found: Question-Answer Methodology for Vulnerable Source Code Review via Prototype-Based Model-Agnostic Meta-Learning with method: DOI Match
# Duplicate found: Application of an Innovative Methodology to Build Infrastructure for Digital Transformation of Health Systems: Developmental Program Evaluation with method: DOI Match
# Duplicate found: A Framework for Efficient Development and Debugging of Role-Playing Agents with Large Language Models with method: DOI Match
# Duplicate found: DSKIPP: A Prompt Method to Enhance the Reliability in LLMs for Java API Recommendation Task with method: DOI Match
# Duplicate found: Supporting the identification of prevalent quality issues in code changes by analyzing reviewers' feedback with method: DOI Match
# Duplicate found: Generative API Recommendation Based on Global Semantics and Local Context with method: DOI Match
# Duplicate found: Requirements Traceability Link Recovery via Retrieval-Augmented Generation with method: DOI Match
# Duplicate found: FormalSpecCpp: A Dataset of C plus plus Formal Specifications created using LLMs with method: DOI Match
# Duplicate found: Enhancing Project-Specific Code Completion by Inferring Internal API Information with method: DOI Match
# Duplicate found: Refactoring for Dockerfile Quality: A Dive into Developer Practices and Automation Potential with method: DOI Match
# Duplicate found: A Transmission Axle Fault Diagnosis System for Massive Rapid Transit System With Enhanced Attention-Based Shuffle Networks with method: DOI Match
# Duplicate found: On Security Weaknesses and Vulnerabilities in Deep Learning Systems with method: DOI Match
# Duplicate found: Clinical data integration and processing challenges in healthcare caused by contemporary software design with method: DOI Match
# Duplicate found: Industrial applications of artificial intelligence in software defects prediction: Systematic review, challenges, and future works with method: DOI Match
# Duplicate found: Toward Tool-Agnostic Guidelines for Expert Debugging Strategies with method: DOI Match
# Duplicate found: How Scientists Use Jupyter Notebooks: Goals, Quality Attributes, and Opportunities with method: DOI Match
# Duplicate found: Improving Retrieval-Augmented Deep Assertion Generation via Joint Training with method: DOI Match
# Duplicate found: Quantifying behavior-based gender discrimination on collaborative platforms with method: DOI Match
# Duplicate found: Democratizing Digital Transformation: A Multisector Study of Low-Code Adoption Patterns, Limitations, and Emerging Paradigms with method: DOI Match
# Duplicate found: People and Management Debt in ML-Integrated Software Projects: Structuring Industry Insights with method: DOI Match
# Duplicate found: Nurse and Other Healthcare Managers' Experiences and Recommendations for Patient Incident Reporting Processes and Real-Time Software Development: A Qualitative Study with method: DOI Match
# Duplicate found: Privacy Impact Tree Analysis (PITA): A Tree-Based Privacy Threat Modeling Approach with method: DOI Match
# Duplicate found: E-PRedictor: an approach for early prediction of pull request acceptance with method: DOI Match
# Duplicate found: CoCoCoLa: Code Completion Control Language with method: DOI Match
# Duplicate found: Multi-label software requirement smells classification using deep learning with method: DOI Match
# Duplicate found: Identification of Intracranial Germ Cell Tumors Based on Facial Photos: Exploratory Study on the Use of Deep Learning for Software Development with method: DOI Match
# Duplicate found: Enhancing software effort estimation with random forest tuning and adaptive decision strategies with method: DOI Match
# Duplicate found: Pytester: Deep reinforcement learning for text-to-testcase generation with method: DOI Match
# Duplicate found: Tab: template-aware bug report title generation via two-phase fine-tuned models with method: DOI Match
# Duplicate found: Instruct or Interact? Exploring and Eliciting LLMs' Capability in Code Snippet Adaptation Through Prompt Engineering with method: DOI Match
# Duplicate found: Understanding Flaky Tests Through Linguistic Diversity: A Cross-Language and Comparative Machine Learning Study with method: DOI Match
# Duplicate found: Personality-based pair programming: toward intrinsic motivation alignment in very small entities with method: DOI Match
# Duplicate found: The Virtual Co-design of Sleep Solved - A Case Study of an Educational Sleep App Designed with Teens with method: DOI Match
# Duplicate found: Retrieval-Augmented Fine-Tuning for Improving Retrieve-and-Edit Based Assertion Generation with method: DOI Match
# Duplicate found: Formal Verification for Preventing Misconfigured Access Policies in Kubernetes Clusters with method: DOI Match
# Duplicate found: Exploring Large Language Models for Analyzing Open Source License Conflicts: How Far Are We? with method: DOI Match
# Duplicate found: What Types of Automated Tests do Developers Write? with method: DOI Match
# Duplicate found: Evolving funding strategies for research software: Insights from an international survey of research funders with method: DOI Match
# Duplicate found: Validation of Automated Standardization Performance for ECDaim Software Developed Using a Taiwan-Specific Database with method: DOI Match
# Duplicate found: An adaptive model for cross-domain code search with method: DOI Match
# Duplicate found: Application of Generative AI in Software Development with method: Fuzzy Title Match
# Files saved: No duplicates and duplicates files.
# 4074 duplicates were identified and removed.

# %%
# !rm -rf Duplicates_Removed/

# %% [markdown]
# # **SPARK Keywords Screening (Table 7)**
#
# Phase-I

# %%
import pandas as pd
import os
import re

# Define the input CSV file path
input_csv_path = r"/content/Duplicates_Removed/No_Duplicates.csv"

# Create the Keyword_Filtered directory within the same directory as the input file
keyword_filtered_dir = os.path.join(os.path.dirname(input_csv_path), "Keyword_Filtered")
os.makedirs(keyword_filtered_dir, exist_ok=True)

# Define the preprocessing function for text
def preprocess_text(text):
    if not isinstance(text, str):
        return ""  # Return an empty string if the text is NaN or non-string

    text = text.lower()  # Convert to lowercase
    pattern = re.compile(r'[^a-zA-Z0-9\s]+', re.IGNORECASE)
    return pattern.sub(' ', text)  # Replace special characters with a space

# Define the function to filter articles by keywords
def filter_articles_by_keywords(input_csv_path, output_csv_path,
                               and_keywords=None, or_keywords=None, exclude_keywords=None):

    df = pd.read_csv(input_csv_path)

    df['title'] = df['title'].apply(preprocess_text)
    df['abstract'] = df['abstract'].apply(preprocess_text)

    if and_keywords is None:
        and_keywords = []

    if or_keywords is None:
        or_keywords = []

    if exclude_keywords is None:
        exclude_keywords = []

    and_patterns = [re.compile(rf'{keyword}', re.IGNORECASE) for keyword in and_keywords]

    if and_patterns:
        and_mask = pd.Series(True, index=df.index)

        for pattern in and_patterns:
            and_mask &= (df['title'].str.contains(pattern, na=False) |
                        df['abstract'].str.contains(pattern, na=False))

        df = df[and_mask]

    or_patterns = [re.compile(rf'{keyword}', re.IGNORECASE) for keyword in or_keywords]

    if or_patterns:
        or_mask = pd.Series(False, index=df.index)

        for pattern in or_patterns:
            or_mask |= (df['title'].str.contains(pattern, na=False) |
                       df['abstract'].str.contains(pattern, na=False))

        df = df[or_mask]

    exclude_patterns = [re.compile(rf'{keyword}', re.IGNORECASE) for keyword in exclude_keywords]

    if exclude_patterns:
        exclude_mask = pd.Series(False, index=df.index)

        for pattern in exclude_patterns:
            exclude_mask |= (df['title'].str.contains(pattern, na=False) |
                           df['abstract'].str.contains(pattern, na=False))

        df = df[~exclude_mask]

    df.to_csv(output_csv_path, index=False)

    print(f"Filtered articles saved to {output_csv_path}")

# Define the output file path within the same directory as the input file
output_csv_path = os.path.join(keyword_filtered_dir, "Screened.csv")

# Define the keywords for filtering
# and_keywords = ["software project management", "review"]
and_keywords = ["project", "management"]

or_keywords = ["software project management", "software project", "project management",
            "IT project management", "software engineering management", "project performance",
            "SPM", "PMBOK", "software development management",
            "agile project management", "scrum management", "DevOps management",
            "requirements management", "project requirements management",
            "risk management", "quality management", "team management",
            "resource management", "project schedule management",
            "software process management", "waterfall project management",
            "agile management", "waterfall management", "project governance",
            "software project planning", "project planning", "project management tool",
            "stakeholder management", "procurement management", "schedule management",
            "scope management", "project integration", "project integration management",
            "cost management", "project cost management", "project quality management",
            "project resource management", "communication management", "project communication management",
            "project risk management",


            "large language model", "LLM", "generative AI", "GenAI",
            "language models", "transformer models", "deep learning",
            "machine learning", "neural networks", "artificial intelligence",
            "AI", "NLP models", "GPT", "BERT", "ChatGPT", "OpenAI",
            "Anthropic", "Claude", "Bard", "Gemini", "natural language processing",
            "conversational AI", "text generation", "language understanding",
            "pre-trained models", "foundation models", "automated reasoning",
            "natural language generation", "language model", "transformer",
            "attention mechanism", "fine-tuning", "prompt engineering",
            "few-shot learning", "zero-shot learning", "transfer learning",
            "neural language model", "autoregressive model", "seq2seq",
            "encoder-decoder", "LSTM", "GRU", "RNN", "CNN", "generation models",


            "systematic literature review", "systematic review", "literature review",
            "mapping study", "survey paper", "short review", "review", "survey",
            "meta-analysis", "scoping review", "narrative review", "critical review",
            "state-of-the-art", "bibliometric analysis", "content analysis",
            "thematic analysis", "qualitative review", "quantitative review",
            "comprehensive review", "overview", "research synthesis",
            "evidence synthesis", "research review", "academic review",
            "scientific review", "technical review", "comparative study",
            "analytical review", "descriptive review", "exploratory review"]

exclude_keywords = []

# Call the function to filter articles and save the result
filter_articles_by_keywords(input_csv_path, output_csv_path, and_keywords,
                           or_keywords, exclude_keywords)
# Out:
# Filtered articles saved to /content/Duplicates_Removed/Keyword_Filtered/Screened.csv

# %% [markdown]
# # **SPARK Keywords Screening (Phase II)**

# %%
import pandas as pd
import os
import re

# Define the input CSV file path
# input_csv_path = r"No_Duplicates.csv"
input_csv_path = r"/content/Duplicates_Removed/No_Duplicates.csv"

# Create the Keyword_Filtered directory within the same directory as the input file
keyword_filtered_dir = os.path.join(os.path.dirname(input_csv_path), "Keyword_Filtered")
os.makedirs(keyword_filtered_dir, exist_ok=True)

# Define the preprocessing function for text
def preprocess_text(text):
    if not isinstance(text, str):
        return ""  # Return an empty string if the text is NaN or non-string

    text = text.lower()  # Convert to lowercase
    pattern = re.compile(r'[^a-zA-Z0-9\s]+', re.IGNORECASE)
    return pattern.sub(' ', text)  # Replace special characters with a space

# Define the function to filter articles by keywords
def filter_articles_by_keywords(input_csv_path, output_csv_path,
                               and_keywords=None, or_keywords=None, exclude_keywords=None):

    df = pd.read_csv(input_csv_path)

    df['title'] = df['title'].apply(preprocess_text)
    df['abstract'] = df['abstract'].apply(preprocess_text)

    if and_keywords is None:
        and_keywords = []

    if or_keywords is None:
        or_keywords = []

    if exclude_keywords is None:
        exclude_keywords = []

    and_patterns = [re.compile(rf'{keyword}', re.IGNORECASE) for keyword in and_keywords]

    if and_patterns:
        and_mask = pd.Series(True, index=df.index)

        for pattern in and_patterns:
            and_mask &= (df['title'].str.contains(pattern, na=False) |
                        df['abstract'].str.contains(pattern, na=False))

        df = df[and_mask]

    or_patterns = [re.compile(rf'{keyword}', re.IGNORECASE) for keyword in or_keywords]

    if or_patterns:
        or_mask = pd.Series(False, index=df.index)

        for pattern in or_patterns:
            or_mask |= (df['title'].str.contains(pattern, na=False) |
                       df['abstract'].str.contains(pattern, na=False))

        df = df[or_mask]

    exclude_patterns = [re.compile(rf'{keyword}', re.IGNORECASE) for keyword in exclude_keywords]

    if exclude_patterns:
        exclude_mask = pd.Series(False, index=df.index)

        for pattern in exclude_patterns:
            exclude_mask |= (df['title'].str.contains(pattern, na=False) |
                           df['abstract'].str.contains(pattern, na=False))

        df = df[~exclude_mask]

    df.to_csv(output_csv_path, index=False)

    print(f"Filtered articles saved to {output_csv_path}")

# Define the output file path within the same directory as the input file
output_csv_path = os.path.join(keyword_filtered_dir, "Screened.csv")

# Define the keywords for filtering
# and_keywords = ["software project management", "review"]
and_keywords = ["project", "management"]

or_keywords = [
    "LLM", "Large Language Model", "Language Model", "LM", "PLM", "Pre-trained Language Model",
    "Pretrained Model", "Pretraining", "Pre-training", "Natural Language Processing", "NLP",
    "Artificial Intelligence", "AI", "Transformer", "Sequence Model", "Attention Model",
    "Transfer Learning", "Generative AI", "GPT", "ChatGPT", "Codex", "BERT", "T5", "Gemini",
    "Mistral", "LLaMA",

    "SPM", "Software Project Management", "Software Development Project Management",
    "Software Engineering Project Management", "software engineering management",
    "software project", "IT project management", "IT project", "software development project",
    "Software Process Management", "Software Lifecycle Management", "Agile Project Management",
    "Hybrid Project Management", "Software Project Scheduling Problem", "SPSP",
    "Software Development", "Software Lifecycle", "Software Life Cycle", "SDLC",
    "Requirements Management", "PMBOK"

    # "PMBOK", "Project Management Body of Knowledge", "project management framework", "PM framework",
    # "project management standard", "Project Management Practices", "Project Management Institute",
    # "Integration", "Scope", "Schedule", "Cost", "Quality", "Resource", "Communications", "Risk",
    # "Stakeholder", "Procurement",

    # "support", "practice", "mechanism", "automation", "communication", "information processing",
    # "outcome", "research design", "empirical", "case study", "survey", "interview", "effectiveness",
    # "measurement", "benefit", "challenge", "limitation", "evaluate", "integrate", "predict", "forecast",
    # "assessment", "original studies", "prediction", "validation", "verification", "approach", "process",
    # "deploy", "implementation", "detection", "identification", "analysis", "classification", "monitoring",
    # "error", "solution"
]

exclude_keywords = ["review", "systematic literature review", "SLR", "tertiary study"]

# Call the function to filter articles and save the result
filter_articles_by_keywords(input_csv_path, output_csv_path, and_keywords,
                           or_keywords, exclude_keywords)
# Out:
# Filtered articles saved to /content/Duplicates_Removed/Keyword_Filtered/Screened.csv

# %% [markdown]
# ## **Extracting non-processed meta-data for Title and Abstract Screening**

# %% [markdown]
# After SPARK processing, all meta-data is in lowercase and also stopwords and punctuations are not there. So the code below retrives back the original meta-data from the dataset file that contains the original (non-processed) data.

# %%
import pandas as pd
import os
import numpy as np

# Define file paths
# original_csv_path = r"/content/Duplicates_Removed/No_Duplicates.csv"  # Original 13,454 papers
# filtered_csv_path = r"/content/Duplicates_Removed/Keyword_Filtered/Screened.csv"  # Your 1,152 filtered papers

original_csv_path = r"No_Duplicates.csv"  # Original 20,006 papers
filtered_csv_path = r"128_papers.csv"  # Your 128 filtered papers

# Define output directory and file path
output_dir = os.path.join(os.path.dirname(filtered_csv_path), "Original_Metadata")
os.makedirs(output_dir, exist_ok=True)
output_csv_path = os.path.join(output_dir, "Screened_Original_Metadata.csv")

print("Loading files...")
print("-" * 50)

# Load both CSV files
df_original = pd.read_csv(original_csv_path)
df_filtered = pd.read_csv(filtered_csv_path)

print(f"Original file: {len(df_original)} papers")
print(f"Filtered file: {len(df_filtered)} papers")
print("-" * 50)

# Add normalized columns to original dataframe for matching
def preprocess_text(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()
    pattern = re.compile(r'[^a-zA-Z0-9\s]+', re.IGNORECASE)
    return pattern.sub(' ', text).strip()

df_original['Normalized Title'] = df_original['title'].apply(preprocess_text)
df_original['Normalized Authors'] = df_original['authors'].apply(lambda x: ''.join(sorted(re.sub(r'[^A-Za-z\s]', '', str(x)).lower().split(' '))))


# Check for missing DOIs in both files
original_missing_doi = df_original['doi'].isna().sum()
filtered_missing_doi = df_filtered['doi'].isna().sum()

print(f"Missing DOIs in original file: {original_missing_doi}")
print(f"Missing DOIs in filtered file: {filtered_missing_doi}")
print("-" * 50)

# Strategy: Try multiple matching approaches
print("Attempting to match papers...")

# Initialize new columns in df_filtered
df_filtered['match_source'] = 'unmatched'
df_filtered['original_title'] = None
df_filtered['original_abstract'] = None
df_filtered['original_authors'] = None
df_filtered['original_doi'] = None # Add original DOI column

# Approach 1: Match by DOI (for papers with DOI)
# Create a mapping from original data with DOI
doi_mapping = df_original[df_original['doi'].notna()].set_index('doi')[['title', 'abstract', 'authors']].to_dict('index')

matched_by_doi = 0
for idx, row in df_filtered.iterrows():
    doi = row['doi']
    if pd.notna(doi) and doi in doi_mapping:
        df_filtered.at[idx, 'original_title'] = doi_mapping[doi]['title']
        df_filtered.at[idx, 'original_abstract'] = doi_mapping[doi]['abstract']
        df_filtered.at[idx, 'original_authors'] = doi_mapping[doi]['authors']
        df_filtered.at[idx, 'original_doi'] = doi # Capture the original DOI
        df_filtered.at[idx, 'match_source'] = 'doi'
        matched_by_doi += 1

print(f"✓ Matched by DOI: {matched_by_doi}")

# Approach 2: Match by normalized title for papers without DOI or unmatched
unmatched_mask_title = (df_filtered['match_source'] == 'unmatched') & (df_filtered['Normalized Title'].notna())
unmatched_count_title = unmatched_mask_title.sum()

if unmatched_count_title > 0:
    print(f"Attempting to match {unmatched_count_title} papers by normalized title...")

    # Group original data by Normalized Title
    original_grouped_by_title = df_original.groupby('Normalized Title')[['title', 'abstract', 'authors', 'doi']].apply(lambda x: x.to_dict('records')).to_dict()

    matched_by_title = 0
    for idx, row in df_filtered[unmatched_mask_title].iterrows():
        norm_title = row['Normalized Title']
        if norm_title in original_grouped_by_title:
            # Take the first match found (assuming normalized title is a strong indicator)
            original_record = original_grouped_by_title[norm_title][0]
            df_filtered.at[idx, 'original_title'] = original_record.get('title')
            df_filtered.at[idx, 'original_abstract'] = original_record.get('abstract')
            df_filtered.at[idx, 'original_authors'] = original_record.get('authors')
            df_filtered.at[idx, 'original_doi'] = original_record.get('doi') # Capture original DOI
            df_filtered.at[idx, 'match_source'] = 'normalized_title'
            matched_by_title += 1

    print(f"✓ Matched by Normalized Title: {matched_by_title}")


# Approach 3: Match by normalized authors + year for remaining unmatched
unmatched_mask_author_year = (df_filtered['match_source'] == 'unmatched') & (df_filtered['Normalized Authors'].notna()) & (df_filtered['year'].notna())
unmatched_count_author_year = unmatched_mask_author_year.sum()


if unmatched_count_author_year > 0:
    print(f"Attempting to match {unmatched_count_author_year} papers by authors + year...")

    # Create composite key and group original data
    df_original['author_year_key'] = df_original['Normalized Authors'].astype(str) + '_' + df_original['year'].astype(str)
    original_grouped_by_author_year = df_original.groupby('author_year_key')[['title', 'abstract', 'authors', 'doi']].apply(lambda x: x.to_dict('records')).to_dict()


    matched_by_author_year = 0
    for idx, row in df_filtered[unmatched_mask_author_year].iterrows():
        key = str(row['Normalized Authors']) + '_' + str(row['year'])
        if key in original_grouped_by_author_year:
            # Take the first match found
            original_record = original_grouped_by_author_year[key][0]
            df_filtered.at[idx, 'original_title'] = original_record.get('title')
            df_filtered.at[idx, 'original_abstract'] = original_record.get('abstract')
            df_filtered.at[idx, 'original_authors'] = original_record.get('authors')
            df_filtered.at[idx, 'original_doi'] = original_record.get('doi') # Capture original DOI
            df_filtered.at[idx, 'match_source'] = 'authors_year'
            matched_by_author_year += 1

    print(f"✓ Matched by Authors + Year: {matched_by_author_year}")

print("-" * 50)

# Final statistics
total_matched = (df_filtered['match_source'] != 'unmatched').sum()
total_unmatched = (df_filtered['match_source'] == 'unmatched').sum()

print(f"\nFinal Matching Results:")
print(f"Total papers in filtered file: {len(df_filtered)}")
print(f"Successfully matched: {total_matched}")
print(f"Unmatched: {total_unmatched}")
print("-" * 50)

# Save the filtered dataframe with original metadata
df_filtered.to_csv(output_csv_path, index=False)

print(f"✓ Successfully extracted original metadata!")
print(f"✓ Saved to: {output_csv_path}")
print("-" * 50)

# Display sample of the first few papers that were successfully matched
print("\nSample of extracted papers (first 3 successfully matched):")
print("-" * 50)
matched_samples = df_filtered[df_filtered['match_source'] != 'unmatched'].head(3)
if not matched_samples.empty:
    for idx, row in matched_samples.iterrows():
        print(f"\nOriginal Title: {row['original_title']}")
        print(f"Original Authors: {row['original_authors']}")
        print(f"Original Year: {row['year']}") # Year should be the same
        print(f"Original DOI: {row['original_doi']}")
        print(f"Original Abstract: {str(row['original_abstract'])[:150]}...")  # First 150 characters
        print(f"Matched by: {row['match_source']}")
        print("-" * 50)
else:
    print("No papers were successfully matched.")
    print("-" * 50)

# Summary statistics
print("\nSummary Statistics:")
print(f"Total papers in filtered file: {len(df_filtered)}")
print(f"Total successfully matched: {total_matched}")
print(f"Total unmatched: {total_unmatched}")
print("-" * 50)

if total_matched < len(df_filtered):
    print("\n⚠ Warning: Some papers from filtered file were not found in original file or could not be matched!")
else:
    print("\n✓ All filtered papers were successfully matched to the original data!")
# Out:
# Loading files...
# --------------------------------------------------
# Original file: 16008 papers
# Filtered file: 128 papers
# --------------------------------------------------
# Missing DOIs in original file: 619
# Missing DOIs in filtered file: 9
# --------------------------------------------------
# Attempting to match papers...
# ✓ Matched by DOI: 113
# --------------------------------------------------
#
# Final Matching Results:
# Total papers in filtered file: 128
# Successfully matched: 113
# Unmatched: 15
# --------------------------------------------------
# ✓ Successfully extracted original metadata!
# ✓ Saved to: Original_Metadata/Screened_Original_Metadata.csv
# --------------------------------------------------
#
# Sample of extracted papers (first 3 successfully matched):
# --------------------------------------------------
#
# Original Title: Enhancing software effort estimation with random forest tuning and adaptive decision strategies
# Original Authors: Priya Varshini, A.G.; Anitha Kumari, K.; Ramakrishnan, S.
# Original Year: nan
# Original DOI: 10.1038/s41598-025-14372-7
# Original Abstract: Software Effort estimation (SEE) is a vital task for project management as it is essential for resource allocation and project planning. Numerous algo...
# Matched by: doi
# --------------------------------------------------
#
# Original Title: Benchmarking large language models for automated labeling: The case of issue report classification
# Original Authors: Colavito, G.; Lanubile, F.; Novielli, N.
# Original Year: nan
# Original DOI: 10.1016/j.infsof.2025.107758
# Original Abstract: Context: Issue labeling is a fundamental task for software development as it is critical for the effective management of software projects. This pract...
# Matched by: doi
# --------------------------------------------------
#
# Original Title: Success with Agile Project Management: Looking back and into the future
# Original Authors: Koudriachov, C.; Tam, C.; Aparicio, M.
# Original Year: nan
# Original DOI: 10.1016/j.jss.2025.112428
# Original Abstract: We show what the influential factors and practical strategies are that contribute to agile project management success. The research model comprises th...
# Matched by: doi
# --------------------------------------------------
#
# Summary Statistics:
# Total papers in filtered file: 128
# Total successfully matched: 113
# Total unmatched: 15
# --------------------------------------------------
#
# ⚠ Warning: Some papers from filtered file were not found in original file or could not be matched!

# %%
# !rm -rf Keyword_Filtered/
#

# %% [markdown]
# # Comparing SPARK results before and after query modifications

# %%
import pandas as pd
import numpy as np

# Read both CSV files
df1 = pd.read_csv('screened_1152.csv')
df2 = pd.read_csv('screened_1180.csv')

print("=" * 80)
print("CSV FILES COMPARISON ANALYSIS")
print("=" * 80)

# Basic file information
print(f"\nFile 1 (screened_1152.csv): {len(df1)} records")
print(f"File 2 (screenedd_1180.csv): {len(df2)} records")

# Create unique identifiers for comparison
# Primary: DOI, Fallback: Normalized Title + Normalized Authors
def create_key(row):
    if pd.notna(row.get('doi')) and str(row['doi']).strip():
        return f"doi:{str(row['doi']).strip().lower()}"
    title = str(row.get('Normalized Title', row.get('title', ''))).strip().lower()
    authors = str(row.get('Normalized Authors', row.get('authors', ''))).strip().lower()
    return f"{title}|||{authors}"

# Add unique keys to both dataframes
df1['_key'] = df1.apply(create_key, axis=1)
df2['_key'] = df2.apply(create_key, axis=1)

# Remove empty keys
df1_clean = df1[df1['_key'] != '|||']
df2_clean = df2[df2['_key'] != '|||']

# Find duplicates and unique records
keys1 = set(df1_clean['_key'])
keys2 = set(df2_clean['_key'])

duplicate_keys = keys1.intersection(keys2)
unique_to_file1_keys = keys1 - keys2
unique_to_file2_keys = keys2 - keys1

# Get the actual records
duplicates = df1_clean[df1_clean['_key'].isin(duplicate_keys)]
unique_to_file1 = df1_clean[df1_clean['_key'].isin(unique_to_file1_keys)]
unique_to_file2 = df2_clean[df2_clean['_key'].isin(unique_to_file2_keys)]

# Print results
print("\n" + "=" * 80)
print("RESULTS")
print("=" * 80)
print(f"\nTotal records in File 1 (cleaned): {len(df1_clean)}")
print(f"Total records in File 2 (cleaned): {len(df2_clean)}")
print(f"\nDuplicates (in both files): {len(duplicates)}")
print(f"Unique to File 1 only: {len(unique_to_file1)}")
print(f"Unique to File 2 only: {len(unique_to_file2)}")
print(f"\nTotal unique records across both files: {len(duplicate_keys) + len(unique_to_file1_keys) + len(unique_to_file2_keys)}")

# Percentage calculations
if len(df1_clean) > 0:
    print(f"\nDuplicates as % of File 1: {(len(duplicates) / len(df1_clean) * 100):.2f}%")
if len(df2_clean) > 0:
    print(f"Duplicates as % of File 2: {(len(duplicates) / len(df2_clean) * 100):.2f}%")

# Show sample duplicates
print("\n" + "=" * 80)
print("SAMPLE DUPLICATES (first 5)")
print("=" * 80)
if len(duplicates) > 0:
    sample_cols = ['title', 'authors', 'year', 'doi']
    available_cols = [col for col in sample_cols if col in duplicates.columns]
    print(duplicates[available_cols].head(5).to_string(index=False))
else:
    print("No duplicates found!")

# Show sample unique to File 1
print("\n" + "=" * 80)
print("SAMPLE UNIQUE TO FILE 1 (first 5)")
print("=" * 80)
if len(unique_to_file1) > 0:
    available_cols = [col for col in sample_cols if col in unique_to_file1.columns]
    print(unique_to_file1[available_cols].head(5).to_string(index=False))
else:
    print("No unique records in File 1!")

# Show sample unique to File 2
print("\n" + "=" * 80)
print("SAMPLE UNIQUE TO FILE 2 (first 5)")
print("=" * 80)
if len(unique_to_file2) > 0:
    available_cols = [col for col in sample_cols if col in unique_to_file2.columns]
    print(unique_to_file2[available_cols].head(5).to_string(index=False))
else:
    print("No unique records in File 2!")

# Optional: Save results to CSV files
print("\n" + "=" * 80)
print("SAVING RESULTS TO CSV FILES")
print("=" * 80)

# Remove the temporary key column before saving
duplicates_export = duplicates.drop(columns=['_key'])
unique_to_file1_export = unique_to_file1.drop(columns=['_key'])
unique_to_file2_export = unique_to_file2.drop(columns=['_key'])

duplicates_export.to_csv('duplicates.csv', index=False)
unique_to_file1_export.to_csv('unique_to_file1.csv', index=False)
unique_to_file2_export.to_csv('unique_to_file2.csv', index=False)

print(f"✓ Saved duplicates.csv ({len(duplicates)} records)")
print(f"✓ Saved unique_to_file1.csv ({len(unique_to_file1)} records)")
print(f"✓ Saved unique_to_file2.csv ({len(unique_to_file2)} records)")
print("\nAnalysis complete!")
# Out:
# ================================================================================
# CSV FILES COMPARISON ANALYSIS
# ================================================================================
#
# File 1 (screened_1152.csv): 1152 records
# File 2 (screenedd_1180.csv): 1180 records
#
# ================================================================================
# RESULTS
# ================================================================================
#
# Total records in File 1 (cleaned): 1152
# Total records in File 2 (cleaned): 1180
#
# Duplicates (in both files): 1052
# Unique to File 1 only: 100
# Unique to File 2 only: 128
#
# Total unique records across both files: 1280
#
# Duplicates as % of File 1: 91.32%
# Duplicates as % of File 2: 89.15%
#
# ================================================================================
# SAMPLE DUPLICATES (first 5)
# ================================================================================
#                                                                                                                            title                                                                                            authors  year                                           doi
# the distributed situational centers system as an instrument of state and corporate strategic goal setting in the digital economy Z.K. Avdeeva and S.V. Kovriga and V.E. Lepskiy and A.N. Raikov and B.B. Slavin and A.A. Zatsarinny  2020 https://doi.org/10.1016/j.ifacol.2020.12.2156
#                           ambiguous regulations for dealing with ai in higher education can lead to moral hazards among students                                   Michelle Smit and Reinhard F. Wagner and Taryn Jane Bond-Barnard  2025    https://doi.org/10.1016/j.plas.2025.100187
#                                                      enablers  barriers and strategies for adopting new technology in accounting                                                                 Denise Jackson and Christina Allen  2024  https://doi.org/10.1016/j.accinf.2023.100666
#                      automated progress monitoring of construction projects using machine learning and image processing approach                                                              Greeshma A.S. and Jeena B. Edayadiyil  2022   https://doi.org/10.1016/j.matpr.2022.03.137
#                                           choosing the right path for ai integration in engineering companies  a strategic guide                                         Rimma Dzhusupova and Jan Bosch and Helena Holmström Olsson  2024     https://doi.org/10.1016/j.jss.2023.111945
#
# ================================================================================
# SAMPLE UNIQUE TO FILE 1 (first 5)
# ================================================================================
#                                                                                                                                                      title                                                                                           authors  year                                         doi
#                                    leveraging llm based data augmentation for automatic classification of recurring tasks in software development projects                                                          Włodzimierz Wysocki and Mirosław Ochodek  2026   https://doi.org/10.1016/j.jss.2025.112641
#                                                            using automation and artificial intelligence in the management of european social fund projects                                                 Matei Oliviu and Laura Andreica and Faragau Tudor  2025 https://doi.org/10.1016/j.procs.2025.02.333
#                                                                     verification and validation for data marketplaces via a blockchain and smart contracts                                                                                      Will Serrano  2022  https://doi.org/10.1016/j.bcra.2022.100100
# cross platform epc collaboration framework for construction management of pumped storage hydropower utilizing industry foundation classes and semantic web Sherong Zhang and Shihang Zhang and Zhengqiao Wu and Chao Wang and Zhiyong Jiang and Xiaohua Wang  2025  https://doi.org/10.1016/j.tust.2025.106692
#                                                                               a new approach for competency frameworks mapping using large language models                              Imene Jemal and Naoussi Sijou Wilfried Armand and Belkacem Chikhaoui  2025  https://doi.org/10.1016/j.eswa.2024.125648
#
# ================================================================================
# SAMPLE UNIQUE TO FILE 2 (first 5)
# ================================================================================
#                                                                                              title                                                                authors  year                          doi
#    enhancing software effort estimation with random forest tuning and adaptive decision strategies              Priya Varshini, A.G.; Anitha Kumari, K.; Ramakrishnan, S.  2025   10.1038/s41598-025-14372-7
# benchmarking large language models for automated labeling  the case of issue report classification                               Colavito, G.; Lanubile, F.; Novielli, N.  2025 10.1016/j.infsof.2025.107758
#                            success with agile project management  looking back and into the future                                 Koudriachov, C.; Tam, C.; Aparicio, M.  2025    10.1016/j.jss.2025.112428
# mediating between human programmers and integrated development environments using llm based agents                                                                 Li, Z.  2025      10.1145/3696630.3731460
#       data driven predictive modelling of agile projects using explainable artificial intelligence ForouzeshNejad, A.A.; Arabikhan, F.; Gegov, A.; Jafari, R.; Ichtev, A.  2025  10.3390/electronics14132609
#
# ================================================================================
# SAVING RESULTS TO CSV FILES
# ================================================================================
# ✓ Saved duplicates.csv (1052 records)
# ✓ Saved unique_to_file1.csv (100 records)
# ✓ Saved unique_to_file2.csv (128 records)
#
# Analysis complete!

# %% [markdown]
# modified code to also include the index of the data.

# %%
import pandas as pd
import numpy as np

# Read both CSV files
df1 = pd.read_csv('screened_1152.csv')
df2 = pd.read_csv('screened_1180.csv')

print("=" * 80)
print("CSV FILES COMPARISON ANALYSIS")
print("=" * 80)

# Basic file information
print(f"\nFile 1 (screened_1152.csv): {len(df1)} records")
print(f"File 2 (screened_1180.csv): {len(df2)} records")

# Store original indices
df1['_original_index_file1'] = df1.index
df2['_original_index_file2'] = df2.index

# Create unique identifiers for comparison
# Primary: DOI, Fallback: Normalized Title + Normalized Authors
def create_key(row):
    if pd.notna(row.get('doi')) and str(row['doi']).strip():
        return f"doi:{str(row['doi']).strip().lower()}"
    title = str(row.get('Normalized Title', row.get('title', ''))).strip().lower()
    authors = str(row.get('Normalized Authors', row.get('authors', ''))).strip().lower()
    return f"{title}|||{authors}"

# Add unique keys to both dataframes
df1['_key'] = df1.apply(create_key, axis=1)
df2['_key'] = df2.apply(create_key, axis=1)

# Remove empty keys
df1_clean = df1[df1['_key'] != '|||'].copy()
df2_clean = df2[df2['_key'] != '|||'].copy()

# Find duplicates and unique records
keys1 = set(df1_clean['_key'])
keys2 = set(df2_clean['_key'])

duplicate_keys = keys1.intersection(keys2)
unique_to_file1_keys = keys1 - keys2
unique_to_file2_keys = keys2 - keys1

# Get the actual records
duplicates_df1 = df1_clean[df1_clean['_key'].isin(duplicate_keys)].copy()
duplicates_df2 = df2_clean[df2_clean['_key'].isin(duplicate_keys)].copy()
unique_to_file1 = df1_clean[df1_clean['_key'].isin(unique_to_file1_keys)].copy()
unique_to_file2 = df2_clean[df2_clean['_key'].isin(unique_to_file2_keys)].copy()

# Create a mapping of duplicates with indices from both files
duplicate_mapping = []
for key in duplicate_keys:
    file1_records = duplicates_df1[duplicates_df1['_key'] == key]
    file2_records = duplicates_df2[duplicates_df2['_key'] == key]

    for _, row1 in file1_records.iterrows():
        for _, row2 in file2_records.iterrows():
            duplicate_mapping.append({
                'key': key,
                'file1_index': row1['_original_index_file1'],
                'file2_index': row2['_original_index_file2'],
                'title': row1.get('title', row1.get('Normalized Title', '')),
                'authors': row1.get('authors', row1.get('Normalized Authors', '')),
                'year': row1.get('year', ''),
                'doi': row1.get('doi', '')
            })

# Create DataFrame from duplicate mapping
duplicate_mapping_df = pd.DataFrame(duplicate_mapping)

# Print results
print("\n" + "=" * 80)
print("RESULTS")
print("=" * 80)
print(f"\nTotal records in File 1 (cleaned): {len(df1_clean)}")
print(f"Total records in File 2 (cleaned): {len(df2_clean)}")
print(f"\nDuplicates (in both files): {len(duplicate_keys)}")
print(f"Unique to File 1 only: {len(unique_to_file1)}")
print(f"Unique to File 2 only: {len(unique_to_file2)}")
print(f"\nTotal unique records across both files: {len(duplicate_keys) + len(unique_to_file1_keys) + len(unique_to_file2_keys)}")

# Percentage calculations
if len(df1_clean) > 0:
    print(f"\nDuplicates as % of File 1: {(len(duplicate_keys) / len(df1_clean) * 100):.2f}%")
if len(df2_clean) > 0:
    print(f"Duplicates as % of File 2: {(len(duplicate_keys) / len(df2_clean) * 100):.2f}%")

# Show sample duplicates with indices
print("\n" + "=" * 80)
print("SAMPLE DUPLICATES WITH INDICES (first 10)")
print("=" * 80)
if len(duplicate_mapping_df) > 0:
    display_cols = ['file1_index', 'file2_index', 'title', 'authors', 'year', 'doi']
    available_cols = [col for col in display_cols if col in duplicate_mapping_df.columns]
    print(duplicate_mapping_df[available_cols].head(10).to_string(index=False))
else:
    print("No duplicates found!")

# Show sample unique to File 1 with indices
print("\n" + "=" * 80)
print("SAMPLE UNIQUE TO FILE 1 WITH INDICES (first 5)")
print("=" * 80)
if len(unique_to_file1) > 0:
    sample_cols = ['_original_index_file1', 'title', 'authors', 'year', 'doi']
    available_cols = [col for col in sample_cols if col in unique_to_file1.columns]
    print(unique_to_file1[available_cols].head(5).to_string(index=False))
else:
    print("No unique records in File 1!")

# Show sample unique to File 2 with indices
print("\n" + "=" * 80)
print("SAMPLE UNIQUE TO FILE 2 WITH INDICES (first 5)")
print("=" * 80)
if len(unique_to_file2) > 0:
    sample_cols = ['_original_index_file2', 'title', 'authors', 'year', 'doi']
    available_cols = [col for col in sample_cols if col in unique_to_file2.columns]
    print(unique_to_file2[available_cols].head(5).to_string(index=False))
else:
    print("No unique records in File 2!")

# Optional: Save results to CSV files
print("\n" + "=" * 80)
print("SAVING RESULTS TO CSV FILES")
print("=" * 80)

# Save duplicate mapping (with indices from both files)
if len(duplicate_mapping_df) > 0:
    duplicate_mapping_df.to_csv('duplicates_with_indices.csv', index=False)
    print(f"✓ Saved duplicates_with_indices.csv ({len(duplicate_mapping_df)} records)")

# Remove temporary columns before saving individual file results
duplicates_df1_export = duplicates_df1.drop(columns=['_key']).rename(columns={'_original_index_file1': 'original_index'})
unique_to_file1_export = unique_to_file1.drop(columns=['_key']).rename(columns={'_original_index_file1': 'original_index'})
unique_to_file2_export = unique_to_file2.drop(columns=['_key']).rename(columns={'_original_index_file2': 'original_index'})

duplicates_df1_export.to_csv('duplicates_file1_with_index.csv', index=False)
unique_to_file1_export.to_csv('unique_to_file1_with_index.csv', index=False)
unique_to_file2_export.to_csv('unique_to_file2_with_index.csv', index=False)

print(f"✓ Saved duplicates_file1_with_index.csv ({len(duplicates_df1)} records from File 1)")
print(f"✓ Saved unique_to_file1_with_index.csv ({len(unique_to_file1)} records)")
print(f"✓ Saved unique_to_file2_with_index.csv ({len(unique_to_file2)} records)")

# Print summary of index ranges
print("\n" + "=" * 80)
print("INDEX SUMMARY")
print("=" * 80)
if len(duplicate_mapping_df) > 0:
    print(f"\nDuplicates:")
    print(f"  File 1 index range: {duplicate_mapping_df['file1_index'].min():.0f} - {duplicate_mapping_df['file1_index'].max():.0f}")
    print(f"  File 2 index range: {duplicate_mapping_df['file2_index'].min():.0f} - {duplicate_mapping_df['file2_index'].max():.0f}")

if len(unique_to_file1) > 0:
    print(f"\nUnique to File 1:")
    print(f"  Index range: {unique_to_file1['_original_index_file1'].min():.0f} - {unique_to_file1['_original_index_file1'].max():.0f}")

if len(unique_to_file2) > 0:
    print(f"\nUnique to File 2:")
    print(f"  Index range: {unique_to_file2['_original_index_file2'].min():.0f} - {unique_to_file2['_original_index_file2'].max():.0f}")

print("\nAnalysis complete!")
# Out:
# ================================================================================
# CSV FILES COMPARISON ANALYSIS
# ================================================================================
#
# File 1 (screened_1152.csv): 1152 records
# File 2 (screened_1180.csv): 1180 records
#
# ================================================================================
# RESULTS
# ================================================================================
#
# Total records in File 1 (cleaned): 1152
# Total records in File 2 (cleaned): 1180
#
# Duplicates (in both files): 1052
# Unique to File 1 only: 100
# Unique to File 2 only: 128
#
# Total unique records across both files: 1280
#
# Duplicates as % of File 1: 91.32%
# Duplicates as % of File 2: 89.15%
#
# ================================================================================
# SAMPLE DUPLICATES WITH INDICES (first 10)
# ================================================================================
#  file1_index  file2_index                                                                                                                                                                                                  title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       authors  year                                                                          doi
#          905          758                                                            examining the impact of artificial intelligence adoption on it project success in pakistan  the moderating role of employee skill readiness                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            M Alam, SF Amjad, A Younas… - Bulletin of …, 2025 - bulletinofmanagementreview.com  2025 http://www.bulletinofmanagementreview.com/index.php/Journal/article/view/138
#         1051          960                                                                                                                                       risk assessment and management using machine learning approaches                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        S. Darandale; R. Mehta  2022                                             10.1109/ICAAIC53929.2022.9792870
#          113         1102 teaching computing for complex problems in civil engineering and geosciences using big data and machine learning  synergizing four different computing paradigms and four different management domains Zoran BabovićBranislav BajatDusan BaracVesna BenginVladan ĐokićFilip ĐorđevićDražen DraškovićNenad FilipovićStephan FrenchBorko FurhtMarija IlićAyhan IrfanogluAleksandar KarteljMilan KilibardaGerhard KlimeckNenad KorolijaMiloš KotlarMiloš KovačevićVladan KuzmanovićJean-Marie LehnDejan MadićMarko MarinkovićMiodrag MateljevićAvi MendelsonFedor MesingerGradimir MilovanovićVeljko MilutinovićNenad MitićAleksandar NeškovićNataša NeškovićBoško NikolićKonstantin NovoselovArun PrakashJelica ProtićIvan RatkovićDiego RiosDan ShechtmanZoran StojadinovićAndrey UstyuzhaninStan Zak  2023                                                   10.1186/s40537-023-00730-7
#          217          172                                                                                         ontology based approach to risk factor identification to support the management of provisions in bridge design                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Hassan, F.U.; Le, T.  2023                                           10.1061/(ASCE)LA.1943-4170.0000574
#          510          382                                                                                                                                                            data analytics in agile project managements                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Radu, Laura-Diana and Popescul, Daniela  2025                                                      10.1145/3700706.3700708
#          776          630                                                                                                                            leveraging big data from open source to improve software project management                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     J Jagtiani, C Bach, C Huntley - IEEE Engineering Management …, 2018 - ieeexplore.ieee.org  2025                       https://ieeexplore.ieee.org/abstract/document/8334870/
#          893          746                                                                                                                                              software engineering expert system for global development                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     DB Simmons, NK Ma - … on Tools with Artificial Intelligence …, 2006 - ieeexplore.ieee.org  2025                       https://ieeexplore.ieee.org/abstract/document/4031877/
#          964          814                                                                                                                          question crafting system for personalized learning using large language model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  R Dhanalakshmi, M Akhil, G Chethan… - 2025 6th …, 2025 - ieeexplore.ieee.org  2025                      https://ieeexplore.ieee.org/abstract/document/11089510/
#           78         1071                                                                                                             exploring the challenges and software risks of agile methodologies in software development                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Neha ChoudharyMahaveer SainSumitra Chopra  2025                                                 10.1007/978-981-97-5200-3_39
#          339           99                                                                                                                           automatic classification of recurring tasks in software development projects                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Wysocki, W.; Ochodek, M.  2024                                                 10.1109/SEAA64295.2024.00076
#
# ================================================================================
# SAMPLE UNIQUE TO FILE 1 WITH INDICES (first 5)
# ================================================================================
#  _original_index_file1                                                                                                                                                      title                                                                                           authors  year                                         doi
#                      2                                    leveraging llm based data augmentation for automatic classification of recurring tasks in software development projects                                                          Włodzimierz Wysocki and Mirosław Ochodek  2026   https://doi.org/10.1016/j.jss.2025.112641
#                      3                                                            using automation and artificial intelligence in the management of european social fund projects                                                 Matei Oliviu and Laura Andreica and Faragau Tudor  2025 https://doi.org/10.1016/j.procs.2025.02.333
#                      7                                                                     verification and validation for data marketplaces via a blockchain and smart contracts                                                                                      Will Serrano  2022  https://doi.org/10.1016/j.bcra.2022.100100
#                     10 cross platform epc collaboration framework for construction management of pumped storage hydropower utilizing industry foundation classes and semantic web Sherong Zhang and Shihang Zhang and Zhengqiao Wu and Chao Wang and Zhiyong Jiang and Xiaohua Wang  2025  https://doi.org/10.1016/j.tust.2025.106692
#                     15                                                                               a new approach for competency frameworks mapping using large language models                              Imene Jemal and Naoussi Sijou Wilfried Armand and Belkacem Chikhaoui  2025  https://doi.org/10.1016/j.eswa.2024.125648
#
# ================================================================================
# SAMPLE UNIQUE TO FILE 2 WITH INDICES (first 5)
# ================================================================================
#  _original_index_file2                                                                                              title                                                                authors  year                          doi
#                      1    enhancing software effort estimation with random forest tuning and adaptive decision strategies              Priya Varshini, A.G.; Anitha Kumari, K.; Ramakrishnan, S.  2025   10.1038/s41598-025-14372-7
#                      3 benchmarking large language models for automated labeling  the case of issue report classification                               Colavito, G.; Lanubile, F.; Novielli, N.  2025 10.1016/j.infsof.2025.107758
#                      5                            success with agile project management  looking back and into the future                                 Koudriachov, C.; Tam, C.; Aparicio, M.  2025    10.1016/j.jss.2025.112428
#                      7 mediating between human programmers and integrated development environments using llm based agents                                                                 Li, Z.  2025      10.1145/3696630.3731460
#                     10       data driven predictive modelling of agile projects using explainable artificial intelligence ForouzeshNejad, A.A.; Arabikhan, F.; Gegov, A.; Jafari, R.; Ichtev, A.  2025  10.3390/electronics14132609
#
# ================================================================================
# SAVING RESULTS TO CSV FILES
# ================================================================================
# ✓ Saved duplicates_with_indices.csv (1052 records)
# ✓ Saved duplicates_file1_with_index.csv (1052 records from File 1)
# ✓ Saved unique_to_file1_with_index.csv (100 records)
# ✓ Saved unique_to_file2_with_index.csv (128 records)
#
# ================================================================================
# INDEX SUMMARY
# ================================================================================
#
# Duplicates:
#   File 1 index range: 0 - 1151
#   File 2 index range: 0 - 1178
#
# Unique to File 1:
#   Index range: 2 - 1149
#
# Unique to File 2:
#   Index range: 1 - 1179
#
# Analysis complete!

# %% [markdown]
# # **Comparing SPARK 398 papers with our 480 papers.**

# %%
# !pip install pandas openpyxl fuzzywuzzy python-Levenshtein
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.12/dist-packages (0.18.0)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.12/dist-packages (0.27.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: Levenshtein==0.27.1 in /usr/local/lib/python3.12/dist-packages (from python-Levenshtein) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from Levenshtein==0.27.1->python-Levenshtein) (3.14.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import re
from fuzzywuzzy import fuzz
import openpyxl

def preprocess_text(text):
    """
    Preprocess text by removing special characters, converting to lowercase,
    and removing extra whitespaces
    """
    if pd.isna(text) or text == '':
        return ""

    # Convert to string and lowercase
    text = str(text).lower()

    # Remove special characters and extra spaces
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()

    return text

def compare_records(record1_title, record1_abstract, record2_title, record2_abstract,
                   title_threshold=90, abstract_threshold=80):
    """
    Compare two records based on title and abstract similarity
    Returns True if records are considered duplicates
    """
    # Preprocess texts
    title1 = preprocess_text(record1_title)
    abstract1 = preprocess_text(record1_abstract)
    title2 = preprocess_text(record2_title)
    abstract2 = preprocess_text(record2_abstract)

    # Check title similarity
    title_similarity = fuzz.ratio(title1, title2)

    # Check abstract similarity
    abstract_similarity = fuzz.ratio(abstract1, abstract2)

    # Consider as duplicate if:
    # 1. Title similarity >= title_threshold, OR
    # 2. Both title similarity >= 70 AND abstract similarity >= abstract_threshold

    if title_similarity >= title_threshold:
        return True, title_similarity, abstract_similarity
    elif title_similarity >= 70 and abstract_similarity >= abstract_threshold:
        return True, title_similarity, abstract_similarity
    else:
        return False, title_similarity, abstract_similarity

def find_duplicates_between_files(file1_path, file2_path, output_path):
    """
    Main function to compare two XLSX files and find duplicates
    """
    try:
        # Read the two XLSX files
        print("Loading files...")
        df1 = pd.read_excel(file1_path)
        df2 = pd.read_excel(file2_path)

        print(f"File 1: {len(df1)} records")
        print(f"File 2: {len(df2)} records")

        # Ensure required columns exist
        required_cols = ['title', 'abstract']
        for col in required_cols:
            if col not in df1.columns:
                raise ValueError(f"Column '{col}' not found in file 1")
            if col not in df2.columns:
                raise ValueError(f"Column '{col}' not found in file 2")

        # Create result dataframe based on file 1
        result_df = df1.copy()

        # Add new columns for comparison results
        result_df['duplicate_status'] = ''
        result_df['file2_row_number'] = ''
        result_df['title_similarity'] = ''
        result_df['abstract_similarity'] = ''

        print("Comparing records...")

        # Compare each record in file1 with all records in file2
        for idx1, row1 in df1.iterrows():
            print(f"Processing record {idx1 + 1}/{len(df1)}")

            best_match_found = False
            best_match_row = None
            best_title_sim = 0
            best_abstract_sim = 0

            # Compare with each record in file2
            for idx2, row2 in df2.iterrows():
                is_duplicate, title_sim, abstract_sim = compare_records(
                    row1['title'], row1['abstract'],
                    row2['title'], row2['abstract']
                )

                if is_duplicate:
                    # If this is the first match or a better match, update
                    if not best_match_found or title_sim > best_title_sim:
                        best_match_found = True
                        best_match_row = idx2 + 2  # +2 because Excel rows start from 1 and we have header
                        best_title_sim = title_sim
                        best_abstract_sim = abstract_sim

            # Update result dataframe
            if best_match_found:
                result_df.at[idx1, 'duplicate_status'] = 'Duplicate Found'
                result_df.at[idx1, 'file2_row_number'] = best_match_row
                result_df.at[idx1, 'title_similarity'] = f"{best_title_sim}%"
                result_df.at[idx1, 'abstract_similarity'] = f"{best_abstract_sim}%"
            else:
                result_df.at[idx1, 'duplicate_status'] = 'Unique/New/Not a duplicate'
                result_df.at[idx1, 'file2_row_number'] = 'N/A'
                result_df.at[idx1, 'title_similarity'] = 'N/A'
                result_df.at[idx1, 'abstract_similarity'] = 'N/A'

        # Save results
        print(f"Saving results to {output_path}")
        result_df.to_excel(output_path, index=False, engine='openpyxl')

        # Print summary statistics
        duplicates_found = len(result_df[result_df['duplicate_status'] == 'Duplicate Found'])
        unique_records = len(result_df[result_df['duplicate_status'] == 'Unique/New/Not a duplicate'])

        print(f"\n=== COMPARISON RESULTS ===")
        print(f"Total records in File 1: {len(df1)}")
        print(f"Duplicates found: {duplicates_found}")
        print(f"Unique records: {unique_records}")
        print(f"Duplicate percentage: {(duplicates_found/len(df1))*100:.2f}%")
        print(f"Results saved to: {output_path}")

        return result_df

    except Exception as e:
        print(f"Error occurred: {e}")
        return None

# Example usage
if __name__ == "__main__":
    # Specify file paths
    file1_path = "spark_papers.xlsx"  # Replace with your actual file path
    file2_path = "our_papers.xlsx"  # Replace with your actual file path
    output_path = "comparison_results.xlsx"

    # Run the comparison
    results = find_duplicates_between_files(file1_path, file2_path, output_path)

    if results is not None:
        print("\nComparison completed successfully!")
        print("\nFirst few results:")
        print(results[['title', 'duplicate_status', 'file2_row_number', 'title_similarity']].head())
    else:
        print("Comparison failed. Please check your file paths and formats.")
# Out:
# Loading files...
# File 1: 398 records
# File 2: 480 records
# Comparing records...
# Processing record 1/398
# Processing record 2/398
# Processing record 3/398
# Processing record 4/398
# Processing record 5/398
# Processing record 6/398
# Processing record 7/398
# Processing record 8/398
# Processing record 9/398
# Processing record 10/398
# Processing record 11/398
# Processing record 12/398
# Processing record 13/398
# Processing record 14/398
# Processing record 15/398
# Processing record 16/398
# Processing record 17/398
# Processing record 18/398
# Processing record 19/398
# Processing record 20/398
# Processing record 21/398
# Processing record 22/398
# Processing record 23/398
# Processing record 24/398
# Processing record 25/398
# Processing record 26/398
# Processing record 27/398
# Processing record 28/398
# Processing record 29/398
# Processing record 30/398
# Processing record 31/398
# Processing record 32/398
# Processing record 33/398
# Processing record 34/398
# Processing record 35/398
# Processing record 36/398
# Processing record 37/398
# Processing record 38/398
# Processing record 39/398
# Processing record 40/398
# Processing record 41/398
# Processing record 42/398
# Processing record 43/398
# Processing record 44/398
# Processing record 45/398
# Processing record 46/398
# Processing record 47/398
# Processing record 48/398
# Processing record 49/398
# Processing record 50/398
# Processing record 51/398
# Processing record 52/398
# Processing record 53/398
# Processing record 54/398
# Processing record 55/398
# Processing record 56/398
# Processing record 57/398
# Processing record 58/398
# Processing record 59/398
# Processing record 60/398
# Processing record 61/398
# Processing record 62/398
# Processing record 63/398
# Processing record 64/398
# Processing record 65/398
# Processing record 66/398
# Processing record 67/398
# Processing record 68/398
# Processing record 69/398
# Processing record 70/398
# Processing record 71/398
# Processing record 72/398
# Processing record 73/398
# Processing record 74/398
# Processing record 75/398
# Processing record 76/398
# Processing record 77/398
# Processing record 78/398
# Processing record 79/398
# Processing record 80/398
# Processing record 81/398
# Processing record 82/398
# Processing record 83/398
# Processing record 84/398
# Processing record 85/398
# Processing record 86/398
# Processing record 87/398
# Processing record 88/398
# Processing record 89/398
# Processing record 90/398
# Processing record 91/398
# Processing record 92/398
# Processing record 93/398
# Processing record 94/398
# Processing record 95/398
# Processing record 96/398
# Processing record 97/398
# Processing record 98/398
# Processing record 99/398
# Processing record 100/398
# Processing record 101/398
# Processing record 102/398
# Processing record 103/398
# Processing record 104/398
# Processing record 105/398
# Processing record 106/398
# Processing record 107/398
# Processing record 108/398
# Processing record 109/398
# Processing record 110/398
# Processing record 111/398
# Processing record 112/398
# Processing record 113/398
# Processing record 114/398
# Processing record 115/398
# Processing record 116/398
# Processing record 117/398
# Processing record 118/398
# Processing record 119/398
# Processing record 120/398
# Processing record 121/398
# Processing record 122/398
# Processing record 123/398
# Processing record 124/398
# Processing record 125/398
# Processing record 126/398
# Processing record 127/398
# Processing record 128/398
# Processing record 129/398
# Processing record 130/398
# Processing record 131/398
# Processing record 132/398
# Processing record 133/398
# Processing record 134/398
# Processing record 135/398
# Processing record 136/398
# Processing record 137/398
# Processing record 138/398
# Processing record 139/398
# Processing record 140/398
# Processing record 141/398
# Processing record 142/398
# Processing record 143/398
# Processing record 144/398
# Processing record 145/398
# Processing record 146/398
# Processing record 147/398
# Processing record 148/398
# Processing record 149/398
# Processing record 150/398
# Processing record 151/398
# Processing record 152/398
# Processing record 153/398
# Processing record 154/398
# Processing record 155/398
# Processing record 156/398
# Processing record 157/398
# Processing record 158/398
# Processing record 159/398
# Processing record 160/398
# Processing record 161/398
# Processing record 162/398
# Processing record 163/398
# Processing record 164/398
# Processing record 165/398
# Processing record 166/398
# Processing record 167/398
# Processing record 168/398
# Processing record 169/398
# Processing record 170/398
# Processing record 171/398
# Processing record 172/398
# Processing record 173/398
# Processing record 174/398
# Processing record 175/398
# Processing record 176/398
# Processing record 177/398
# Processing record 178/398
# Processing record 179/398
# Processing record 180/398
# Processing record 181/398
# Processing record 182/398
# Processing record 183/398
# Processing record 184/398
# Processing record 185/398
# Processing record 186/398
# Processing record 187/398
# Processing record 188/398
# Processing record 189/398
# Processing record 190/398
# Processing record 191/398
# Processing record 192/398
# Processing record 193/398
# Processing record 194/398
# Processing record 195/398
# Processing record 196/398
# Processing record 197/398
# Processing record 198/398
# Processing record 199/398
# Processing record 200/398
# Processing record 201/398
# Processing record 202/398
# Processing record 203/398
# Processing record 204/398
# Processing record 205/398
# Processing record 206/398
# Processing record 207/398
# Processing record 208/398
# Processing record 209/398
# Processing record 210/398
# Processing record 211/398
# Processing record 212/398
# Processing record 213/398
# Processing record 214/398
# Processing record 215/398
# Processing record 216/398
# Processing record 217/398
# Processing record 218/398
# Processing record 219/398
# Processing record 220/398
# Processing record 221/398
# Processing record 222/398
# Processing record 223/398
# Processing record 224/398
# Processing record 225/398
# Processing record 226/398
# Processing record 227/398
# Processing record 228/398
# Processing record 229/398
# Processing record 230/398
# Processing record 231/398
# Processing record 232/398
# Processing record 233/398
# Processing record 234/398
# Processing record 235/398
# Processing record 236/398
# Processing record 237/398
# Processing record 238/398
# Processing record 239/398
# Processing record 240/398
# Processing record 241/398
# Processing record 242/398
# Processing record 243/398
# Processing record 244/398
# Processing record 245/398
# Processing record 246/398
# Processing record 247/398
# Processing record 248/398
# Processing record 249/398
# Processing record 250/398
# Processing record 251/398
# Processing record 252/398
# Processing record 253/398
# Processing record 254/398
# Processing record 255/398
# Processing record 256/398
# Processing record 257/398
# Processing record 258/398
# Processing record 259/398
# Processing record 260/398
# Processing record 261/398
# Processing record 262/398
# Processing record 263/398
# Processing record 264/398
# Processing record 265/398
# Processing record 266/398
# Processing record 267/398
# Processing record 268/398
# Processing record 269/398
# Processing record 270/398
# Processing record 271/398
# Processing record 272/398
# Processing record 273/398
# Processing record 274/398
# Processing record 275/398
# Processing record 276/398
# Processing record 277/398
# Processing record 278/398
# Processing record 279/398
# Processing record 280/398
# Processing record 281/398
# Processing record 282/398
# Processing record 283/398
# Processing record 284/398
# Processing record 285/398
# Processing record 286/398
# Processing record 287/398
# Processing record 288/398
# Processing record 289/398
# Processing record 290/398
# Processing record 291/398
# Processing record 292/398
# Processing record 293/398
# Processing record 294/398
# Processing record 295/398
# Processing record 296/398
# Processing record 297/398
# Processing record 298/398
# Processing record 299/398
# Processing record 300/398
# Processing record 301/398
# Processing record 302/398
# Processing record 303/398
# Processing record 304/398
# Processing record 305/398
# Processing record 306/398
# Processing record 307/398
# Processing record 308/398
# Processing record 309/398
# Processing record 310/398
# Processing record 311/398
# Processing record 312/398
# Processing record 313/398
# Processing record 314/398
# Processing record 315/398
# Processing record 316/398
# Processing record 317/398
# Processing record 318/398
# Processing record 319/398
# Processing record 320/398
# Processing record 321/398
# Processing record 322/398
# Processing record 323/398
# Processing record 324/398
# Processing record 325/398
# Processing record 326/398
# Processing record 327/398
# Processing record 328/398
# Processing record 329/398
# Processing record 330/398
# Processing record 331/398
# Processing record 332/398
# Processing record 333/398
# Processing record 334/398
# Processing record 335/398
# Processing record 336/398
# Processing record 337/398
# Processing record 338/398
# Processing record 339/398
# Processing record 340/398
# Processing record 341/398
# Processing record 342/398
# Processing record 343/398
# Processing record 344/398
# Processing record 345/398
# Processing record 346/398
# Processing record 347/398
# Processing record 348/398
# Processing record 349/398
# Processing record 350/398
# Processing record 351/398
# Processing record 352/398
# Processing record 353/398
# Processing record 354/398
# Processing record 355/398
# Processing record 356/398
# Processing record 357/398
# Processing record 358/398
# Processing record 359/398
# Processing record 360/398
# Processing record 361/398
# Processing record 362/398
# Processing record 363/398
# Processing record 364/398
# Processing record 365/398
# Processing record 366/398
# Processing record 367/398
# Processing record 368/398
# Processing record 369/398
# Processing record 370/398
# Processing record 371/398
# Processing record 372/398
# Processing record 373/398
# Processing record 374/398
# Processing record 375/398
# Processing record 376/398
# Processing record 377/398
# Processing record 378/398
# Processing record 379/398
# Processing record 380/398
# Processing record 381/398
# Processing record 382/398
# Processing record 383/398
# Processing record 384/398
# Processing record 385/398
# Processing record 386/398
# Processing record 387/398
# Processing record 388/398
# Processing record 389/398
# Processing record 390/398
# Processing record 391/398
# Processing record 392/398
# Processing record 393/398
# Processing record 394/398
# Processing record 395/398
# Processing record 396/398
# Processing record 397/398
# Processing record 398/398
# Saving results to comparison_results.xlsx
#
# === COMPARISON RESULTS ===
# Total records in File 1: 398
# Duplicates found: 183
# Unique records: 215
# Duplicate percentage: 45.98%
# Results saved to: comparison_results.xlsx
#
# Comparison completed successfully!
#
# First few results:
#                                                title  \
# 0  developing an ai readiness model for software ...
# 1  software project management using machine lear...
# 2  a systematic short review of machine learning ...
# 3  online solution based on machine learning for ...
# 4  ai powered it project management  analyzing th...
#
#              duplicate_status file2_row_number title_similarity
# 0  Unique/New/Not a duplicate              N/A              N/A
# 1  Unique/New/Not a duplicate              N/A              N/A
# 2  Unique/New/Not a duplicate              N/A              N/A
# 3  Unique/New/Not a duplicate              N/A              N/A
# 4  Unique/New/Not a duplicate              N/A              N/A

# %%
# !rm -rf *

# %% [markdown]
# # **Converting CSV to XLSX.**

# %%
import pandas as pd

# Replace with your CSV file path
csv_file = "Screened_Original_Metadata.csv"
xlsx_file = "Title_Abstract_Screening_128.xlsx"

# Read CSV
try:
    df = pd.read_csv(csv_file, quotechar='"', doublequote=True)
except pd.errors.ParserError as e:
    print(f"ParserError: {e}")
    print("Trying to read with a different engine...")
    try:
        df = pd.read_csv(csv_file, engine='python', quotechar='"', doublequote=True)
    except Exception as e_python:
        print(f"Error with python engine: {e_python}")
        print("Could not read the CSV file with either engine.")
        exit()


# Write to Excel
df.to_excel(xlsx_file, index=False, engine="openpyxl")

print(f"CSV file '{csv_file}' has been converted to Excel file '{xlsx_file}'")
# Out:
# CSV file 'Screened_Original_Metadata.csv' has been converted to Excel file 'Title_Abstract_Screening_128.xlsx'

# %% [markdown]
# # For Phase II, retriving Abstracts from Springer Nature Link data

# %% [markdown]
# Simple query-based data extraction does not provide with the abstract of the papers.
#
# For this reason, we are usign API to scrap data and get abstract as well.

# %% [markdown]
# my springer link API key = 7702ae00e440dd5248edaa25791da70c

# %%
import requests, pandas as pd

# Replace with your actual API key or use Google Colab secrets
api_key = "7702ae00e440dd5248edaa25791da70c" # Make sure this is your valid API key
df = pd.read_csv("Springer.csv")

abstracts = []
for doi in df['Item DOI']:
    # Ensure the DOI is not a float or NaN
    if pd.notna(doi) and isinstance(doi, str):
        url = f"https://api.springernature.com/meta/v2/json?q=doi:{doi}&api_key={api_key}"
        r = requests.get(url).json()
        # Check if 'records' key exists in the response before accessing it
        if 'records' in r and r['records']:
            abstracts.append(r['records'][0].get('abstract', ''))
        else:
            abstracts.append('')
    else:
        abstracts.append('') # Append empty string if DOI is invalid

df['Abstract'] = abstracts
df.to_csv("springer_results_with_abstract.csv", index=False)

# %% [markdown]
# # Converting .bib file into .csv file

# %%
# !pip install bibtexparser
# Out:
# Collecting bibtexparser
#   Downloading bibtexparser-1.4.3.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from bibtexparser) (3.2.5)
# Building wheels for collected packages: bibtexparser
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.3-py3-none-any.whl size=43549 sha256=3543aebe525cdd9c2f6ec81eb4bf25b94be608995b87ccb058fe222fc5ac2b65
#   Stored in directory: /root/.cache/pip/wheels/1f/7d/e9/1ff2509f13767a55df1279744adfb757f4ab94b2cbe761f56a
# Successfully built bibtexparser
# Installing collected packages: bibtexparser
# Successfully installed bibtexparser-1.4.3

# %%
# ============================
# Convert .bib → .csv
# ============================

import bibtexparser
import pandas as pd

# 1. Path to your BibTeX file
input_bib = "DBLP.bib"
output_csv = "dblp.csv"

# 2. Load and parse the .bib file
with open(input_bib, encoding="utf-8") as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)

# 3. Each entry is a dictionary of all fields (title, author, abstract, etc.)
entries = bib_database.entries

# 4. Convert to DataFrame
df = pd.DataFrame(entries)

# 5. Optional: Reorder common columns for readability (others will still be preserved)
preferred_order = [
    "ID", "ENTRYTYPE", "title", "author", "year", "journal", "booktitle",
    "volume", "number", "pages", "doi", "url", "keywords", "abstract", "note"
]
cols = [c for c in preferred_order if c in df.columns] + [c for c in df.columns if c not in preferred_order]
df = df[cols]

# 6. Save to CSV
df.to_csv(output_csv, index=False, encoding="utf-8")

print(f"✅ Successfully converted {len(df)} records to '{output_csv}'")
print(f"Fields preserved: {len(df.columns)} columns")
# Out:
# ✅ Successfully converted 711 records to 'dblp.csv'
# Fields preserved: 24 columns

# %% [markdown]
# # Scrapping abstract for DBLP meta-data

# %%
# =====================================
# Enrich DBLP CSV with abstracts via DOI
# =====================================

import requests
import pandas as pd
import time

# === Configuration ===
input_csv = "dblp.csv"      # Your existing metadata file
output_csv = "dblp_with_abstracts.csv"
sleep_time = 0.5                    # delay between API calls (avoid rate-limit)

# === Load data ===
df = pd.read_csv(input_csv)

# Ensure DOI column exists
if 'doi' not in df.columns:
    raise ValueError("❌ No 'DOI' column found in the input CSV.")

# Prepare list for abstracts
abstracts = []

# === Function to get abstract from Semantic Scholar ===
def get_abstract_from_semanticscholar(doi):
    try:
        url = f"https://api.semanticscholar.org/graph/v1/paper/DOI:{doi}?fields=title,abstract"
        r = requests.get(url, timeout=15)
        if r.status_code == 200:
            data = r.json()
            return data.get('abstract', '')
        return ''
    except Exception as e:
        print(f"Error fetching from Semantic Scholar for DOI {doi}: {e}")
        return ''

# === (Optional) Function to get abstract from Crossref if missing ===
def get_abstract_from_crossref(doi):
    try:
        url = f"https://api.crossref.org/works/{doi}"
        r = requests.get(url, timeout=15)
        if r.status_code == 200:
            data = r.json()
            abstract = data['message'].get('abstract', '')
            # Abstracts from Crossref often contain HTML tags like <jats:p>
            return abstract.replace('<jats:p>', '').replace('</jats:p>', '').strip()
        return ''
    except Exception as e:
        print(f"Error fetching from Crossref for DOI {doi}: {e}")
        return ''

# === Loop through all rows ===
for idx, row in df.iterrows():
    doi = str(row['doi']).strip()
    if not doi or doi.lower() == 'nan':
        abstracts.append('')
        continue

    print(f"[{idx+1}/{len(df)}] Fetching abstract for DOI: {doi}")

    abstract = get_abstract_from_semanticscholar(doi)

    # Fallback to Crossref if Semantic Scholar gives nothing
    if not abstract:
        abstract = get_abstract_from_crossref(doi)

    abstracts.append(abstract)
    time.sleep(sleep_time)

# === Add new column and save ===
df['Abstract'] = abstracts
df.to_csv(output_csv, index=False, encoding='utf-8')

print(f"\n✅ Done! Abstracts added for {sum(bool(a) for a in abstracts)} papers.")
print(f"💾 Saved enriched dataset to: {output_csv}")
# Out:
# [1/711] Fetching abstract for DOI: 10.1016/J.FUTURE.2025.108056
# [2/711] Fetching abstract for DOI: 10.1016/J.JSS.2025.112641
# [3/711] Fetching abstract for DOI: 10.1109/ACCESS.2025.3586203
# [4/711] Fetching abstract for DOI: 10.1007/S10515-025-00500-0
# [5/711] Fetching abstract for DOI: 10.1111/CGF.70123
# [6/711] Fetching abstract for DOI: 10.1007/S10586-025-05383-0
# [7/711] Fetching abstract for DOI: 10.1109/MCOM.002.2400276
# [8/711] Fetching abstract for DOI: 10.1109/MC.2025.3546204
# [9/711] Fetching abstract for DOI: 10.3389/FCOMP.2025.1519437
# [10/711] Fetching abstract for DOI: 10.3389/FRAI.2025.1474017
# [11/711] Fetching abstract for DOI: 10.1016/J.IJHCS.2025.103602
# [12/711] Fetching abstract for DOI: 10.1016/J.INFSOF.2025.107832
# [13/711] Fetching abstract for DOI: 10.1016/J.INFSOF.2025.107803
# [14/711] Fetching abstract for DOI: 10.1109/JIOT.2024.3521425
# [15/711] Fetching abstract for DOI: 10.1109/JIOT.2025.3531512
# [16/711] Fetching abstract for DOI: 10.1186/S40537-025-01209-3
# [17/711] Fetching abstract for DOI: 10.1016/J.JSS.2025.112452
# [18/711] Fetching abstract for DOI: 10.1016/J.JSS.2025.112581
# [19/711] Fetching abstract for DOI: 10.1016/J.KNOSYS.2025.114184
# [20/711] Fetching abstract for DOI: 10.1145/3709703
# [21/711] Fetching abstract for DOI: 10.1145/3728922
# [22/711] Fetching abstract for DOI: 10.1145/3728984
# [23/711] Fetching abstract for DOI: 10.1145/3728963
# [24/711] Fetching abstract for DOI: 10.1145/3715754
# [25/711] Fetching abstract for DOI: 10.1145/3729386
# [27/711] Fetching abstract for DOI: 10.1145/3759441.3759446
# [28/711] Fetching abstract for DOI: 10.1016/J.SOFTX.2025.102290
# [29/711] Fetching abstract for DOI: 10.1016/J.SOFTX.2025.102260
# [30/711] Fetching abstract for DOI: 10.1016/J.SOFTX.2025.102278
# [31/711] Fetching abstract for DOI: 10.1016/J.SOFTX.2025.102121
# [32/711] Fetching abstract for DOI: 10.1016/J.SOFTX.2024.102029
# [33/711] Fetching abstract for DOI: 10.1016/J.SOFTX.2025.102194
# [35/711] Fetching abstract for DOI: 10.1109/MTS.2025.3583233
# [36/711] Fetching abstract for DOI: 10.1145/3712003
# [37/711] Fetching abstract for DOI: 10.1109/TSE.2025.3555622
# [38/711] Fetching abstract for DOI: 10.1109/TSE.2025.3586082
# [39/711] Fetching abstract for DOI: 10.1109/TSE.2025.3569086
# [40/711] Fetching abstract for DOI: 10.1109/TSE.2025.3548168
# [41/711] Fetching abstract for DOI: 10.1109/TSE.2024.3519159
# [42/711] Fetching abstract for DOI: 10.1109/TSE.2025.3591791
# [43/711] Fetching abstract for DOI: 10.1109/TSE.2025.3543187
# [44/711] Fetching abstract for DOI: 10.1109/TSE.2025.3562025
# [45/711] Fetching abstract for DOI: 10.1109/TSE.2025.3554562
# [46/711] Fetching abstract for DOI: 10.1109/TSE.2025.3590108
# [47/711] Fetching abstract for DOI: 10.1109/TVCG.2025.3586689
# [48/711] Fetching abstract for DOI: 10.1109/TVCG.2025.3567131
# [49/711] Fetching abstract for DOI: 10.1016/J.WEBSEM.2024.100853
# [50/711] Fetching abstract for DOI: 10.1109/SSE67621.2025.00024
# [51/711] Fetching abstract for DOI: 10.1609/AAAI.V39I28.35147
# [52/711] Fetching abstract for DOI: 10.1609/AAAI.V39I22.34531
# [53/711] Fetching abstract for DOI: 10.1609/AAAI.V39I23.34587
# [54/711] Fetching abstract for DOI: 10.1609/AAAI.V39I28.35234
# [63/711] Fetching abstract for DOI: 10.1007/978-3-031-98462-4\_42
# [64/711] Fetching abstract for DOI: 10.1145/3676641.3716245
# [65/711] Fetching abstract for DOI: 10.1145/3669940.3707256
# [66/711] Fetching abstract for DOI: 10.1007/978-3-031-94590-8\_33
# [67/711] Fetching abstract for DOI: 10.1109/CASE58245.2025.11164106
# [68/711] Fetching abstract for DOI: 10.1145/3706598.3713606
# [69/711] Fetching abstract for DOI: 10.1145/3706599.3721169
# [70/711] Fetching abstract for DOI: 10.1145/3706598.3713932
# [71/711] Fetching abstract for DOI: 10.1145/3706599.3720197
# [72/711] Fetching abstract for DOI: 10.1145/3706599.3720027
# [73/711] Fetching abstract for DOI: 10.1145/3706599.3720263
# [74/711] Fetching abstract for DOI: 10.1145/3706598.3714261
# [75/711] Fetching abstract for DOI: 10.1145/3715928.3737479
# [76/711] Fetching abstract for DOI: 10.1109/COMPSAC65507.2025.00310
# [77/711] Fetching abstract for DOI: 10.1109/COMPSAC65507.2025.00024
# [78/711] Fetching abstract for DOI: 10.1109/COMPSAC65507.2025.00175
# [79/711] Fetching abstract for DOI: 10.1109/CSCWD64889.2025.11033648
# [80/711] Fetching abstract for DOI: 10.5220/0013435800003932
# [81/711] Fetching abstract for DOI: 10.1109/CSR64739.2025.11130174
# [82/711] Fetching abstract for DOI: 10.1109/CSR64739.2025.11130171
# [84/711] Fetching abstract for DOI: 10.1109/DAC63849.2025.11133193
# [85/711] Fetching abstract for DOI: 10.23919/DATE64628.2025.10993129
# [86/711] Fetching abstract for DOI: 10.1109/DDECS63720.2025.11006767
# [87/711] Fetching abstract for DOI: 10.1145/3735654.3735937
# [88/711] Fetching abstract for DOI: 10.1145/3735654.3735942
# [89/711] Fetching abstract for DOI: 10.1007/978-3-032-02049-9\_9
# [90/711] Fetching abstract for DOI: 10.1109/DSN-S65789.2025.00067
# [92/711] Fetching abstract for DOI: 10.1007/978-3-032-02138-0\_5
# [93/711] Fetching abstract for DOI: 10.1007/978-3-032-04403-7\_14
# [94/711] Fetching abstract for DOI: 10.1007/978-3-032-02138-0\_8
# [95/711] Fetching abstract for DOI: 10.1007/978-3-032-02138-0\_7
# [96/711] Fetching abstract for DOI: 10.1007/978-3-032-03870-8\_33
# [97/711] Fetching abstract for DOI: 10.1109/EDCC-C66476.2025.00034
# [98/711] Fetching abstract for DOI: 10.1109/EDUCON62633.2025.11016653
# [99/711] Fetching abstract for DOI: 10.1145/3679240.3734608
# [100/711] Fetching abstract for DOI: 10.1007/978-3-032-05179-0\_19
# [101/711] Fetching abstract for DOI: 10.1007/978-3-031-99872-0\_2
# [102/711] Fetching abstract for DOI: 10.1007/978-3-031-99857-7\_9
# [103/711] Fetching abstract for DOI: 10.1109/GI66624.2025.00012
# [104/711] Fetching abstract for DOI: 10.1007/978-3-031-92823-9\_16
# [105/711] Fetching abstract for DOI: 10.1109/ICAIIC64266.2025.10920709
# [106/711] Fetching abstract for DOI: 10.1109/ICCCN65249.2025.11133886
# [107/711] Fetching abstract for DOI: 10.1109/ICCE63647.2025.10930181
# [108/711] Fetching abstract for DOI: 10.1109/ICNC64010.2025.10994008
# [109/711] Fetching abstract for DOI: 10.1109/ICDEW67478.2025.00018
# [110/711] Fetching abstract for DOI: 10.1109/ICDE65448.2025.00316
# [111/711] Fetching abstract for DOI: 10.1109/ICDE65448.2025.00331
# [112/711] Fetching abstract for DOI: 10.5220/0013482600003929
# [117/711] Fetching abstract for DOI: 10.1109/ICSA-C65153.2025.00006
# [118/711] Fetching abstract for DOI: 10.1109/ICSA-C65153.2025.00049
# [119/711] Fetching abstract for DOI: 10.1109/ICSE-SEIP66354.2025.00051
# [120/711] Fetching abstract for DOI: 10.1109/ICSE-SEIS66351.2025.00023
# [121/711] Fetching abstract for DOI: 10.1109/DESIGNING66910.2025.00007
# [122/711] Fetching abstract for DOI: 10.1109/ICSE-SEIS66351.2025.00022
# [123/711] Fetching abstract for DOI: 10.1109/ICSE-SEIS66351.2025.00014
# [124/711] Fetching abstract for DOI: 10.1109/ICSE55347.2025.00204
# [125/711] Fetching abstract for DOI: 10.1109/ICSE-COMPANION66252.2025.00069
# [126/711] Fetching abstract for DOI: 10.1109/ICSE55347.2025.00211
# [127/711] Fetching abstract for DOI: 10.5220/0013461900003964
# [128/711] Fetching abstract for DOI: 10.1109/ICSTW64639.2025.10962470
# [129/711] Fetching abstract for DOI: 10.1007/978-981-96-8889-0\_37
# [130/711] Fetching abstract for DOI: 10.1109/CAI64502.2025.00032
# [131/711] Fetching abstract for DOI: 10.1109/CAI64502.2025.00066
# [132/711] Fetching abstract for DOI: 10.24963/IJCAI.2025/814
# [133/711] Fetching abstract for DOI: 10.1109/IRI66576.2025.00027
# [134/711] Fetching abstract for DOI: 10.1109/IRI66576.2025.00009
# [135/711] Fetching abstract for DOI: 10.1145/3695053.3731057
# [136/711] Fetching abstract for DOI: 10.1109/ICPC66645.2025.00052
# [137/711] Fetching abstract for DOI: 10.1109/LLM4CODE66737.2025.00019
# [138/711] Fetching abstract for DOI: 10.1109/LLM4CODE66737.2025.00008
# [139/711] Fetching abstract for DOI: 10.1007/978-3-032-06004-4\_1
# [140/711] Fetching abstract for DOI: 10.1109/MSR66628.2025.00086
# [141/711] Fetching abstract for DOI: 10.1109/MSR66628.2025.00037
# [142/711] Fetching abstract for DOI: 10.1109/MSR66628.2025.00099
# [143/711] Fetching abstract for DOI: 10.18653/V1/2025.NAACL-SHORT.5
# [144/711] Fetching abstract for DOI: 10.18653/V1/2025.FINDINGS-NAACL.73
# [145/711] Fetching abstract for DOI: 10.18653/V1/2025.NAACL-LONG.273
# [146/711] Fetching abstract for DOI: 10.18653/V1/2025.NAACL-LONG.212
# [147/711] Fetching abstract for DOI: 10.18653/V1/2025.FINDINGS-NAACL.407
# [148/711] Fetching abstract for DOI: 10.1109/NLBSE66842.2025.00011
# [149/711] Fetching abstract for DOI: 10.1109/NOMS57970.2025.11073595
# [153/711] Fetching abstract for DOI: 10.1145/3766882.3767171
# [154/711] Fetching abstract for DOI: 10.1007/978-3-031-88531-0\_19
# [156/711] Fetching abstract for DOI: 10.1007/978-3-031-88531-0\_20
# [157/711] Fetching abstract for DOI: 10.1007/978-3-032-05435-7\_12
# [158/711] Fetching abstract for DOI: 10.1109/SANER64311.2025.00090
# [159/711] Fetching abstract for DOI: 10.1109/SANER64311.2025.00009
# [160/711] Fetching abstract for DOI: 10.1109/SANER64311.2025.00069
# [161/711] Fetching abstract for DOI: 10.1109/SANER64311.2025.00096
# [162/711] Fetching abstract for DOI: 10.1109/SATML64287.2025.00028
# [163/711] Fetching abstract for DOI: 10.1109/SATRENDS66715.2025.00006
# [164/711] Fetching abstract for DOI: 10.18420/SE2025-WS-12
# [165/711] Fetching abstract for DOI: 10.1145/3718958.3750537
# [166/711] Fetching abstract for DOI: 10.1145/3641554.3701841
# [167/711] Fetching abstract for DOI: 10.1145/3641555.3705183
# [168/711] Fetching abstract for DOI: 10.1145/3722212.3724492
# [169/711] Fetching abstract for DOI: 10.1145/3696630.3728699
# [170/711] Fetching abstract for DOI: 10.1145/3696630.3734199
# [171/711] Fetching abstract for DOI: 10.1145/3696630.3728719
# [172/711] Fetching abstract for DOI: 10.1145/3696630.3728714
# [173/711] Fetching abstract for DOI: 10.1145/3696630.3731432
# [174/711] Fetching abstract for DOI: 10.1145/3696630.3728717
# [175/711] Fetching abstract for DOI: 10.1145/3696630.3731666
# [176/711] Fetching abstract for DOI: 10.1145/3696630.3731671
# [177/711] Fetching abstract for DOI: 10.1145/3696630.3728492
# [178/711] Fetching abstract for DOI: 10.1145/3731569.3764823
# [180/711] Fetching abstract for DOI: 10.1145/3744915.3748460
# [181/711] Fetching abstract for DOI: 10.23919/TMA66427.2025.11097007
# [183/711] Fetching abstract for DOI: 10.1145/3746059.3747670
# [184/711] Fetching abstract for DOI: 10.1145/3708319.3733808
# [185/711] Fetching abstract for DOI: 10.1109/WCNC61545.2025.10978505
# [186/711] Fetching abstract for DOI: 10.29327/1588952.28-12
# [187/711] Fetching abstract for DOI: 10.1109/WSESE66602.2025.00010
# [188/711] Fetching abstract for DOI: 10.1109/WSESE66602.2025.00008
# [189/711] Fetching abstract for DOI: 10.1145/3696410.3714632
# [190/711] Fetching abstract for DOI: 10.1145/3701716.3715169
# [191/711] Fetching abstract for DOI: 10.5281/ZENODO.15003631
# [192/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.00217
# [193/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.00655
# [194/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.00826
# [195/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.01205
# [196/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.02688
# [197/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.03569
# [198/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.06370
# [199/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.09866
# [200/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.11086
# [201/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.12210
# [202/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.12904
# [203/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.15829
# [204/711] Fetching abstract for DOI: 10.48550/ARXIV.2501.16155
# [205/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.00350
# [206/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.01273
# [207/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.02009
# [208/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.02368
# [209/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.02675
# [210/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.03964
# [211/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.04008
# [212/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.04564
# [213/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.05310
# [214/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.06193
# [215/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.06215
# [216/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.06556
# [217/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.07049
# [218/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.07728
# [219/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.09331
# [220/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.12115
# [221/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.12964
# [222/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.14145
# [223/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.14541
# [224/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.16399
# [225/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.17441
# [226/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.17650
# [227/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.18449
# [228/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.18468
# [229/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.18851
# [230/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.19135
# [231/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.19413
# [232/711] Fetching abstract for DOI: 10.48550/ARXIV.2502.19518
# [233/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.01048
# [234/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.01319
# [235/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.01622
# [236/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.02246
# [237/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.02400
# [238/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.02463
# [239/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.05012
# [240/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.05507
# [241/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.05856
# [242/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.06781
# [243/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.07556
# [244/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.07967
# [245/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.09211
# [246/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.11018
# [247/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.11951
# [248/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.12043
# [249/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.13793
# [250/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.15231
# [251/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.16458
# [252/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.17741
# [253/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.18292
# [254/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.19693
# [255/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.21735
# [256/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.22238
# [257/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.22424
# [258/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.23514
# [259/711] Fetching abstract for DOI: 10.48550/ARXIV.2503.24157
# [260/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.01145
# [261/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.01637
# [262/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.02141
# [263/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.02553
# [264/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.04292
# [265/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.06143
# [266/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.06323
# [267/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.06614
# [268/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.07137
# [269/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.09378
# [270/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.09522
# [271/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.09855
# [272/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.10013
# [273/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.10050
# [274/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.10504
# [275/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.10906
# [276/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.11765
# [277/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.12337
# [278/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.15080
# [279/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.15439
# [280/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.16032
# [281/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.16472
# [282/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.19746
# [283/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.20049
# [284/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.20406
# [285/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.20437
# [286/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.20781
# [287/711] Fetching abstract for DOI: 10.48550/ARXIV.2504.21589
# [288/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.00651
# [289/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.01744
# [290/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.01841
# [291/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.03563
# [292/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.03796
# [293/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.04251
# [294/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.04628
# [295/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.07793
# [296/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.10008
# [297/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.10321
# [298/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.11570
# [299/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.12259
# [300/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.12951
# [301/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.13766
# [302/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.14336
# [303/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.15347
# [304/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.16067
# [305/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.16086
# [306/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.16697
# [307/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.17084
# [308/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.17196
# [309/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.17416
# [310/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.17710
# [311/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.17813
# [312/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.18019
# [313/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.18382
# [314/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.18597
# [315/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.19419
# [316/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.20521
# [317/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.21069
# [318/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.21919
# [319/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.23970
# [320/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.24037
# [321/711] Fetching abstract for DOI: 10.48550/ARXIV.2505.24119
# [322/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.00203
# [323/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.00486
# [324/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.02177
# [325/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.02546
# [326/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.02873
# [327/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.03504
# [328/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.03585
# [329/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.04133
# [330/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.04534
# [331/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.05364
# [332/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.06509
# [333/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.06519
# [334/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.06522
# [335/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.07240
# [336/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.10299
# [337/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.11237
# [338/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.11659
# [339/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.11791
# [340/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.12691
# [341/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.13090
# [342/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.13171
# [343/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.14387
# [344/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.15155
# [345/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.16136
# [346/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.16653
# [347/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.17006
# [348/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.19290
# [349/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.19806
# [350/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.20187
# [351/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.22688
# [352/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.23464
# [353/711] Fetching abstract for DOI: 10.48550/ARXIV.2506.23774
# [354/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.02170
# [355/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.02503
# [356/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.03156
# [357/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.06323
# [358/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.07186
# [359/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.07548
# [360/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.07996
# [361/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.08898
# [362/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.08979
# [363/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.09790
# [364/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.10593
# [365/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.10803
# [366/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.11898
# [367/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.13555
# [368/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.14330
# [369/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.15828
# [370/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.16331
# [371/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.17927
# [372/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.19113
# [373/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.19845
# [374/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.20655
# [375/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.21083
# [376/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.21428
# [377/711] Fetching abstract for DOI: 10.48550/ARXIV.2507.23370
# [378/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.00198
# [379/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.02233
# [380/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.02827
# [381/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.03603
# [382/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.04664
# [383/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.05299
# [384/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.06394
# [385/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.06554
# [386/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.08761
# [387/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.09149
# [388/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.09190
# [389/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.13171
# [390/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.15449
# [391/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.16445
# [392/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.18089
# [393/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.19089
# [394/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.20912
# [395/711] Fetching abstract for DOI: 10.48550/ARXIV.2508.21433
# [396/711] Fetching abstract for DOI: 10.48550/ARXIV.2509.00140
# [397/711] Fetching abstract for DOI: 10.48550/ARXIV.2509.02408
# [398/711] Fetching abstract for DOI: 10.48550/ARXIV.2509.02449
# [399/711] Fetching abstract for DOI: 10.48550/ARXIV.2509.05338
# [400/711] Fetching abstract for DOI: 10.48550/ARXIV.2509.07763
# [401/711] Fetching abstract for DOI: 10.1145/3695860
# [402/711] Fetching abstract for DOI: 10.1587/TRANSINF.2023IHP0011
# [403/711] Fetching abstract for DOI: 10.1007/S44196-024-00551-3
# [404/711] Fetching abstract for DOI: 10.1016/J.JSS.2024.112031
# [405/711] Fetching abstract for DOI: 10.1109/MNET.2024.3420120
# [406/711] Fetching abstract for DOI: 10.14778/3685800.3685838
# [407/711] Fetching abstract for DOI: 10.1016/J.SOFTX.2024.101847
# [408/711] Fetching abstract for DOI: 10.1007/S10270-024-01206-9
# [412/711] Fetching abstract for DOI: 10.1109/TLT.2024.3499751
# [413/711] Fetching abstract for DOI: 10.1109/TSE.2024.3428972
# [414/711] Fetching abstract for DOI: 10.1109/TSE.2024.3475375
# [415/711] Fetching abstract for DOI: 10.1109/TSE.2024.3470333
# [416/711] Fetching abstract for DOI: 10.1145/3643834.3660692
# [417/711] Fetching abstract for DOI: 10.1109/SSE62657.2024.00036
# [418/711] Fetching abstract for DOI: 10.18653/V1/2024.CLINICALNLP-1.39
# [419/711] Fetching abstract for DOI: 10.18653/V1/2024.ACL-LONG.738
# [420/711] Fetching abstract for DOI: 10.18653/V1/2024.ACL-SHORT.60
# [421/711] Fetching abstract for DOI: 10.18653/V1/2024.ACL-LONG.506
# [422/711] Fetching abstract for DOI: 10.1109/ACSACW65225.2024.00031
# [423/711] Fetching abstract for DOI: 10.1109/APSIPAASC63619.2025.10848752
# [424/711] Fetching abstract for DOI: 10.1109/ASP-DAC58780.2024.10473893
# [425/711] Fetching abstract for DOI: 10.1145/3620666.3651329
# [426/711] Fetching abstract for DOI: 10.1109/BIBM62325.2024.10821991
# [427/711] Fetching abstract for DOI: 10.1007/978-3-031-78666-2\_16
# [428/711] Fetching abstract for DOI: 10.1007/978-3-031-78666-2\_18
# [429/711] Fetching abstract for DOI: 10.1007/978-3-031-78666-2\_20
# [430/711] Fetching abstract for DOI: 10.1007/978-3-031-78666-2\_11
# [431/711] Fetching abstract for DOI: 10.1109/CCWC60891.2024.10427622
# [432/711] Fetching abstract for DOI: 10.1145/3613905.3650784
# [433/711] Fetching abstract for DOI: 10.1145/3613904.3642385
# [434/711] Fetching abstract for DOI: 10.1145/3627508.3638298
# [435/711] Fetching abstract for DOI: 10.1109/COG60054.2024.10645545
# [452/711] Fetching abstract for DOI: 10.1109/COMPSAC61105.2024.00156
# [453/711] Fetching abstract for DOI: 10.1145/3680121.3699887
# [454/711] Fetching abstract for DOI: 10.1109/CSEET62301.2024.10662989
# [455/711] Fetching abstract for DOI: 10.1109/CSEET62301.2024.10663055
# [456/711] Fetching abstract for DOI: 10.1145/3640794.3665570
# [457/711] Fetching abstract for DOI: 10.1109/CVPR52733.2024.01311
# [458/711] Fetching abstract for DOI: 10.1007/978-3-031-78238-1\_1
# [460/711] Fetching abstract for DOI: 10.1145/3661167.3661218
# [461/711] Fetching abstract for DOI: 10.1145/3661167.3661269
# [462/711] Fetching abstract for DOI: 10.1145/3661167.3661210
# [463/711] Fetching abstract for DOI: 10.1145/3661167.3661202
# [465/711] Fetching abstract for DOI: 10.18653/V1/2024.FINDINGS-EMNLP.827
# [466/711] Fetching abstract for DOI: 10.18653/V1/2024.EMNLP-INDUSTRY.65
# [467/711] Fetching abstract for DOI: 10.18653/V1/2024.EMNLP-MAIN.650
# [468/711] Fetching abstract for DOI: 10.1007/978-3-031-75872-0\_16
# [469/711] Fetching abstract for DOI: 10.1145/3674805.3690755
# [470/711] Fetching abstract for DOI: 10.1007/978-3-031-70879-4\_14
# [471/711] Fetching abstract for DOI: 10.1109/FLLM63129.2024.10852455
# [472/711] Fetching abstract for DOI: 10.1109/FLLM63129.2024.10852489
# [473/711] Fetching abstract for DOI: 10.4230/LIPICS.GD.2024.61
# [474/711] Fetching abstract for DOI: 10.1109/GLOBECOM52923.2024.10901065
# [475/711] Fetching abstract for DOI: 10.1109/HPEC62836.2024.10938418
# [476/711] Fetching abstract for DOI: 10.1007/978-981-96-0865-2\_23
# [477/711] Fetching abstract for DOI: 10.1109/ICASSP48485.2024.10446156
# [478/711] Fetching abstract for DOI: 10.1109/ICBASE63199.2024.10762029
# [479/711] Fetching abstract for DOI: 10.1007/978-3-031-63759-9\_27
# [480/711] Fetching abstract for DOI: 10.1145/3676536.3676740
# [481/711] Fetching abstract for DOI: 10.1145/3695080.3695127
# [483/711] Fetching abstract for DOI: 10.1109/ICMLA61862.2024.00254
# [484/711] Fetching abstract for DOI: 10.1145/3650200.3656592
# [485/711] Fetching abstract for DOI: 10.1109/ICSA-C63560.2024.00059
# [486/711] Fetching abstract for DOI: 10.1145/3643788.3648014
# [487/711] Fetching abstract for DOI: 10.1145/3643661.3643953
# [488/711] Fetching abstract for DOI: 10.1145/3597503.3639223
# [489/711] Fetching abstract for DOI: 10.1145/3639476.3639764
# [490/711] Fetching abstract for DOI: 10.1109/CAI59869.2024.00159
# [492/711] Fetching abstract for DOI: 10.1109/IOTSMS62296.2024.10710254
# [493/711] Fetching abstract for DOI: 10.1145/3650212.3652106
# [494/711] Fetching abstract for DOI: 10.1145/3650212.3680388
# [495/711] Fetching abstract for DOI: 10.1145/3650212.3680328
# [497/711] Fetching abstract for DOI: 10.1145/3640543.3645200
# [498/711] Fetching abstract for DOI: 10.1145/3691620.3695022
# [499/711] Fetching abstract for DOI: 10.1145/3691620.3695336
# [500/711] Fetching abstract for DOI: 10.1145/3691620.3695606
# [501/711] Fetching abstract for DOI: 10.1016/J.PROCS.2024.09.568
# [502/711] Fetching abstract for DOI: 10.1007/978-981-97-6469-3\_12
# [503/711] Fetching abstract for DOI: 10.1145/3699538.3699541
# [504/711] Fetching abstract for DOI: 10.1007/978-981-97-5492-2\_13
# [505/711] Fetching abstract for DOI: 10.1145/3643795.3648377
# [506/711] Fetching abstract for DOI: 10.1145/3643795.3648379
# [507/711] Fetching abstract for DOI: 10.1145/3716554.3716561
# [508/711] Fetching abstract for DOI: 10.1007/978-981-97-8692-3\_17
# [509/711] Fetching abstract for DOI: 10.1007/978-3-031-78386-9\_28
# [510/711] Fetching abstract for DOI: 10.1007/978-3-031-80889-0\_3
# [511/711] Fetching abstract for DOI: 10.1109/QRS-C63300.2024.00151
# [512/711] Fetching abstract for DOI: 10.1109/RE59067.2024.00056
# [513/711] Fetching abstract for DOI: 10.1109/RE59067.2024.00046
# [514/711] Fetching abstract for DOI: 10.1109/REW61692.2024.00045
# [515/711] Fetching abstract for DOI: 10.1007/978-3-031-65668-2\_20
# [516/711] Fetching abstract for DOI: 10.1145/3701625.3701675
# [517/711] Fetching abstract for DOI: 10.1109/SCISISIS61014.2024.10759994
# [518/711] Fetching abstract for DOI: 10.1007/978-981-96-4656-2\_7
# [519/711] Fetching abstract for DOI: 10.18420/SEUH2024\_04
# [520/711] Fetching abstract for DOI: 10.1145/3626252.3630927
# [521/711] Fetching abstract for DOI: 10.1145/3649409.3691092
# [522/711] Fetching abstract for DOI: 10.1145/3626772.3657828
# [523/711] Fetching abstract for DOI: 10.1145/3663529.3663861
# [524/711] Fetching abstract for DOI: 10.1109/SMARTGRIDCOMM60555.2024.10738100
# [525/711] Fetching abstract for DOI: 10.1145/3694715.3695971
# [526/711] Fetching abstract for DOI: 10.1145/3654777.3676348
# [527/711] Fetching abstract for DOI: 10.1145/3672539.3686341
# [528/711] Fetching abstract for DOI: 10.1007/978-3-031-75434-0\_11
# [529/711] Fetching abstract for DOI: 10.1007/978-3-031-75434-0\_9
# [530/711] Fetching abstract for DOI: 10.1109/VL/HCC60511.2024.00053
# [532/711] Fetching abstract for DOI: 10.1109/VTC2024-FALL63153.2024.10757597
# [533/711] Fetching abstract for DOI: 10.1145/3677619.3678131
# [534/711] Fetching abstract for DOI: 10.18653/V1/2024.WMT-1.14
# [535/711] Fetching abstract for DOI: 10.1145/3589335.3651233
# [537/711] Fetching abstract for DOI: 10.1007/978-3-031-72781-8\_12
# [539/711] Fetching abstract for DOI: 10.5281/ZENODO.13139492
# [540/711] Fetching abstract for DOI: 10.5281/ZENODO.12677054
# [541/711] Fetching abstract for DOI: 10.5281/ZENODO.12661315
# [542/711] Fetching abstract for DOI: 10.5281/ZENODO.12538512
# [543/711] Fetching abstract for DOI: 10.5281/ZENODO.12538511
# [544/711] Fetching abstract for DOI: 10.5281/ZENODO.12599730
# [545/711] Fetching abstract for DOI: 10.5281/ZENODO.12594274
# [546/711] Fetching abstract for DOI: 10.5281/ZENODO.12594273
# [547/711] Fetching abstract for DOI: 10.5281/ZENODO.12738577
# [548/711] Fetching abstract for DOI: 10.48550/ARXIV.2401.06676
# [549/711] Fetching abstract for DOI: 10.48550/ARXIV.2401.07526
# [550/711] Fetching abstract for DOI: 10.48550/ARXIV.2401.09092
# [551/711] Fetching abstract for DOI: 10.48550/ARXIV.2401.16186
# [552/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.02643
# [553/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.04380
# [554/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.07442
# [555/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.08030
# [556/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.10067
# [557/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.10890
# [558/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.10908
# [559/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.13220
# [560/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.13518
# [561/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.14261
# [562/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.14533
# [563/711] Fetching abstract for DOI: 10.48550/ARXIV.2402.16832
# [564/711] Fetching abstract for DOI: 10.48550/ARXIV.2403.03507
# [565/711] Fetching abstract for DOI: 10.48550/ARXIV.2403.08429
# [566/711] Fetching abstract for DOI: 10.48550/ARXIV.2403.10588
# [567/711] Fetching abstract for DOI: 10.48550/ARXIV.2403.15852
# [568/711] Fetching abstract for DOI: 10.48550/ARXIV.2403.16159
# [569/711] Fetching abstract for DOI: 10.48550/ARXIV.2403.16362
# [570/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.00640
# [571/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.01332
# [572/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.02056
# [573/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.03662
# [574/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.04793
# [575/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.04834
# [576/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.09384
# [577/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.09789
# [578/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.15869
# [579/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.17842
# [580/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.18832
# [581/711] Fetching abstract for DOI: 10.48550/ARXIV.2404.18919
# [582/711] Fetching abstract for DOI: 10.48550/ARXIV.2405.04437
# [583/711] Fetching abstract for DOI: 10.48550/ARXIV.2405.11346
# [584/711] Fetching abstract for DOI: 10.48550/ARXIV.2405.11835
# [585/711] Fetching abstract for DOI: 10.48550/ARXIV.2405.15114
# [586/711] Fetching abstract for DOI: 10.48550/ARXIV.2405.17378
# [587/711] Fetching abstract for DOI: 10.48550/ARXIV.2405.18380
# [588/711] Fetching abstract for DOI: 10.48550/ARXIV.2406.01721
# [589/711] Fetching abstract for DOI: 10.48550/ARXIV.2406.03317
# [590/711] Fetching abstract for DOI: 10.48550/ARXIV.2406.06059
# [591/711] Fetching abstract for DOI: 10.48550/ARXIV.2406.08269
# [592/711] Fetching abstract for DOI: 10.48550/ARXIV.2406.08305
# [593/711] Fetching abstract for DOI: 10.48550/ARXIV.2406.09233
# [594/711] Fetching abstract for DOI: 10.48550/ARXIV.2406.10181
# [595/711] Fetching abstract for DOI: 10.48550/ARXIV.2406.10300
# [596/711] Fetching abstract for DOI: 10.48550/ARXIV.2406.10958
# [597/711] Fetching abstract for DOI: 10.48550/ARXIV.2406.12806
# [598/711] Fetching abstract for DOI: 10.48550/ARXIV.2406.13972
# [599/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.00487
# [600/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.00978
# [601/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.01489
# [602/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.02392
# [603/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.03963
# [604/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.06798
# [605/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.14372
# [606/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.14402
# [607/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.15309
# [608/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.16557
# [609/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.18992
# [610/711] Fetching abstract for DOI: 10.48550/ARXIV.2407.20588
# [611/711] Fetching abstract for DOI: 10.48550/ARXIV.2408.00948
# [612/711] Fetching abstract for DOI: 10.48550/ARXIV.2408.01055
# [613/711] Fetching abstract for DOI: 10.48550/ARXIV.2408.01527
# [614/711] Fetching abstract for DOI: 10.48550/ARXIV.2408.02479
# [615/711] Fetching abstract for DOI: 10.48550/ARXIV.2408.03528
# [616/711] Fetching abstract for DOI: 10.48550/ARXIV.2408.05534
# [617/711] Fetching abstract for DOI: 10.48550/ARXIV.2408.09785
# [618/711] Fetching abstract for DOI: 10.48550/ARXIV.2408.10886
# [619/711] Fetching abstract for DOI: 10.48550/ARXIV.2408.16400
# [620/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.01001
# [621/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.06205
# [622/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.06558
# [623/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.06643
# [624/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.06816
# [625/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.09338
# [626/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.14605
# [627/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.16395
# [628/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.16559
# [629/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.16732
# [630/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.17166
# [631/711] Fetching abstract for DOI: 10.48550/ARXIV.2409.18203
# [632/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.01109
# [633/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.08911
# [634/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.09457
# [635/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.11906
# [636/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.12071
# [637/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.15512
# [638/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.17245
# [639/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.17619
# [640/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.18703
# [641/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.19274
# [642/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.20200
# [643/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.22368
# [644/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.23069
# [645/711] Fetching abstract for DOI: 10.48550/ARXIV.2410.23365
# [646/711] Fetching abstract for DOI: 10.48550/ARXIV.2411.00932
# [647/711] Fetching abstract for DOI: 10.48550/ARXIV.2411.02594
# [648/711] Fetching abstract for DOI: 10.48550/ARXIV.2411.03923
# [649/711] Fetching abstract for DOI: 10.48550/ARXIV.2411.04444
# [650/711] Fetching abstract for DOI: 10.48550/ARXIV.2411.09916
# [651/711] Fetching abstract for DOI: 10.48550/ARXIV.2411.09974
# [652/711] Fetching abstract for DOI: 10.48550/ARXIV.2411.13269
# [653/711] Fetching abstract for DOI: 10.48550/ARXIV.2411.13941
# [654/711] Fetching abstract for DOI: 10.48550/ARXIV.2411.17927
# [655/711] Fetching abstract for DOI: 10.48550/ARXIV.2411.17981
# [656/711] Fetching abstract for DOI: 10.48550/ARXIV.2411.19146
# [657/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.00329
# [658/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.00546
# [659/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.03815
# [660/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.03905
# [661/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.05098
# [662/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.06294
# [663/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.09644
# [664/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.10133
# [665/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.14461
# [666/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.15574
# [667/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.16434
# [668/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.18588
# [669/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.19616
# [670/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.19820
# [671/711] Fetching abstract for DOI: 10.48550/ARXIV.2412.21016
# [673/711] Fetching abstract for DOI: 10.1109/AICS60730.2023.10470654
# [674/711] Fetching abstract for DOI: 10.1007/978-3-031-50974-2\_32
# [677/711] Fetching abstract for DOI: 10.23919/CNSM59352.2023.10327837
# [679/711] Fetching abstract for DOI: 10.18653/V1/2023.FINDINGS-EMNLP.68
# [680/711] Fetching abstract for DOI: 10.1145/3582515.3609536
# [681/711] Fetching abstract for DOI: 10.1109/ICCA59364.2023.10401818
# [682/711] Fetching abstract for DOI: 10.1109/ICSPIS60075.2023.10344019
# [683/711] Fetching abstract for DOI: 10.1109/ASE56229.2023.00035
# [685/711] Fetching abstract for DOI: 10.1145/3617555.3634736
# [686/711] Fetching abstract for DOI: 10.1109/SMARTCLOUD58862.2023.00038
# [687/711] Fetching abstract for DOI: 10.1145/3573381.3603362
# [689/711] Fetching abstract for DOI: 10.5281/ZENODO.10040086
# [690/711] Fetching abstract for DOI: 10.48550/ARXIV.2304.09064
# [691/711] Fetching abstract for DOI: 10.48550/ARXIV.2306.02230
# [692/711] Fetching abstract for DOI: 10.48550/ARXIV.2308.00158
# [693/711] Fetching abstract for DOI: 10.48550/ARXIV.2308.04416
# [694/711] Fetching abstract for DOI: 10.48550/ARXIV.2308.08043
# [695/711] Fetching abstract for DOI: 10.48550/ARXIV.2309.03852
# [696/711] Fetching abstract for DOI: 10.48550/ARXIV.2309.07418
# [697/711] Fetching abstract for DOI: 10.48550/ARXIV.2309.11653
# [698/711] Fetching abstract for DOI: 10.48550/ARXIV.2311.06237
# [699/711] Fetching abstract for DOI: 10.48550/ARXIV.2312.02296
# [700/711] Fetching abstract for DOI: 10.48550/ARXIV.2312.06121
# [701/711] Fetching abstract for DOI: 10.48550/ARXIV.2312.06742
# [702/711] Fetching abstract for DOI: 10.48550/ARXIV.2312.08055
# [703/711] Fetching abstract for DOI: 10.48550/ARXIV.2312.09731
# [704/711] Fetching abstract for DOI: 10.1145/3551349.3559555
# [705/711] Fetching abstract for DOI: 10.48550/ARXIV.2207.04237
# [706/711] Fetching abstract for DOI: 10.1007/978-3-030-81688-9\_32
# [707/711] Fetching abstract for DOI: 10.1007/S11390-018-1819-2
# [708/711] Fetching abstract for DOI: 10.1145/2501626.2501632
# [709/711] Fetching abstract for DOI: 10.1109/ASAP.2011.6043275
# [710/711] Fetching abstract for DOI: 10.1145/1878961.1879015
# [711/711] Fetching abstract for DOI: 10.1145/1579114.1579173
#
# ✅ Done! Abstracts added for 296 papers.
# 💾 Saved enriched dataset to: dblp_with_abstracts.csv

# %% [markdown]
# # Extracting CSV data values from XLSX file

# %%
# !pip install pandas openpyxl fuzzywuzzy python-Levenshtein
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting python-Levenshtein
#   Downloading python_levenshtein-0.27.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Collecting Levenshtein==0.27.3 (from python-Levenshtein)
#   Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from Levenshtein==0.27.3->python-Levenshtein)
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Downloading python_levenshtein-0.27.3-py3-none-any.whl (9.5 kB)
# Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 2.5 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 29.6 MB/s eta 0:00:00
# Installing collected packages: fuzzywuzzy, rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.27.3 fuzzywuzzy-0.18.0 python-Levenshtein-0.27.3 rapidfuzz-3.14.3

# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
import warnings
warnings.filterwarnings('ignore')

# Read the files
csv_file = 'unique_in_1152.csv'  # Replace with your CSV filename
xlsx_file = 'Title_Abstract_Screening_1152.xlsx'  # Replace with your Excel filename

print("Reading files...")
df_csv = pd.read_csv(csv_file)
df_xlsx = pd.read_excel(xlsx_file)

# Clean column names (remove extra spaces)
df_csv.columns = df_csv.columns.str.strip()
df_xlsx.columns = df_xlsx.columns.str.strip()

print(f"CSV file contains {len(df_csv)} entries")
print(f"Excel file contains {len(df_xlsx)} entries")

# Normalize text for better matching
def normalize_text(text):
    """Normalize text by converting to lowercase and removing extra spaces"""
    if pd.isna(text):
        return ""
    return str(text).lower().strip()

# Create normalized versions for matching
df_csv['title_norm'] = df_csv['title'].apply(normalize_text)
df_csv['doi_norm'] = df_csv['doi'].apply(normalize_text)

df_xlsx['Title_norm'] = df_xlsx['Title'].apply(normalize_text)
df_xlsx['DOI_norm'] = df_xlsx['DOI'].apply(normalize_text)

# Initialize results
results = []
matched_count = 0
unmatched_indices = []

print("\nMatching entries...")

# Match each CSV entry with Excel entries
for idx, csv_row in df_csv.iterrows():
    matched = False

    # First try: Match by DOI (most reliable)
    if csv_row['doi_norm']:
        doi_match = df_xlsx[df_xlsx['DOI_norm'] == csv_row['doi_norm']]
        if not doi_match.empty:
            matched = True
            matched_row = doi_match.iloc[0]

    # Second try: Match by title (exact match)
    if not matched and csv_row['title_norm']:
        title_match = df_xlsx[df_xlsx['Title_norm'] == csv_row['title_norm']]
        if not title_match.empty:
            matched = True
            matched_row = title_match.iloc[0]

    # Third try: Fuzzy matching on title (if exact match fails)
    if not matched and csv_row['title_norm']:
        max_ratio = 0
        best_match_idx = None

        for xlsx_idx, xlsx_row in df_xlsx.iterrows():
            ratio = fuzz.ratio(csv_row['title_norm'], xlsx_row['Title_norm'])
            if ratio > max_ratio:
                max_ratio = ratio
                best_match_idx = xlsx_idx

        # Use fuzzy match if similarity is high enough (>90%)
        if max_ratio > 90:
            matched = True
            matched_row = df_xlsx.iloc[best_match_idx]

    if matched:
        matched_count += 1
        results.append({
            'CSV_Index': idx,
            'Title': csv_row['title'],
            'DOI': csv_row['doi'],
            'Excluded': matched_row['Excluded'],
            'Reason': matched_row['Reason']
        })
    else:
        unmatched_indices.append(idx)
        results.append({
            'CSV_Index': idx,
            'Title': csv_row['title'],
            'DOI': csv_row['doi'],
            'Excluded': 'NOT_FOUND',
            'Reason': 'No match found in Excel file'
        })

# Create results dataframe
df_results = pd.DataFrame(results)

# Save results
output_file = 'matched_results.csv'
df_results.to_csv(output_file, index=False)

print(f"\n{'='*60}")
print(f"Matching completed!")
print(f"{'='*60}")
print(f"Total CSV entries: {len(df_csv)}")
print(f"Successfully matched: {matched_count}")
print(f"Unmatched entries: {len(unmatched_indices)}")
print(f"\nResults saved to: {output_file}")

if unmatched_indices:
    print(f"\nUnmatched CSV indices: {unmatched_indices[:10]}" +
          ("..." if len(unmatched_indices) > 10 else ""))

# Display summary statistics
print("\n" + "="*60)
print("Exclusion Summary:")
print("="*60)
if matched_count > 0:
    exclusion_counts = df_results[df_results['Excluded'] != 'NOT_FOUND']['Excluded'].value_counts()
    print(exclusion_counts)

    print("\nSample of matched results:")
    print(df_results.head(10).to_string())
else:
    print("No matches found!")

# %% [markdown]
# checking how many papers (out of 116 papers independently screened based for titles and abstract) are present in the common 1052 papers.

# %%
import pandas as pd
import re

def normalize_text(text):
    """Normalize text for comparison by converting to lowercase and removing extra whitespace"""
    if pd.isna(text) or text is None:
        return ""
    return re.sub(r'\s+', ' ', str(text).lower().strip())

def extract_doi(text):
    """Extract DOI from text, handling various formats"""
    if pd.isna(text) or text is None:
        return ""
    text = str(text).lower()
    # Remove common DOI prefixes
    text = text.replace('https://doi.org/', '').replace('http://doi.org/', '')
    text = text.replace('doi:', '').strip()
    return text

def check_matches(csv_file, xlsx_file):
    """
    Check how many XLSX entries are present in CSV file

    Parameters:
    csv_file: path to CSV file
    xlsx_file: path to XLSX file
    """

    # Read files
    print("Reading CSV file...")
    csv_df = pd.read_csv(csv_file)
    print(f"CSV file loaded: {len(csv_df)} rows")

    print("\nReading XLSX file...")
    xlsx_df = pd.read_excel(xlsx_file)
    print(f"XLSX file loaded: {len(xlsx_df)} rows")

    # Display column names
    print("\nCSV columns:", csv_df.columns.tolist())
    print("XLSX columns:", xlsx_df.columns.tolist())

    # Normalize CSV data (already lowercase according to user)
    csv_df['normalized_title'] = csv_df['Normalized Title'].apply(normalize_text)
    csv_df['normalized_doi'] = csv_df['doi'].apply(extract_doi)
    csv_df['normalized_abstract'] = csv_df['abstract'].apply(normalize_text)

    # Normalize XLSX data (convert to lowercase)
    xlsx_df['normalized_title'] = xlsx_df['Title'].apply(normalize_text)
    xlsx_df['normalized_doi'] = xlsx_df['DOI'].apply(extract_doi)
    xlsx_df['normalized_abstract'] = xlsx_df['Abstract'].apply(normalize_text)

    # Track matches
    matches = []
    match_methods = []

    print("\n" + "="*80)
    print("Checking for matches...")
    print("="*80)

    for idx, xlsx_row in xlsx_df.iterrows():
        matched = False
        match_method = ""

        # Method 1: Check by DOI (most reliable)
        if xlsx_row['normalized_doi'] and xlsx_row['normalized_doi'] != "":
            doi_match = csv_df[csv_df['normalized_doi'] == xlsx_row['normalized_doi']]
            if not doi_match.empty:
                matched = True
                match_method = "DOI"

        # Method 2: Check by exact title match
        if not matched and xlsx_row['normalized_title'] and xlsx_row['normalized_title'] != "":
            title_match = csv_df[csv_df['normalized_title'] == xlsx_row['normalized_title']]
            if not title_match.empty:
                matched = True
                match_method = "Exact Title"

        # Method 3: Check by partial title match (first 50 characters)
        if not matched and xlsx_row['normalized_title'] and len(xlsx_row['normalized_title']) > 50:
            title_prefix = xlsx_row['normalized_title'][:50]
            partial_match = csv_df[csv_df['normalized_title'].str.startswith(title_prefix)]
            if not partial_match.empty:
                matched = True
                match_method = "Partial Title"

        # Method 4: Check by abstract similarity (first 100 characters)
        if not matched and xlsx_row['normalized_abstract'] and len(xlsx_row['normalized_abstract']) > 100:
            abstract_prefix = xlsx_row['normalized_abstract'][:100]
            abstract_match = csv_df[csv_df['normalized_abstract'].str.startswith(abstract_prefix)]
            if not abstract_match.empty:
                matched = True
                match_method = "Abstract"

        matches.append(matched)
        match_methods.append(match_method if matched else "No Match")

        # Print progress every 20 rows
        if (idx + 1) % 20 == 0:
            print(f"Processed {idx + 1}/{len(xlsx_df)} rows...")

    # Add results to XLSX dataframe
    xlsx_df['Matched'] = matches
    xlsx_df['Match_Method'] = match_methods

    # Summary statistics
    total_matches = sum(matches)
    match_rate = (total_matches / len(xlsx_df)) * 100

    print("\n" + "="*80)
    print("RESULTS SUMMARY")
    print("="*80)
    print(f"Total XLSX entries: {len(xlsx_df)}")
    print(f"Entries found in CSV: {total_matches}")
    print(f"Entries NOT found in CSV: {len(xlsx_df) - total_matches}")
    print(f"Match rate: {match_rate:.2f}%")

    print("\nMatches by method:")
    method_counts = xlsx_df['Match_Method'].value_counts()
    for method, count in method_counts.items():
        print(f"  {method}: {count}")

    # Show some examples of matches and non-matches
    print("\n" + "="*80)
    print("SAMPLE MATCHES (first 5)")
    print("="*80)
    matched_samples = xlsx_df[xlsx_df['Matched'] == True].head(5)
    for idx, row in matched_samples.iterrows():
        print(f"\n[{row['Match_Method']}] {row['Title'][:80]}...")

    print("\n" + "="*80)
    print("SAMPLE NON-MATCHES (first 5)")
    print("="*80)
    non_matched_samples = xlsx_df[xlsx_df['Matched'] == False].head(5)
    for idx, row in non_matched_samples.iterrows():
        print(f"\n{row['Title'][:80]}...")

    # Save detailed results
    output_file = 'match_results.xlsx'
    xlsx_df.to_excel(output_file, index=False)
    print(f"\n\nDetailed results saved to: {output_file}")

    return xlsx_df

# Usage
if __name__ == "__main__":
    # Replace these with your actual file paths
    csv_file = "duplicates1052.csv"
    xlsx_file = "Title_Abstract_Screening_joint.xlsx"

    try:
        results = check_matches(csv_file, xlsx_file)
    except FileNotFoundError as e:
        print(f"Error: {e}")
        print("\nPlease update the file paths in the script:")
        print("  csv_file = 'duplicates1052.csv'")
        print("  xlsx_file = 'Title_Abstract_Screening_joint.xlsx'")
    except Exception as e:
        print(f"An error occurred: {e}")
        import traceback
        traceback.print_exc()
# Out:
# Reading CSV file...
# CSV file loaded: 1052 rows
#
# Reading XLSX file...
# XLSX file loaded: 116 rows
#
# CSV columns: ['title', 'authors', 'doi', 'year', 'abstract', 'Normalized Title', 'Normalized Authors']
# XLSX columns: ['Title', 'Abstract', 'Authors', 'DOI', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', "Saad's choices"]
#
# ================================================================================
# Checking for matches...
# ================================================================================
# Processed 20/116 rows...
# Processed 40/116 rows...
# Processed 60/116 rows...
# Processed 80/116 rows...
# Processed 100/116 rows...
#
# ================================================================================
# RESULTS SUMMARY
# ================================================================================
# Total XLSX entries: 116
# Entries found in CSV: 100
# Entries NOT found in CSV: 16
# Match rate: 86.21%
#
# Matches by method:
#   DOI: 100
#   No Match: 16
#
# ================================================================================
# SAMPLE MATCHES (first 5)
# ================================================================================
#
# [DOI] The Distributed Situational Centers System as an Instrument of State and Corpora...
#
# [DOI] Ambiguous regulations for dealing with AI in higher education can lead to moral ...
#
# [DOI] Enablers, barriers and strategies for adopting new technology in accounting...
#
# [DOI] Automated progress monitoring of construction projects using Machine learning an...
#
# [DOI] Choosing the right path for AI integration in engineering companies: A strategic...
#
# ================================================================================
# SAMPLE NON-MATCHES (first 5)
# ================================================================================
#
# Leveraging LLM-based data augmentation for automatic classification of recurring...
#
# Using Automation and Artificial Intelligence in the Management of European Socia...
#
# Verification and Validation for data marketplaces via a blockchain and smart con...
#
# Cross-platform EPC collaboration framework for construction management of pumped...
#
# A new approach for competency frameworks mapping using large language models...
#
#
# Detailed results saved to: match_results.xlsx
